# %%
import fitz

# %%
from collections import deque  
  
def find_fastest_path_with_conveyors(matrix, start, end):  
    def get_neighbors(node):  
        directions = [(1, 0), (-1, 0), (0, 1), (0, -1)]  
        neighbors = []  
        for direction in directions:  
            neighbor = (node[0] + direction[0], node[1] + direction[1])  
            if 0 <= neighbor[0] < len(matrix) and 0 <= neighbor[1] < len(matrix[0]):  
                if matrix[neighbor[0]][neighbor[1]] == ' ':  
                    neighbors.append(neighbor)  
        return neighbors  
  
    # Mapping conveyor points  
    conveyor_map = {}  
    for i in range(len(matrix)):  
        for j in range(len(matrix[0])):  
            if matrix[i][j] == 'c':  
                if 'start' not in conveyor_map:  
                    conveyor_map['start'] = (i, j)  
                else:  
                    conveyor_map['end'] = (i, j)  
                    conveyor_map[conveyor_map['start']] = conveyor_map['end']  
                    conveyor_map[conveyor_map['end']] = conveyor_map['start']  
                    del conveyor_map['start']  
                    del conveyor_map['end']  
  
    queue = deque([(start, 0)])  
    visited = set()  
    visited.add(start)  
  
    while queue:  
        current, distance = queue.popleft()  
        if current == end:  
            return distance  
  
        for neighbor in get_neighbors(current):  
            if neighbor not in visited:  
                visited.add(neighbor)  
                queue.append((neighbor, distance + 1))  
  
        # Check if the current cell is a conveyor start point  
        if current in conveyor_map:  
            conveyor_destination = conveyor_map[current]  
            if conveyor_destination not in visited:  
                visited.add(conveyor_destination)  
                queue.append((conveyor_destination, distance + 1))  
  
    return float('inf')  
  
matrix = [  
    ['x', 'c', ' ', ' ', 'x'],  
    [' ', ' ', ' ', ' ', ' '],  
    ['x', 'x', 'c', ' ', ' '],  
    [' ', ' ', 'x', 'x', ' '],  
    ['c', ' ', ' ', ' ', ' ']  
]  
  
start = (1, 0)  
end = (3, 4)  
shortest_distance = find_fastest_path_with_conveyors(matrix, start, end)  
print("Fastest Path Distance with Conveyors:", shortest_distance)
# Out:
# Fastest Path Distance with Conveyors: 6

# %%
from collections import deque  
  
def find_fastest_path_with_conveyors(matrix, start, end):  
    def get_neighbors(node):  
        directions = [(1, 0), (-1, 0), (0, 1), (0, -1)]  
        neighbors = []  
        for direction in directions:  
            neighbor = (node[0] + direction[0], node[1] + direction[1])  
            if 0 <= neighbor[0] < len(matrix) and 0 <= neighbor[1] < len(matrix[0]):  
                if matrix[neighbor[0]][neighbor[1]] == ' ' or matrix[neighbor[0]][neighbor[1]].startswith('c'):  
                    neighbors.append(neighbor)  
        return neighbors  
  
    # Mapping conveyor points  
    conveyor_map = {}  
    for i in range(len(matrix)):  
        for j in range(len(matrix[0])):  
            if matrix[i][j].startswith('c'):  
                if matrix[i][j] not in conveyor_map:  
                    conveyor_map[matrix[i][j]] = [(i, j)]  
                else:  
                    conveyor_map[matrix[i][j]].append((i, j))  
  
    # Create a dictionary that maps each conveyor point to its corresponding endpoint  
    conveyor_endpoints = {}  
    for points in conveyor_map.values():  
        if len(points) == 2:  
            conveyor_endpoints[points[0]] = points[1]  
            conveyor_endpoints[points[1]] = points[0]  
  
    queue = deque([(start, 0)])  
    visited = set()  
    visited.add(start)  
  
    while queue:  
        current, distance = queue.popleft()  
        if current == end:  
            return distance  
  
        for neighbor in get_neighbors(current):  
            if neighbor not in visited:  
                visited.add(neighbor)  
                queue.append((neighbor, distance + 1))  
  
        # Check if the current cell is a conveyor start point  
        if current in conveyor_endpoints:  
            conveyor_destination = conveyor_endpoints[current]  
            if conveyor_destination not in visited:  
                visited.add(conveyor_destination)  
                queue.append((conveyor_destination, distance + 1))  
  
    return float('inf')  
  
matrix = [  
    ['x', 'c1', ' ', ' ', 'x'],  
    [' ', ' ', ' ', ' ', 'c2'],  
    ['x', 'x', 'c1', ' ', ' '],  
    [' ', ' ', 'x', 'x', ' '],  
    ['c2', ' ', ' ', ' ', ' ']  
]  
  
start = (0, 2)  
end = (4, 1)  
shortest_distance = find_fastest_path_with_conveyors(matrix, start, end)  
print("Fastest Path Distance with Multiple Conveyors:", shortest_distance)
# Out:
# Fastest Path Distance with Multiple Conveyors: 5

# %%
from collections import deque  
  
def find_fastest_path_with_conveyors(matrix, start, end):  
    def get_neighbors(node):  
        directions = [(1, 0), (-1, 0), (0, 1), (0, -1)]  
        neighbors = []  
        for direction in directions:  
            neighbor = (node[0] + direction[0], node[1] + direction[1])  
            if 0 <= neighbor[0] < len(matrix) and 0 <= neighbor[1] < len(matrix[0]):  
                if matrix[neighbor[0]][neighbor[1]] == ' ' or matrix[neighbor[0]][neighbor[1]].startswith('c'):  
                    neighbors.append(neighbor)  
        return neighbors  
  
    # Mapping conveyor points  
    conveyor_map = {}  
    for i in range(len(matrix)):  
        for j in range(len(matrix[0])):  
            if matrix[i][j].startswith('c'):  
                if matrix[i][j] not in conveyor_map:  
                    conveyor_map[matrix[i][j]] = [(i, j)]  
                else:  
                    conveyor_map[matrix[i][j]].append((i, j))  
  
    # Create a dictionary that maps each conveyor point to its corresponding endpoint  
    conveyor_endpoints = {}  
    for points in conveyor_map.values():  
        if len(points) == 2:  
            conveyor_endpoints[points[0]] = points[1]  
            conveyor_endpoints[points[1]] = points[0]  
  
    queue = deque([(start, 0)])  
    visited = set()  
    visited.add(start)  
  
    while queue:  
        current, distance = queue.popleft()  
        if current == end:  
            return distance  
  
        for neighbor in get_neighbors(current):  
            if neighbor not in visited:  
                visited.add(neighbor)  
                queue.append((neighbor, distance + 1))  
  
        # Check if the current cell is a conveyor start point  
        if current in conveyor_endpoints:  
            conveyor_destination = conveyor_endpoints[current]  
            if conveyor_destination not in visited:  
                visited.add(conveyor_destination)  
                queue.append((conveyor_destination, distance + 1))  
  
    return float('inf')  
  
matrix = [  
    ['x', 'c1', ' ', ' ', 'x'],  
    [' ', ' ', ' ', ' ', ' '],  
    ['x', 'x', 'c2', ' ', ' '],  
    [' ', ' ', 'x', 'x', ' '],  
    ['c1', ' ', ' ', 'c2', ' ']  
]  
  
start = (1,0)  
end = (4, 4)  
shortest_distance = find_fastest_path_with_conveyors(matrix, start, end)  
print("Fastest Path Distance with Multiple Conveyors:", shortest_distance)
# Out:
# Fastest Path Distance with Multiple Conveyors: 5

# %%
from collections import deque  
  
def find_fastest_path_with_conveyors(matrix, start, end):  
    def get_neighbors(node):  
        directions = [(1, 0), (-1, 0), (0, 1), (0, -1)]  
        neighbors = []  
        for direction in directions:  
            neighbor = (node[0] + direction[0], node[1] + direction[1])  
            if 0 <= neighbor[0] < len(matrix) and 0 <= neighbor[1] < len(matrix[0]):  
                if matrix[neighbor[0]][neighbor[1]] == ' ' or matrix[neighbor[0]][neighbor[1]].startswith('c'):  
                    neighbors.append(neighbor)  
        return neighbors  
  
    # Mapping conveyor points  
    conveyor_map = {}  
    for i in range(len(matrix)):  
        for j in range(len(matrix[0])):  
            if matrix[i][j].startswith('c'):  
                if matrix[i][j] not in conveyor_map:  
                    conveyor_map[matrix[i][j]] = [(i, j)]  
                else:  
                    conveyor_map[matrix[i][j]].append((i, j))  
  
    # Create a dictionary that maps each conveyor point to its corresponding endpoint  
    conveyor_endpoints = {}  
    for points in conveyor_map.values():  
        if len(points) == 2:  
            conveyor_endpoints[points[0]] = points[1]  
            conveyor_endpoints[points[1]] = points[0]  
  
    queue = deque([(start, 0)])  
    visited = set()  
    visited.add(start)  
    parent = {start: None}  
  
    while queue:  
        current, distance = queue.popleft()  
        if current == end:  
            # Reconstruct the path  
            path = []  
            while current is not None:  
                path.append(current)  
                current = parent[current]  
            path.reverse()  
            return distance, path  
  
        for neighbor in get_neighbors(current):  
            if neighbor not in visited:  
                visited.add(neighbor)  
                parent[neighbor] = current  
                queue.append((neighbor, distance + 1))  
  
        # Check if the current cell is a conveyor start point  
        if current in conveyor_endpoints:  
            conveyor_destination = conveyor_endpoints[current]  
            if conveyor_destination not in visited:  
                visited.add(conveyor_destination)  
                parent[conveyor_destination] = current  
                queue.append((conveyor_destination, distance + 1))  
  
    return float('inf'), []  
  
matrix = [  
    ['x', 'c1', ' ', ' ', 'x'],  
    [' ', ' ', ' ', ' ', ' '],  
    ['x', 'x', 'c2', ' ', ' '],  
    [' ', ' ', 'x', 'x', ' '],  
    ['c1', ' ', ' ', 'c2', ' ']  
]  
  
start = (1, 0)  
end = (4, 4)  
shortest_distance, path = find_fastest_path_with_conveyors(matrix, start, end)  
print("Fastest Path Distance with Multiple Conveyors:", shortest_distance)  
print("Path Taken:", path)
# Out:
# Fastest Path Distance with Multiple Conveyors: 5
# Path Taken: [(1, 0), (1, 1), (1, 2), (2, 2), (4, 3), (4, 4)]

# %%
import os

def remove_highlighted_files(pdf_dir):
    # Walk through the directory and subdirectories
    for root, dirs, files in os.walk(pdf_dir):
        for file in files:
            if file.startswith("highlighted_"):
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Removed file: {file_path}")

pdf_dir = 'C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf'
remove_highlighted_files(pdf_dir)
# Out:
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_CybergyHoldingsInc_20140520_10-Q_EX-10.27_8605784_EX-10.27_Affiliate Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_DigitalCinemaDestinationsCorp_20111220_S-1_EX-10.10_7346719_EX-10.10_Affiliate Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_LinkPlusCorp_20050802_8-K_EX-10_3240252_EX-10_Affiliate Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_SouthernStarEnergyInc_20051202_SB-2A_EX-9_801890_EX-9_Affiliate Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_SteelVaultCorp_20081224_10-K_EX-10.16_3074935_EX-10.16_Affiliate Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_TubeMediaCorp_20060310_8-K_EX-10.1_513921_EX-10.1_Affiliate Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_UnionDentalHoldingsInc_20050204_8-KA_EX-10_3345577_EX-10_Affiliate Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Affiliate_Agreements\highlighted_UsioInc_20040428_SB-2_EX-10.11_1723988_EX-10.11_Affiliate Agreement 2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_2ThemartComInc_19990826_10-12G_EX-10.10_6700288_EX-10.10_Co-Branding Agreement_ Agency Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_DeltathreeInc_19991102_S-1A_EX-10.19_6227850_EX-10.19_Co-Branding Agreement_ Service Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_EbixInc_20010515_10-Q_EX-10.3_4049767_EX-10.3_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_EdietsComInc_20001030_10QSB_EX-10.4_2606646_EX-10.4_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_EmbarkComInc_19991008_S-1A_EX-10.10_6487661_EX-10.10_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_ImpresseCorp_20000322_S-1A_EX-10.11_5199234_EX-10.11_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_IntegrityMediaInc_20010329_10-K405_EX-10.17_2373875_EX-10.17_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_LeadersonlineInc_20000427_S-1A_EX-10.8_4991089_EX-10.8_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_MphaseTechnologiesInc_20030911_10-K_EX-10.15_1560667_EX-10.15_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_MusclepharmCorp_20170208_10-KA_EX-10.38_9893581_EX-10.38_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_NeoformaInc_19991202_S-1A_EX-10.26_5224521_EX-10.26_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_PaperexchangeComInc_20000322_S-1A_EX-10.4_5202103_EX-10.4_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement3.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_RaeSystemsInc_20001114_10-Q_EX-10.57_2631790_EX-10.57_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_RandWorldwideInc_20010402_8-KA_EX-10.2_2102464_EX-10.2_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_TheglobeComInc_19990503_S-1A_EX-10.20_5416126_EX-10.20_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Co_Branding\highlighted_TomOnlineInc_20060501_20-F_EX-4.46_749700_EX-4.46_Co-Branding Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_AimmuneTherapeuticsInc_20200205_8-K_EX-10.3_11967170_EX-10.3_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_ArcaUsTreasuryFund_20200207_N-2_EX-99.K5_11971930_EX-99.K5_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_ClickstreamCorp_20200330_1-A_EX1A-6 MAT CTRCT_12089935_EX1A-6 MAT CTRCT_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_CnsPharmaceuticalsInc_20200326_8-K_EX-10.1_12079626_EX-10.1_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_ConformisInc_20191101_10-Q_EX-10.6_11861402_EX-10.6_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_ElPolloLocoHoldingsInc_20200306_10-K_EX-10.16_12041700_EX-10.16_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_EmeraldHealthBioceuticalsInc_20200218_1-A_EX1A-6 MAT CTRCT_11987205_EX1A-6 MAT CTRCT_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_EtonPharmaceuticalsInc_20191114_10-Q_EX-10.1_11893941_EX-10.1_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_FuelcellEnergyInc_20191106_8-K_EX-10.1_11868007_EX-10.1_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_HarpoonTherapeuticsInc_20200312_10-K_EX-10.18_12051356_EX-10.18_Development Agreement_Option Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_HfEnterprisesInc_20191223_S-1_EX-10.22_11931299_EX-10.22_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_IbioInc_20200313_8-K_EX-10.1_12052678_EX-10.1_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_NlsPharmaceuticsLtd_20200228_F-1_EX-10.14_12029046_EX-10.14_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_PelicanDeliversInc_20200211_S-1_EX-10.3_11975895_EX-10.3_Development Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_PelicanDeliversInc_20200211_S-1_EX-10.3_11975895_EX-10.3_Development Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_PhasebioPharmaceuticalsInc_20200330_10-K_EX-10.21_12086810_EX-10.21_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_ReedsInc_20191113_10-Q_EX-10.4_11888303_EX-10.4_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_RevolutionMedicinesInc_20200117_S-1_EX-10.1_11948417_EX-10.1_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_RitterPharmaceuticalsInc_20200313_S-4A_EX-10.54_12055220_EX-10.54_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Development\highlighted_VgrabCommunicationsInc_20200129_10-K_EX-10.33_11958828_EX-10.33_Development Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_FuseMedicalInc_20190321_10-K_EX-10.43_11575454_EX-10.43_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_GentechHoldingsInc_20190808_1-A_EX1A-6 MAT CTRCT_11776814_EX1A-6 MAT CTRCT_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_ImineCorp_20180725_S-1_EX-10.5_11275970_EX-10.5_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_InnerscopeHearingTechnologiesInc_20181109_8-K_EX-10.6_11419704_EX-10.6_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_PrecheckHealthServicesInc_20200320_8-K_EX-99.2_12070169_EX-99.2_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_ScansourceInc_20190509_10-Q_EX-10.2_11661422_EX-10.2_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_ScansourceInc_20190822_10-K_EX-10.38_11793958_EX-10.38_Distributor Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_ScansourceInc_20190822_10-K_EX-10.38_11793958_EX-10.38_Distributor Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_ScansourceInc_20190822_10-K_EX-10.39_11793959_EX-10.39_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_SmartRxSystemsInc_20180914_1-A_EX1A-6 MAT CTRCT_11351705_EX1A-6 MAT CTRCT_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_StaarSurgicalCompany_20180801_10-Q_EX-10.37_11289449_EX-10.37_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_WaterNowInc_20191120_10-Q_EX-10.12_11900227_EX-10.12_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Distributor\highlighted_ZogenixInc_20190509_10-Q_EX-10.2_11663313_EX-10.2_Distributor Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_BerkshireHillsBancorpInc_20120809_10-Q_EX-10.16_7708169_EX-10.16_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_BizzingoInc_20120322_8-K_EX-10.17_7504499_EX-10.17_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_EcoScienceSolutionsInc_20171117_8-K_EX-10.1_10956472_EX-10.1_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_GridironBionutrientsInc_20171206_8-K_EX-10.1_10972555_EX-10.1_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_GridironBionutrientsInc_20171206_8-K_EX-10.2_10972556_EX-10.2_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_LegacyEducationAllianceInc_20141110_8-K_EX-10.9_8828866_EX-10.9_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_LifewayFoodsInc_20160316_10-K_EX-10.24_9489766_EX-10.24_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_NakedBrandGroupInc_20150731_POS AM (on S-1)_EX-10.75_9196027_EX-10.75_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_PapaJohnsInternationalInc_20190617_8-K_EX-10.1_11707365_EX-10.1_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_PerformanceSportsBrandsInc_20110909_S-1_EX-10.10_7220214_EX-10.10_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_PharmagenInc_20120803_8-KA_EX-10.1_7693204_EX-10.1_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_PrudentialBancorpInc_20170606_8-K_EX-10.4_10474434_EX-10.4_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Endorsement\highlighted_ThriventVariableInsuranceAccountB_20190701_N-6_EX-99.D(IV)_11720968_EX-99.D(IV)_Endorsement Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Franchise\highlighted_PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_Franchise Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Franchise\highlighted_PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_Franchise Agreement3.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Franchise\highlighted_RgcResourcesInc_20151216_8-K_EX-10.3_9372751_EX-10.3_Franchise Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Franchise\highlighted_SimplicityEsportsGamingCompany_20181130_8-K_EX-10.1_11444071_EX-10.1_Franchise Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Franchise\highlighted_SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Franchise\highlighted_SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Franchise\highlighted_SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement3.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Franchise\highlighted_SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement4.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Hosting\highlighted_Freecook_20180605_S-1_EX-10.3_11233807_EX-10.3_Hosting Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Hosting\highlighted_PareteumCorp_20081001_8-K_EX-99.1_2654808_EX-99.1_Hosting Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Hosting\highlighted_QuantumGroupIncFl_20090120_8-K_EX-99.2_3672910_EX-99.2_Hosting Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Hosting\highlighted_VitalibisInc_20180316_8-K_EX-10.2_11100168_EX-10.2_Hosting Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\IP\highlighted_ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\IP\highlighted_CerenceInc_20191002_8-K_EX-10.4_11827494_EX-10.4_Intellectual Property Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\IP\highlighted_GarrettMotionInc_20181001_8-K_EX-2.4_11364532_EX-2.4_Intellectual Property Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\IP\highlighted_RareElementResourcesLtd_20171019_SC 13D_EX-99.4_10897534_EX-99.4_Intellectual Property Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_AlliedEsportsEntertainmentInc_20190815_8-K_EX-10.19_11788293_EX-10.19_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_ArconicRolledProductsCorp_20191217_10-12B_EX-2.7_11923804_EX-2.7_Trademark License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_ArtaraTherapeuticsInc_20200110_8-K_EX-10.5_11943350_EX-10.5_License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_ChinaRealEstateInformationCorp_20090929_F-1_EX-10.32_4771615_EX-10.32_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_DataCallTechnologies_20060918_SB-2A_EX-10.9_944510_EX-10.9_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_EuromediaHoldingsCorp_20070215_10SB12G_EX-10.B(01)_525118_EX-10.B(01)_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_FulucaiProductionsLtd_20131223_10-Q_EX-10.9_8368347_EX-10.9_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_GlobalTechnologiesGroupInc_20050928_10KSB_EX-10.9_4148808_EX-10.9_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_GluMobileInc_20070319_S-1A_EX-10.09_436630_EX-10.09_Content License Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_GluMobileInc_20070319_S-1A_EX-10.09_436630_EX-10.09_Content License Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_GluMobileInc_20070319_S-1A_EX-10.09_436630_EX-10.09_Content License Agreement3.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_GluMobileInc_20070319_S-1A_EX-10.09_436630_EX-10.09_Content License Agreement4.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_GopageCorp_20140221_10-K_EX-10.1_8432966_EX-10.1_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_GpaqAcquisitionHoldingsInc_20200123_S-4A_EX-10.6_11951677_EX-10.6_License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_HertzGroupRealtyTrustInc_20190920_S-11A_EX-10.8_11816941_EX-10.8_Trademark License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_IdeanomicsInc_20151124_8-K_EX-10.2_9354744_EX-10.2_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_IdeanomicsInc_20160330_10-K_EX-10.26_9512211_EX-10.26_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_LejuHoldingsLtd_20140121_DRS (on F-1)_EX-10.26_8473102_EX-10.26_Content License Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_LejuHoldingsLtd_20140121_DRS (on F-1)_EX-10.26_8473102_EX-10.26_Content License Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_MidwestEnergyEmissionsCorp_20080604_8-K_EX-10.2_3093976_EX-10.2_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_MorganStanleyDirectLendingFund_20191119_10-12GA_EX-10.5_11898508_EX-10.5_Trademark License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_NmfSlfIInc_20200115_10-12GA_EX-10.5_11946987_EX-10.5_Trademark License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_PacificapEntertainmentHoldingsInc_20051115_8-KA_EX-1.01_4300894_EX-1.01_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_PalmerSquareCapitalBdcInc_20200116_10-12GA_EX-10.6_11949289_EX-10.6_Trademark License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_PhoenixNewMediaLtd_20110421_F-1_EX-10.17_6958322_EX-10.17_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_PlayboyEnterprisesInc_20090220_10-QA_EX-10.2_4091580_EX-10.2_Content License Agreement_ Marketing Agreement_ Sales-Purchase Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_PlayboyEnterprisesInc_20090220_10-QA_EX-10.2_4091580_EX-10.2_Content License Agreement_ Marketing Agreement_ Sales-Purchase Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_RemarkHoldingsInc_20081114_10-Q_EX-10.24_2895649_EX-10.24_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_WatchitMediaInc_20061201_8-K_EX-10.1_4148672_EX-10.1_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_WebmdHealthCorp_20050908_S-1A_EX-10.7_1027007_EX-10.7_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\License_Agreements\highlighted_XinhuaSportsEntertainmentLtd_20070221_F-1_EX-99.4_645553_EX-99.4_Content License Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_AtnInternationalInc_20191108_10-Q_EX-10.1_11878541_EX-10.1_Maintenance Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_Maintenance Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_Maintenance Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_BloomEnergyCorp_20180321_DRSA (on S-1)_EX-10_11240356_EX-10_Maintenance Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_CardlyticsInc_20180112_S-1_EX-10.16_11002987_EX-10.16_Maintenance Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_CardlyticsInc_20180112_S-1_EX-10.16_11002987_EX-10.16_Maintenance Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_CardlyticsInc_20180112_S-1_EX-10.16_11002987_EX-10.16_Maintenance Agreement3.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_CardlyticsInc_20180112_S-1_EX-10.16_11002987_EX-10.16_Maintenance Agreement4.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Maintenance\highlighted_HerImports_20161018_8-KA_EX-10.14_9765707_EX-10.14_Maintenance Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Manufacturing\highlighted_BellringBrandsInc_20190920_S-1_EX-10.12_11817081_EX-10.12_Manufacturing Agreement1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Manufacturing\highlighted_BellringBrandsInc_20190920_S-1_EX-10.12_11817081_EX-10.12_Manufacturing Agreement2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Manufacturing\highlighted_BellringBrandsInc_20190920_S-1_EX-10.12_11817081_EX-10.12_Manufacturing Agreement3.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Manufacturing\highlighted_BellringBrandsInc_20190920_S-1_EX-10.12_11817081_EX-10.12_Manufacturing Agreement4.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Manufacturing\highlighted_InmodeLtd_20190729_F-1A_EX-10.9_11743243_EX-10.9_Manufacturing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Manufacturing\highlighted_KitovPharmaLtd_20190326_20-F_EX-4.15_11584449_EX-4.15_Manufacturing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Manufacturing\highlighted_NeuroboPharmaceuticalsInc_20190903_S-4_EX-10.36_11802165_EX-10.36_Manufacturing Agreement_ Supply Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Manufacturing\highlighted_UpjohnInc_20200121_10-12G_EX-2.6_11948692_EX-2.6_Manufacturing Agreement_ Supply Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Marketing\highlighted_AudibleInc_20001113_10-Q_EX-10.32_2599586_EX-10.32_Co-Branding Agreement_ Marketing Agreement_ Investment Distribution Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Marketing\highlighted_CcRealEstateIncomeFundadv_20181205_POS 8C_EX-99.(H)(3)_11447739_EX-99.(H)(3)_Marketing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Marketing\highlighted_EmmisCommunicationsCorp_20191125_8-K_EX-10.6_11906433_EX-10.6_Marketing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Marketing\highlighted_TodosMedicalLtd_20190328_20-F_EX-4.10_11587157_EX-4.10_Marketing Agreement_ Reseller Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Marketing\highlighted_VertexEnergyInc_20200113_8-K_EX-10.1_11943624_EX-10.1_Marketing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Marketing\highlighted_XpresspaGroupInc_20190401_10-K_EX-10.28_11599457_EX-10.28_Marketing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Outsourcing\highlighted_FerroglobePlc_20150624_F-4A_EX-10.20_9154746_EX-10.20_Outsourcing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Outsourcing\highlighted_ImperialGardenResortInc_20161028_DRS (on F-1)_EX-10.13_9963189_EX-10.13_Outsourcing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Outsourcing\highlighted_ParatekPharmaceuticalsInc_20170505_10-KA_EX-10.29_10323872_EX-10.29_Outsourcing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Outsourcing\highlighted_PhotronicsInc_20171219_10-QA_EX-10.28_10982650_EX-10.28_Outsourcing Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Promotion\highlighted_DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Promotion\highlighted_ExactSciencesCorp_20180822_8-K_EX-10.1_11331629_EX-10.1_Promotion Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Promotion\highlighted_SigaTechnologiesInc_20190603_8-K_EX-10.1_11695818_EX-10.1_Promotion Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Promotion\highlighted_VnueInc_20150914_8-K_EX-10.1_9259571_EX-10.1_Promotion Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Reseller\highlighted_BravatekSolutionsInc_20170418_8-K_EX-10.1_10205739_EX-10.1_Reseller Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Reseller\highlighted_EhaveInc_20190515_20-F_EX-4.44_11678816_EX-4.44_License Agreement_ Reseller Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Reseller\highlighted_HealthcareIntegratedTechnologiesInc_20190812_8-K_EX-10.1_11776966_EX-10.1_Reseller Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Reseller\highlighted_IpassInc_20181203_8-K_EX-99.1_11445874_EX-99.1_Reseller Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Reseller\highlighted_SalesforcecomInc_20171122_10-Q_EX-10.1_10961535_EX-10.1_Reseller Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Service\highlighted_GpaqAcquisitionHoldingsInc_20200123_S-4A_EX-10.8_11951679_EX-10.8_Service Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Service\highlighted_IntegrityFunds_20200121_485BPOS_EX-99.E UNDR CONTR_11948727_EX-99.E UNDR CONTR_Service Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Service\highlighted_ReynoldsConsumerProductsInc_20200121_S-1A_EX-10.22_11948918_EX-10.22_Service Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Service\highlighted_VerizonAbsLlc_20200123_8-K_EX-10.4_11952335_EX-10.4_Service Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Sponsorship\highlighted_AlliedEsportsEntertainmentInc_20190815_8-K_EX-10.34_11788308_EX-10.34_Sponsorship Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Sponsorship\highlighted_ArcGroupInc_20171211_8-K_EX-10.1_10976103_EX-10.1_Sponsorship Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Sponsorship\highlighted_EcoScienceSolutionsInc_20180406_8-K_EX-10.1_11135398_EX-10.1_Sponsorship Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Sponsorship\highlighted_FreezeTagInc_20180411_8-K_EX-10.1_11139603_EX-10.1_Sponsorship Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Supply\highlighted_AgapeAtpCorp_20191202_10-KA_EX-10.1_11911128_EX-10.1_Supply Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Supply\highlighted_LohaCompanyltd_20191209_F-1_EX-10.16_11917878_EX-10.16_Supply Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Supply\highlighted_ReynoldsConsumerProductsInc_20191115_S-1_EX-10.18_11896469_EX-10.18_Supply Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Supply\highlighted_WestPharmaceuticalServicesInc_20200116_8-K_EX-10.1_11947529_EX-10.1_Supply Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Transportation\highlighted_PenntexMidstreamPartnersLp_20150416_S-1A_EX-10.4_9042833_EX-10.4_Transportation Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Transportation\highlighted_RangeResourcesLouisianaInc_20150417_8-K_EX-10.5_9045501_EX-10.5_Transportation Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Transportation\highlighted_TcPipelinesLp_20160226_10-K_EX-99.12_9454048_EX-99.12_Transportation Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_I\Transportation\highlighted_ZtoExpressCaymanInc_20160930_F-1_EX-10.10_9752871_EX-10.10_Transportation Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Agency Agreements\highlighted_OLDAPIWIND-DOWNLTD_01_08_2016-EX-1.3-AGENCY AGREEMENT1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Agency Agreements\highlighted_OLDAPIWIND-DOWNLTD_01_08_2016-EX-1.3-AGENCY AGREEMENT2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Development\highlighted_BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1).pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Development\highlighted_BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT - First Amendment.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Distributor\highlighted_NETGEAR,INC_04_21_2003-EX-10.16- AMENDMENT #2 TO THE DISTRIBUTION AGREEMENT.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Distributor\highlighted_NETGEAR,INC_04_21_2003-EX-10.16-AMENDMENT TO THE DISTRIBUTOR AGREEMENT BETWEEN INGRAM MICRO AND NETGEAR-.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Distributor\highlighted_NETGEAR,INC_04_21_2003-EX-10.16-DISTRIBUTOR AGREEMENT.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Endorsement\highlighted_WOMENSGOLFUNLIMITEDINC_03_29_2000-EX-10.13-ENDORSEMENT AGREEMENT - Intellectual Property Rights                 Confidentiality and Non-Use Obligations Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Hosting\highlighted_HEALTHGATEDATACORP_11_24_1999-EX-10.1-HOSTING AND MANAGEMENT AGREEMENT (1).pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Hosting\highlighted_HEALTHGATEDATACORP_11_24_1999-EX-10.1-HOSTING AND MANAGEMENT AGREEMENT - Escrow Agreement.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Service\highlighted_FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Service\highlighted_FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_AMENDMENT.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Service\highlighted_FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_POWEROF.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Service\highlighted_FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_SECONDAMENDMENT.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Service\highlighted_KUBIENT,INC_07_02_2020-EX-10.14-MASTER SERVICES AGREEMENT_Part1.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_II\Service\highlighted_KUBIENT,INC_07_02_2020-EX-10.14-MASTER SERVICES AGREEMENT_Part2.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_III\Distributor\highlighted_NEONSYSTEMSINC_03_01_1999-EX-10.5-DISTRIBUTOR AGREEMENT_Amendment.pdf
# Removed file: C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf\Part_III\Distributor\highlighted_NEONSYSTEMSINC_03_01_1999-EX-10.5-DISTRIBUTOR AGREEMENT_New.pdf
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import fitz  # PyMuPDF  
import os  
  
def parse_pdfs(pdf_dir):  
    parsed_texts = {}  
      
    # Walk through the directory and subdirectories  
    for root, dirs, files in os.walk(pdf_dir):  
        for pdf_file in files:  
            if pdf_file.endswith('.pdf'):  
                pdf_path = os.path.join(root, pdf_file)  
                doc = fitz.open(pdf_path)  
                text = ""  
                for page in doc:  
                    text += page.get_text()  
                parsed_texts[pdf_path] = text  # Store the full path as the key  
  
    return parsed_texts  
  
pdf_dir = 'C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf'  
parsed_texts = parse_pdfs(pdf_dir)

# %%
import spacy  
  
# Load pre-trained model  
nlp = spacy.load("en_core_web_sm")  
  
def extract_entities(text):  
    doc = nlp(text)  
    entities = {}  
    for ent in doc.ents:  
        entities[ent.label_] = ent.text  
    return entities  
  
# Extract entities from the parsed texts  
entities = {file: extract_entities(text) for file, text in parsed_texts.items()}  
entities

# %%
entities
# Out:
# {'CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.pdf': {'DATE': '8/10/2007',
#   'ORG': 'Continental',
#   'GPE': 'S-1',
#   'CARDINAL': '23',
#   'WORK_OF_ART': 'Universal\xa0Movies',
#   'PERSON': 'CREDITCARDS.COM',
#   'ORDINAL': 'first',
#   'MONEY': '55.00',
#   'NORP': 'Continental',
#   'PRODUCT': 'Marathon\xa0Marathon',
#   'FAC': 'Park\xa0Avenue',
#   'LOC': 'Marina',
#   'TIME': 'last\xa0minute'},
#  'CybergyHoldingsInc_20140520_10-Q_EX-10.27_8605784_EX-10.27_Affiliate Agreement.pdf': {'CARDINAL': '10',
#   'ORG': 'Technology',
#   'DATE': '5/20/2014',
#   'GPE': 'Company',
#   'WORK_OF_ART': 'Service\xa0Fee',
#   'PERSON': 'MA',
#   'ORDINAL': 'first',
#   'PRODUCT': 'Clients',
#   'NORP': 'Company',
#   'LAW': 'Section 1',
#   'MONEY': '15,000.00',
#   'PERCENT': '15%',
#   'LANGUAGE': 'English'},
#  'DigitalCinemaDestinationsCorp_20111220_S-1_EX-10.10_7346719_EX-10.10_Affiliate Agreement.pdf': {'ORG': 'DIGITAL CINEMA DESTINATIONS CORP.',
#   'DATE': 'January 1, 2011',
#   'GPE': 'Bloomfield',
#   'WORK_OF_ART': 'Inventory For Lobby Promotions \n\xa0 \nThe Inventory of Lobby Promotions',
#   'ORDINAL': 'third',
#   'CARDINAL': '06002',
#   'LAW': 'the Beverage Agreement',
#   'PERSON': 'S-1',
#   'PRODUCT': 'Theatre',
#   'QUANTITY': '35 mm',
#   'LOC': 'North Avenue West',
#   'TIME': '30) seconds',
#   'FAC': 'Park Avenue',
#   'MONEY': 'less than $',
#   'PERCENT': '5%',
#   'EVENT': 'this Subsection 5.3(b',
#   'NORP': 'Infringements'},
#  'LinkPlusCorp_20050802_8-K_EX-10_3240252_EX-10_Affiliate Agreement.pdf': {'CARDINAL': '8',
#   'DATE': '21046',
#   'LOC': 'the Effective Date',
#   'GPE': 'Axiometric',
#   'ORG': 'LINK PLUS CORP',
#   'QUANTITY': '7.5      ',
#   'PERSON': 'AMR Product Suite',
#   'NORP': 'Datamatic',
#   'WORK_OF_ART': 'Royalty',
#   'LAW': 'section 3 above;',
#   'PERCENT': '3.0%',
#   'ORDINAL': 'first',
#   'FAC': '6996 Columbia Gateway Drive'},
#  'SouthernStarEnergyInc_20051202_SB-2A_EX-9_801890_EX-9_Affiliate Agreement.pdf': {'CARDINAL': '3',
#   'ORG': 'SOUTHERN STAR ENERGY INC.',
#   'GPE': 'Germany',
#   'PERSON': 'Software',
#   'WORK_OF_ART': 'Advertising Cost Compensation',
#   'DATE': '12/2/2005',
#   'NORP': 'non-German',
#   'PRODUCT': '9 Final',
#   'PERCENT': '2%',
#   'ORDINAL': 'third'},
#  'SteelVaultCorp_20081224_10-K_EX-10.16_3074935_EX-10.16_Affiliate Agreement.pdf': {'CARDINAL': '10',
#   'DATE': 'daily',
#   'EVENT': 'the “Effective Date',
#   'ORG': 'VAULT CORP',
#   'GPE': '12/24/2008',
#   'WORK_OF_ART': 'Marketing Affiliate',
#   'PERSON': 'Ivan Posniak',
#   'ORDINAL': 'third',
#   'PERCENT': '25%',
#   'MONEY': 'less than $35.00',
#   'PRODUCT': 'Agreement',
#   'LAW': 'the Fair Debt Collection Practices Act',
#   'TIME': 'overnight',
#   'LOC': 'the Effective Date',
#   'NORP': 'Experian'},
#  'TubeMediaCorp_20060310_8-K_EX-10.1_513921_EX-10.1_Affiliate Agreement.pdf': {'EVENT': 'AFFILIATION',
#   'DATE': '3/10/2006',
#   'WORK_OF_ART': 'Incremental\xa0Copyright\xa0Cost',
#   'GPE': 'Nielsen',
#   'FAC': 'Miami-Ft',
#   'ORG': 'TUBE MEDIA CORP.',
#   'CARDINAL': '8',
#   'ORDINAL': 'third',
#   'PERSON': 'Nielsen',
#   'TIME': 'overnight',
#   'PRODUCT': '•\nDe',
#   'NORP': 'AMC-3',
#   'MONEY': '1,000,000',
#   'LOC': 'Arctic',
#   'QUANTITY': '150\xa0Feet',
#   'PERCENT': '15%'},
#  'UnionDentalHoldingsInc_20050204_8-KA_EX-10_3345577_EX-10_Affiliate Agreement.pdf': {'CARDINAL': '8',
#   'DATE': '2/4/2005',
#   'WORK_OF_ART': 'Responsibilities of the Parties',
#   'PERSON': 'George D. Green',
#   'ORG': 'WHEREOF',
#   'GPE': 'Florida',
#   'EVENT': 'Parties',
#   'PRODUCT': 'UDC',
#   'TIME': 'normal business hours',
#   'LOC': 'the Effective Date',
#   'NORP': 'WITNESS'},
#  'UsioInc_20040428_SB-2_EX-10.11_1723988_EX-10.11_Affiliate Agreement 2.pdf': {'CARDINAL': '4/28/2004',
#   'ORG': 'USIO, INC.',
#   'DATE': 'the year',
#   'PERSON': 'McLean',
#   'GPE': 'Addendums',
#   'PRODUCT': 'Affiliate\n     Network',
#   'WORK_OF_ART': 'Merchant',
#   'LAW': 'ARTICLE VIII',
#   'NORP': 'American',
#   'QUANTITY': '8.03     AMENDMENT',
#   'TIME': 'normal business hours',
#   'ORDINAL': '25th',
#   'FAC': 'Exit Fee',
#   'MONEY': '500'},
#  '2ThemartComInc_19990826_10-12G_EX-10.10_6700288_EX-10.10_Co-Branding Agreement_ Agency Agreement.pdf': {'ORG': 'By:/s/Dominic J. Magliarditi                By:/s',
#   'DATE': '8/26/1999',
#   'EVENT': 'the "Effective Date',
#   'PERSON': 'Sanjay Bajaj\nTitle',
#   'CARDINAL': '10-12',
#   'GPE': 'Palo Alto',
#   'ORDINAL': '7th',
#   'WORK_OF_ART': 'Confidential Information',
#   'PRODUCT': 'Agreement',
#   'LOC': 'the Launch Date',
#   'PERCENT': '10%',
#   'MONEY': '215',
#   'LAW': 'Section 9',
#   'TIME': 'overnight'},
#  'DeltathreeInc_19991102_S-1A_EX-10.19_6227850_EX-10.19_Co-Branding Agreement_ Service Agreement.pdf': {'ORG': 'S-1/A',
#   'DATE': '11/2/1999',
#   'WORK_OF_ART': 'Entire Agreement',
#   'GPE': 'New York',
#   'PERSON': 'Amos Sela',
#   'LOC': 'the Southern District',
#   'CARDINAL': '10',
#   'PRODUCT': 'Calling Card',
#   'PERCENT': '50%',
#   'LAW': 'Section 9.14',
#   'FAC': 'Park Avenue',
#   'ORDINAL': 'third'},
#  'EbixInc_20010515_10-Q_EX-10.3_4049767_EX-10.3_Co-Branding Agreement.pdf': {'CARDINAL': '10',
#   'ORG': 'EBIX INC',
#   'WORK_OF_ART': 'Signature:                               Signature:\n          --------------------------',
#   'DATE': '1200',
#   'GPE': 'Schuamberg',
#   'FAC': 'the About Network',
#   'PRODUCT': 'Agreement',
#   'LAW': 'Section 12',
#   'ORDINAL': 'third',
#   'PERCENT': '99.0%',
#   'PERSON': 'Richard',
#   'NORP': 'D.',
#   'LOC': 'the Effective Date',
#   'EVENT': 'the "Effective Date',
#   'MONEY': 'Excite@Home; AskJeeves; GOTO;',
#   'TIME': 'overnight'},
#  'EdietsComInc_20001030_10QSB_EX-10.4_2606646_EX-10.4_Co-Branding Agreement.pdf': {'CARDINAL': '3',
#   'ORG': 'Women.com',
#   'DATE': '10QSB',
#   'EVENT': 'Effective Date-Production',
#   'GPE': 'Gambling\n  ',
#   'WORK_OF_ART': 'Total Payment',
#   'FAC': 'the Diet Center',
#   'LOC': 'the Launch Date                                                 ',
#   'PERSON': 'Healthy Ideas',
#   'ORDINAL': 'third',
#   'LAW': 'The "Anchor Sponsorship',
#   'MONEY': '4,000,000',
#   'PERCENT': '20%',
#   'PRODUCT': 'Exclusive',
#   'TIME': '72) hours',
#   'QUANTITY': '15.3 Governing Law',
#   'NORP': 'Letter'},
#  'EmbarkComInc_19991008_S-1A_EX-10.10_6487661_EX-10.10_Co-Branding Agreement.pdf': {'CARDINAL': '12',
#   'ORG': 'S-1/A',
#   'WORK_OF_ART': 'Going to School',
#   'DATE': '10/8/1999',
#   'GPE': 'Sponsor',
#   'PERSON': 'Snap',
#   'EVENT': 'this Section 7',
#   'LAW': 'Rule 406',
#   'PRODUCT': 'MileagePlus\nSource',
#   'ORDINAL': 'first',
#   'LOC': 'the Exclusive\nCategory',
#   'TIME': '8.8   INTEGRATION'},
#  'HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement.pdf': {'CARDINAL': '2',
#   'ORG': 'S-1/A',
#   'DATE': '11/8/1999',
#   'GPE': 'Canada',
#   'FAC': 'CA                  Toronto',
#   'WORK_OF_ART': 'Powered By HealthCentral',
#   'PERSON': 'Less Hispanics',
#   'LOC': 'the Launch Date',
#   'LAW': 'SECTION 16',
#   'ORDINAL': 'third',
#   'NORP': 'Canadian',
#   'TIME': 'normal business hours',
#   'PRODUCT': 'Sympatico.ca',
#   'PERCENT': 'approximately 80%',
#   'EVENT': 'leap\nyears'},
#  'ImpresseCorp_20000322_S-1A_EX-10.11_5199234_EX-10.11_Co-Branding Agreement.pdf': {'WORK_OF_ART': 'TERMINATION',
#   'CARDINAL': '3/22/2000',
#   'ORG': 'FACSIMILES',
#   'DATE': 'VERTICALNET',
#   'GPE': 'Sunnyvale',
#   'FAC': 'CA 94087',
#   'PERSON': 'Siva Kumar',
#   'LOC': 'Eastern Time',
#   'PERCENT': '1%',
#   'LAW': 'DISCLAIMER OF WARRANTY',
#   'EVENT': 'a "Business Day',
#   'TIME': '3:00\np.m.',
#   'MONEY': 'at least $',
#   'PRODUCT': 'Agreement',
#   'ORDINAL': 'first',
#   'NORP': 'PROVIDED'},
#  'IntegrityMediaInc_20010329_10-K405_EX-10.17_2373875_EX-10.17_Co-Branding Agreement.pdf': {'CARDINAL': '10',
#   'ORG': 'INTEGRITY MEDIA INC',
#   'WORK_OF_ART': 'the Term of this Agreement',
#   'DATE': '3/29/2001',
#   'GPE': 'Tennessee',
#   'EVENT': 'the\n                  series',
#   'PERSON': 'Don Mayes',
#   'ORDINAL': 'third',
#   'PRODUCT': 'Trademarks',
#   'LAW': 'the "Songs 4 Worship"',
#   'NORP': 'Christian',
#   'MONEY': '.075',
#   'PERCENT': '7%',
#   'LOC': 'Indicates'},
#  'InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement.pdf': {'ORG': 'INVENDA CORP,',
#   'CARDINAL': '8/28/2000',
#   'DATE': 'within fifteen (15',
#   'WORK_OF_ART': 'the Term of this Agreement',
#   'FAC': 'Net Perceptions\n     Engage Technologies\n     Broadvision\n     Personify',
#   'GPE': 'Targeted',
#   'PERSON': 'Application Provider',
#   'LAW': 'Section 1.b',
#   'ORDINAL': 'First',
#   'NORP': 'Thematic',
#   'PRODUCT': 'Severity',
#   'LOC': 'the Effective Date',
#   'PERCENT': 'at least 80%',
#   'TIME': 'ten seconds',
#   'MONEY': '0.01'},
#  'LeadersonlineInc_20000427_S-1A_EX-10.8_4991089_EX-10.8_Co-Branding Agreement.pdf': {'CARDINAL': '4/27/2000',
#   'ORG': 'S-1/A',
#   'WORK_OF_ART': 'Notice',
#   'DATE': 'VERTICALNET',
#   'GPE': 'Irvine',
#   'FAC': 'Park Plaza\nSource:',
#   'PERSON': 'MICHAEL T. CHRISTY',
#   'PERCENT': '1%',
#   'LOC': 'Eastern Time',
#   'LAW': 'Amendment or Modification',
#   'ORDINAL': 'first',
#   'EVENT': 'Intellectual Property;',
#   'PRODUCT': 'Agreement',
#   'TIME': '3:00\np.m.',
#   'NORP': 'PROVIDED'},
#  'MphaseTechnologiesInc_20030911_10-K_EX-10.15_1560667_EX-10.15_Co-Branding Agreement.pdf': {'CARDINAL': '10',
#   'ORG': 'MPHASE TECHNOLOGIES INC',
#   'DATE': '9/11/2003',
#   'GPE': 'Murray Hill',
#   'FAC': 'Mountain Avenue',
#   'WORK_OF_ART': 'The Lucent co-branding',
#   'PERSON': 'Bob Cort',
#   'LOC': 'Goods',
#   'ORDINAL': 'third',
#   'NORP': 'Schedules',
#   'PRODUCT': 'Agreement'},
#  'MusclepharmCorp_20170208_10-KA_EX-10.38_9893581_EX-10.38_Co-Branding Agreement.pdf': {'DATE': '2/8/2017',
#   'WORK_OF_ART': 'Certified\xa0Mail',
#   'GPE': 'Colorado',
#   'ORG': 'MUSCLEPHARM CORP',
#   'PERSON': 'Arnold\xa0Schwarzenegger',
#   'CARDINAL': '10',
#   'ORDINAL': 'first',
#   'MONEY': '5,000,000',
#   'PRODUCT': 'Receipt',
#   'PERCENT': '5%',
#   'TIME': '2)\xa0hours',
#   'FAC': 'Broadway',
#   'NORP': 'INTELLECTUAL'},
#  'NeoformaInc_19991202_S-1A_EX-10.26_5224521_EX-10.26_Co-Branding Agreement.pdf': {'CARDINAL': '38',
#   'WORK_OF_ART': 'Bulk Upload Spreadsheet',
#   'ORG': 'S-1/A',
#   'GPE': 'Philadelphia',
#   'FAC': 'Biotechnology                  Electrophoresis                Electrophoresis\nBiotechnology                  Fermenters                     Fermenters\nBiotechnology',
#   'PERSON': 'DESCRIPTION       ',
#   'DATE': '12/2/1999',
#   'EVENT': 'VERTICALNET',
#   'PERCENT': '1%',
#   'LAW': 'START             DATE/TIME',
#   'ORDINAL': 'first',
#   'LOC': 'VerticalNet',
#   'NORP': 'American',
#   'PRODUCT': 'Excel',
#   'QUANTITY': '16.6 AMENDMENT OR',
#   'MONEY': '5',
#   'TIME': '04/08/99 15:00'},
#  'PaperexchangeComInc_20000322_S-1A_EX-10.4_5202103_EX-10.4_Co-Branding Agreement.pdf': {'CARDINAL': '3/22/2000',
#   'ORG': 'S-1/A',
#   'WORK_OF_ART': 'Bulk Upload Spreadsheet',
#   'DATE': '21',
#   'GPE': 'Approx',
#   'FAC': 'Career Center Request',
#   'PERSON': 'Seller',
#   'PERCENT': '1%',
#   'LAW': 'Section 8.3(k',
#   'ORDINAL': 'first',
#   'LOC': 'VerticalNet',
#   'NORP': 'FLD1',
#   'PRODUCT': 'Excel',
#   'EVENT': 'this Section 4',
#   'QUANTITY': '0.5 mL',
#   'MONEY': '5',
#   'TIME': '15:00'},
#  'PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement1.pdf': {'CARDINAL': '14',
#   'ORG': 'S-1/A',
#   'DATE': '7/21/1999',
#   'GPE': 'U.S.',
#   'PRODUCT': 'Hyperfeed',
#   'PERSON': 'Steven Malin',
#   'LAW': 'Section 13.B.',
#   'WORK_OF_ART': 'Law and Venue\n     This Agreement',
#   'NORP': 'D.',
#   'LOC': 'Installation',
#   'PERCENT': '12%',
#   'EVENT': 'ANNUAL',
#   'ORDINAL': 'third'},
#  'PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement2.pdf': {'LAW': 'Section 2',
#   'ORG': 'S-1/A',
#   'DATE': '7/21/1999',
#   'GPE': '7/21/1999',
#   'PERSON': 'Howard Meltzer',
#   'CARDINAL': '12/12/96'},
#  'PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement3.pdf': {'LAW': 'This Second Amendment',
#   'WORK_OF_ART': 'Amendment',
#   'DATE': '7/21/1999',
#   'ORG': 'S-1/A',
#   'CARDINAL': '5',
#   'GPE': 'New York',
#   'NORP': 'B.',
#   'PERSON': 'Robert Malin'},
#  'RaeSystemsInc_20001114_10-Q_EX-10.57_2631790_EX-10.57_Co-Branding Agreement.pdf': {'ORG': 'RAE SYSTEMS INC',
#   'DATE': 'any quarter',
#   'EVENT': 'OPERATION',
#   'GPE': 'Spinstore',
#   'MONEY': '6.50',
#   'PRODUCT': 'Solutions',
#   'CARDINAL': '11/14/2000',
#   'WORK_OF_ART': 'Impressions on the\nSpinRecords.com  Pages by Users',
#   'ORDINAL': 'third',
#   'QUANTITY': '11/14/2000\n     modules',
#   'PERSON': 'Advertising Revenues',
#   'PERCENT': '5%',
#   'LAW': 'Section 8.3',
#   'TIME': 'normal business hours',
#   'LOC': 'the Effective Date',
#   'FAC': 'Avenue              11440',
#   'NORP': 'Unique'},
#  'RandWorldwideInc_20010402_8-KA_EX-10.2_2102464_EX-10.2_Co-Branding Agreement.pdf': {'CARDINAL': '8',
#   'LAW': 'SECTION 11',
#   'ORG': 'RAND WORLDWIDE INC',
#   'WORK_OF_ART': 'the Laws of the State of New York',
#   'DATE': '4/2/2001',
#   'GPE': 'The City of Wilmington',
#   'NORP': 'Purchaser',
#   'PERCENT': '10.1 Term',
#   'PERSON': 'Thibault de Tersant',
#   'LOC': 'the Launch Date',
#   'ORDINAL': 'third',
#   'FAC': 'PlanetCAD',
#   'MONEY': '11.17 Assignment; Subcontracting; Third Party Beneficiaries',
#   'PRODUCT': 'Agreement',
#   'QUANTITY': '11.11 Applicable Law',
#   'EVENT': 'Action',
#   'LANGUAGE': 'English'},
#  'StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement.pdf': {'CARDINAL': '11/14/2000',
#   'ORG': 'STAMPS.COM INC',
#   'DATE': '4.7.4',
#   'EVENT': 'the Termination Period',
#   'GPE': 'FedEx',
#   'NORP': 'Company',
#   'LAW': 'a Subscription Agreement',
#   'WORK_OF_ART': 'Package',
#   'PERSON': 'Earliest Delivery Time',
#   'ORDINAL': 'First',
#   'PERCENT': 'thirty (',
#   'LOC': 'Edit Estimate',
#   'FAC': 'Rate Effective Dates',
#   'TIME': '48) hours',
#   'PRODUCT': 'Delivery Notification',
#   'MONEY': '5.2      Service Options'},
#  'TheglobeComInc_19990503_S-1A_EX-10.20_5416126_EX-10.20_Co-Branding Agreement.pdf': {'CARDINAL': '18',
#   'ORG': 'S-1/A',
#   'DATE': '10 days',
#   'EVENT': 'the "Effective Date',
#   'GPE': '5/3/1999',
#   'WORK_OF_ART': 'Privacy Policy',
#   'PERSON': 'Boxlot',
#   'ORDINAL': 'third',
#   'PERCENT': '5%',
#   'PRODUCT': 'Boxlot',
#   'LAW': 'the "Welcome',
#   'MONEY': '6',
#   'TIME': '72 hours',
#   'LOC': 'Net Revenues',
#   'QUANTITY': '6.3  Audit Rights',
#   'NORP': 'D.',
#   'FAC': 'Collectibles Mall\nBuck Auction'},
#  'TomOnlineInc_20060501_20-F_EX-4.46_749700_EX-4.46_Co-Branding Agreement.pdf': {'CARDINAL': '20-F',
#   'PERSON': 'Deliverables',
#   'GPE': 'PRC',
#   'ORG': 'TOM ONLINE INC',
#   'DATE': '5/1/2006',
#   'WORK_OF_ART': 'Effective\xa0Date',
#   'NORP': 'Oriental',
#   'ORDINAL': 'Third',
#   'FAC': 'Affiliate',
#   'PERCENT': '70%',
#   'PRODUCT': '•\n\xa0 Technology',
#   'TIME': 'hours',
#   'LANGUAGE': 'English',
#   'QUANTITY': '14.6\xa0Rights',
#   'LAW': 'Contributor’s\xa0Agreement'},
#  'AimmuneTherapeuticsInc_20200205_8-K_EX-10.3_11967170_EX-10.3_Development Agreement.pdf': {'CARDINAL': '2/5/2020',
#   'ORG': 'Canale Communications',
#   'PERSON': 'AIMMUNE THERAPEUTICS',
#   'DATE': '1995',
#   'LAW': 'Article and Section in this Agreement',
#   'WORK_OF_ART': 'Ph.D.',
#   'GPE': 'M.D.',
#   'PRODUCT': 'Form 10-K',
#   'PERCENT': '14.6 Survival',
#   'MONEY': '$385 million',
#   'EVENT': 'Aimmune',
#   'LOC': 'Europe',
#   'NORP': 'XNCR',
#   'ORDINAL': 'third',
#   'FAC': 'XmAb®',
#   'TIME': '8:01 am',
#   'QUANTITY': '15.3 Force Majeure',
#   'LANGUAGE': 'English'},
#  'ArcaUsTreasuryFund_20200207_N-2_EX-99.K5_11971930_EX-99.K5_Development Agreement.pdf': {'ORG': 'ARCA U.S. TREASURY FUND',
#   'PERSON': 'N-2',
#   'DATE': '2/7/2020',
#   'GPE': 'ERC-1404',
#   'PRODUCT': 'Agreement',
#   'WORK_OF_ART': 'Agreement',
#   'EVENT': 'the "Advisory Agreement");',
#   'CARDINAL': '5',
#   'LAW': 'the Investment Fund Act',
#   'TIME': 'normal\nbusiness hours',
#   'ORDINAL': 'first',
#   'PERCENT': '0.20%',
#   'FAC': 'the Blockchain Administrator'},
#  'ClickstreamCorp_20200330_1-A_EX1A-6 MAT CTRCT_12089935_EX1A-6 MAT CTRCT_Development Agreement.pdf': {'CARDINAL': '3/30/2020',
#   'ORG': 'CLICKSTREAM CORP',
#   'DATE': 'Week 20',
#   'WORK_OF_ART': 'Renew Notice',
#   'PRODUCT': 'InfinixSoft Global',
#   'GPE': 'CLIENT',
#   'MONEY': '90,000.-',
#   'FAC': 'CA 90067',
#   'PERSON': 'Ivan Alejandro Saroka',
#   'LOC': 'the Termination Date',
#   'LAW': 'the Force Majeure Event',
#   'ORDINAL': 'Second',
#   'TIME': 'around 20 seconds',
#   'NORP': 'Integrated',
#   'PERCENT': '90%'},
#  'CnsPharmaceuticalsInc_20200326_8-K_EX-10.1_12079626_EX-10.1_Development Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'INC.',
#   'DATE': '3/26/2020',
#   'GPE': 'o.o.',
#   'LOC': 'West Loop South',
#   'NORP': 'Polish',
#   'PERSON': 'Mariusz Olejniczak',
#   'LAW': 'The Article and Section captions',
#   'WORK_OF_ART': 'FCPA',
#   'MONEY': '$ or “dollars',
#   'PRODUCT': 'Agreement',
#   'PERCENT': '50%',
#   'ORDINAL': 'first',
#   'FAC': 'FCPA'},
#  'CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement.pdf': {'CARDINAL': '10',
#   'ORG': 'Regulation S-K',
#   'PERSON': 'Item',
#   'DATE': '2/27/2020',
#   'WORK_OF_ART': 'Contents of Commercialization Plan for Planned Activities\nOmitted',
#   'FAC': 'Lanfear\nDate',
#   'GPE': 'US',
#   'PRODUCT': 'Annex 2',
#   'LOC': 'the Effective Date',
#   'LAW': 'Section 4.6',
#   'PERCENT': '100%',
#   'NORP': 'Manufacturing',
#   'ORDINAL': 'Third',
#   'LANGUAGE': 'English',
#   'MONEY': '5,000,000',
#   'EVENT': 'Intellectual Property Rights or',
#   'TIME': 'overnight'},
#  'ConformisInc_20191101_10-Q_EX-10.6_11861402_EX-10.6_Development Agreement.pdf': {'ORG': 'CONFORMIS INC',
#   'LAW': 'this Development Agreement',
#   'WORK_OF_ART': 'Signature Page to Development Agreement',
#   'DATE': '11/1/2019',
#   'GPE': 'New York',
#   'CARDINAL': '10',
#   'FAC': 'State Street\n',
#   'PERSON': 'Mark A. Augusti',
#   'ORDINAL': 'first',
#   'LOC': 'the Effective Date',
#   'PRODUCT': 'Agreement',
#   'MONEY': '8.3 Surviving Rights/Obligations',
#   'PERCENT': '8.4 Return or',
#   'TIME': 'overnight',
#   'QUANTITY': '10.7 Governing Law'},
#  'ElPolloLocoHoldingsInc_20200306_10-K_EX-10.16_12041700_EX-10.16_Development Agreement.pdf': {'CARDINAL': '10',
#   'ORG': 'EL POLLO LOCO HOLDINGS, INC.',
#   'PERSON': 'Franchisor',
#   'DATE': '3/6/2020',
#   'LAW': 'SECTION 3',
#   'WORK_OF_ART': 'Competitive Business',
#   'GPE': 'Costa Mesa',
#   'FAC': 'CA 92626',
#   'PRODUCT': 'Agreement',
#   'LOC': 'El Pollo Loco',
#   'PERCENT': '20%',
#   'ORDINAL': 'first',
#   'MONEY': '30,000.00',
#   'EVENT': 'this Section 7',
#   'NORP': 'Mexican',
#   'TIME': 'overnight'},
#  'EmeraldHealthBioceuticalsInc_20200218_1-A_EX1A-6 MAT CTRCT_11987205_EX1A-6 MAT CTRCT_Development Agreement.pdf': {'LAW': 'ARTICLE 9 - GENERAL LEGAL',
#   'DATE': '2/18/2020',
#   'WORK_OF_ART': 'Effective Date',
#   'ORG': 'By:/s/Gaetano Morello',
#   'PERSON': 'Michael T. Murray',
#   'GPE': 'Arizona',
#   'CARDINAL': '1',
#   'NORP': 'Provide',
#   'MONEY': '2,500,000',
#   'PERCENT': 'no more than sixty (60) days after',
#   'PRODUCT': 'the Services Term',
#   'LOC': 'the Effective Date',
#   'ORDINAL': 'first'},
#  'EtonPharmaceuticalsInc_20191114_10-Q_EX-10.1_11893941_EX-10.1_Development Agreement.pdf': {'CARDINAL': '10',
#   'DATE': '2000',
#   'WORK_OF_ART': 'Effective Date',
#   'ORG': 'INC.',
#   'GPE': 'Piscataway',
#   'LOC': 'English Language',
#   'FAC': 'the Aucta Background Intellectual\nProperty',
#   'PERSON': 'Applicable Law',
#   'PERCENT': 'thirty (',
#   'LAW': 'Section 13.3.2',
#   'EVENT': 'the International Sale of Goods',
#   'NORP': 'English',
#   'PRODUCT': 'a Force Majeure\nEvent',
#   'ORDINAL': 'Third',
#   'MONEY': '11.4 Termination Other',
#   'TIME': 'overnight',
#   'QUANTITY': '7.4 Notice of Infringement',
#   'LANGUAGE': 'English'},
#  'FuelcellEnergyInc_20191106_8-K_EX-10.1_11868007_EX-10.1_Development Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'FUELCELL ENERGY INC',
#   'DATE': '11/6/2019',
#   'LAW': 'Article 4 (Disclosure, Confidentiality',
#   'GPE': 'Paragraph',
#   'PERSON': 'DELIVERABLES',
#   'LOC': 'the Effective Date',
#   'FAC': 'Page 29',
#   'WORK_OF_ART': 'ExxonMobil',
#   'ORDINAL': 'third',
#   'PRODUCT': 'Page 30',
#   'NORP': 'addressee',
#   'MONEY': '$50 billion',
#   'EVENT': 'Great Pasture Road\nDanbury',
#   'PERCENT': '50%',
#   'LANGUAGE': 'English',
#   'TIME': 'the hours'},
#  'HarpoonTherapeuticsInc_20200312_10-K_EX-10.18_12051356_EX-10.18_Development Agreement_Option Agreement.pdf': {'CARDINAL': '3/12/2020',
#   'ORG': 'Arbitration',
#   'DATE': '1986',
#   'LAW': 'Article, Section',
#   'PRODUCT': 'Counterparts; Facsimile Execution',
#   'PERSON': 'Schedule',
#   'WORK_OF_ART': 'Oyster Point Blvd',
#   'FAC': 'Hanover Street',
#   'EVENT': 'the License Option Exercise Closing Date',
#   'LANGUAGE': 'English',
#   'ORDINAL': 'first',
#   'GPE': 'the United States',
#   'PERCENT': '11.6',
#   'LOC': 'the Effective Date',
#   'NORP': 'English',
#   'MONEY': '50,000,000);',
#   'TIME': 'minutes'},
#  'HfEnterprisesInc_20191223_S-1_EX-10.22_11931299_EX-10.22_Development Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'HF ENTERPRISES INC.',
#   'DATE': '12/23/2019',
#   'EVENT': 'the “Effective Date',
#   'GPE': 'United States',
#   'PERSON': 'S-1',
#   'LAW': 'Samsung S7',
#   'MONEY': '23,000',
#   'LOC': 'the Effective Date',
#   'WORK_OF_ART': 'Road East',
#   'ORDINAL': 'first',
#   'NORP': 'Schedules',
#   'PRODUCT': 'AuthentiGuard Mobile App',
#   'TIME': 'normal business hours',
#   'FAC': 'Greatmany Centre'},
#  'IbioInc_20200313_8-K_EX-10.1_12052678_EX-10.1_Development Agreement.pdf': {'CARDINAL': '3/13/2020',
#   'PERSON': 'Kevin Yueju Wang\nTitle',
#   'WORK_OF_ART': 'Signature Page to Follow\nMaster Joint Development Agreement iBio CC-Pharming\nPage 10',
#   'ORG': 'CC-Pharming',
#   'DATE': 'August 8, 2018',
#   'GPE': 'China',
#   'FAC': 'Publication',
#   'ORDINAL': 'third',
#   'LOC': 'the Effective Date',
#   'PRODUCT': 'Agreement;',
#   'EVENT': 'U.S. Patent Law',
#   'LAW': 'Article 9.2'},
#  'LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement.pdf': {'CARDINAL': '3/30/2020',
#   'ORG': 'LEGACY EDUCATION ALLIANCE, INC.',
#   'GPE': 'Tarek',
#   'PERSON': 'Studio',
#   'DATE': 'Quarterly',
#   'EVENT': 'Nurturing/Event',
#   'PERCENT': '11.5 Sections',
#   'WORK_OF_ART': 'Approval for Legacy to Repost Tarek’s Social Media Content',
#   'LAW': 'Section 5',
#   'PRODUCT': 'H.264',
#   'ORDINAL': 'third',
#   'FAC': 'CA 92626',
#   'NORP': '§',
#   'TIME': '60 seconds to 3 minutes',
#   'QUANTITY': '14.10 Governing Law',
#   'MONEY': '10,000,000.00',
#   'LOC': 'the Effective Date'},
#  'LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement.pdf': {'CARDINAL': '2/5/2020',
#   'DATE': '30) days',
#   'ORG': 'LIQUIDMETAL TECHNOLOGIES INC',
#   'GPE': 'Vietnam',
#   'WORK_OF_ART': 'Porsche',
#   'NORP': 'Eontec',
#   'LOC': 'the Effective Date',
#   'ORDINAL': 'third',
#   'PRODUCT': 'LeCoultre',
#   'PERSON': 'Intellectual Property',
#   'QUANTITY': '2,000 kg',
#   'FAC': 'ST DuPont',
#   'LAW': 'Section 2.1(b',
#   'PERCENT': 'thirty (',
#   'MONEY': '1,000,000',
#   'TIME': 'overnight',
#   'EVENT': 'the International Sale of Goods'},
#  'NlsPharmaceuticsLtd_20200228_F-1_EX-10.14_12029046_EX-10.14_Development Agreement.pdf': {'CARDINAL': '2/28/2020',
#   'ORG': 'NLS PHARMACEUTICS LTD',
#   'NORP': 'Launch',
#   'GPE': 'BRAZIL',
#   'WORK_OF_ART': 'Template for Licensee Reports',
#   'PERSON': 'Eurofarma',
#   'DATE': '7\nYEAR 8\nYEAR 9\nYEAR',
#   'LOC': 'Latin America',
#   'FAC': 'Agreement',
#   'PRODUCT': 'Agreement',
#   'LAW': 'Article 19.6',
#   'ORDINAL': 'first',
#   'PERCENT': '10 %',
#   'TIME': 'overnight',
#   'EVENT': 'the International Sale of Goods',
#   'LANGUAGE': 'English',
#   'QUANTITY': '276.346 2.229.813'},
#  'PelicanDeliversInc_20200211_S-1_EX-10.3_11975895_EX-10.3_Development Agreement1.pdf': {'ORG': 'PELICAN DELIVERS INC',
#   'CARDINAL': '1',
#   'GPE': 'S-1',
#   'DATE': '2/11/2020',
#   'WORK_OF_ART': 'Order Pickup',
#   'PRODUCT': 'Change Password',
#   'FAC': 'Selecting Dispensary',
#   'LANGUAGE': 'English\nDesign',
#   'MONEY': '500',
#   'PERCENT': '80%',
#   'ORDINAL': 'first',
#   'PERSON': 'Dave Comeau',
#   'NORP': '§',
#   'TIME': '1-2 hours',
#   'LOC': 'the Effective Date'},
#  'PelicanDeliversInc_20200211_S-1_EX-10.3_11975895_EX-10.3_Development Agreement2.pdf': {'DATE': '2/11/2020',
#   'LOC': 'the Effective Date',
#   'ORG': 'Party',
#   'GPE': 'S-1',
#   'CARDINAL': '25',
#   'PERSON': 'Dave Comeau',
#   'PRODUCT': 'Agreement',
#   'MONEY': '3.2 PROJECT',
#   'WORK_OF_ART': '6.4.4 Notification of Suspected Disclosure',
#   'LAW': 'Section 6.1',
#   'QUANTITY': '3.7 FINAL',
#   'TIME': '125.00 per hour',
#   'EVENT': 'the Final Delivery Date',
#   'NORP': 'Content);',
#   'ORDINAL': 'third'},
#  'PhasebioPharmaceuticalsInc_20200330_10-K_EX-10.21_12086810_EX-10.21_Development Agreement.pdf': {'CARDINAL': '3/30/2020',
#   'ORG': 'PHASEBIO PHARMACEUTICALS INC',
#   'GPE': 'LTD',
#   'DATE': 'January 9, 2020',
#   'FAC': 'PO Box 2681',
#   'PERSON': 'Robert DeBenedetto',
#   'WORK_OF_ART': 'Timeline\nExhibit J Manufacturer\nExhibit K Trial Data Package Purchase Agreement\nExhibit L AZ License\nExhibit M Amendment',
#   'NORP': '§',
#   'LAW': 'ARTICLE 6 OR',
#   'PERCENT': '7.1-7.7',
#   'PRODUCT': 'Exhibits',
#   'ORDINAL': 'third',
#   'LOC': 'the Effective Date',
#   'EVENT': 'Relationship of the Parties',
#   'TIME': 'normal business hours',
#   'MONEY': '15.11 Limitation of Liability',
#   'QUANTITY': '15.9 Governing Law',
#   'LANGUAGE': 'English'},
#  'ReedsInc_20191113_10-Q_EX-10.4_11888303_EX-10.4_Development Agreement.pdf': {'ORG': "REED'S",
#   'GPE': 'New\nYork',
#   'WORK_OF_ART': 'Signature Page',
#   'DATE': '11/13/2019',
#   'PERSON': 'Brewmaster',
#   'NORP': 'Company',
#   'LAW': 'Section 14',
#   'CARDINAL': '10',
#   'PRODUCT': 'Agreement',
#   'ORDINAL': 'third',
#   'EVENT': 'this Section 7',
#   'LOC': 'Hood River',
#   'PERCENT': 'thirty (',
#   'FAC': 'Columbia Street'},
#  'RevolutionMedicinesInc_20200117_S-1_EX-10.1_11948417_EX-10.1_Development Agreement.pdf': {'CARDINAL': '5',
#   'ORG': 'Revolution Medicines, Inc.',
#   'PERSON': 'Letter Agreement',
#   'DATE': '1/17/2020',
#   'GPE': 'S-1',
#   'NORP': 'Letter',
#   'FAC': 'Binney Street',
#   'LOC': 'the Effective Date',
#   'PRODUCT': 'Exhibits',
#   'PERCENT': '12.1 Term',
#   'QUANTITY': '15.7 Rights in Bankruptcy',
#   'ORDINAL': 'first',
#   'WORK_OF_ART': 'Signature Page to',
#   'LAW': 'the Collaboration Agreement',
#   'EVENT': 'MA 02142',
#   'MONEY': '15.2 Assignment;',
#   'TIME': 'overnight',
#   'LANGUAGE': 'English'},
#  'RitterPharmaceuticalsInc_20200313_S-4A_EX-10.54_12055220_EX-10.54_Development Agreement.pdf': {'CARDINAL': '3/13/2020',
#   'DATE': 'October 27, 2004',
#   'PERSON': 'Sekisui',
#   'ORG': 'RITTER PHARMACEUTICALS INC',
#   'GPE': 'IA',
#   'WORK_OF_ART': 'Qualigen Distribution Agreements',
#   'PRODUCT': 'the True-Up Period\nInstrument\nDepreciation',
#   'PERCENT': '3%',
#   'LAW': 'S-4/A',
#   'LOC': 'Battery',
#   'FAC': 'Urological Assoc',
#   'ORDINAL': '5/1/2016',
#   'MONEY': '100',
#   'NORP': '○',
#   'EVENT': 'the International Sale of Goods',
#   'QUANTITY': 'no more than 48 hours',
#   'TIME': '5/1/2016 - 9/30/2016'},
#  'VgrabCommunicationsInc_20200129_10-K_EX-10.33_11958828_EX-10.33_Development Agreement.pdf': {'ORG': 'VGRAB COMMUNICATIONS INC.',
#   'CARDINAL': '10',
#   'DATE': '1/29/2020',
#   'GPE': 'Malaysia',
#   'WORK_OF_ART': '397 Hennessy Road',
#   'ORDINAL': 'first',
#   'PERSON': 'Gu Xianwin\nPassport',
#   'PRODUCT': 'Cooperation',
#   'MONEY': '200,000.00',
#   'FAC': 'Duesey Coffee WeChat',
#   'PERCENT': '100 %',
#   'LANGUAGE': 'English',
#   'LOC': 'City Gardens'},
#  'FuseMedicalInc_20190321_10-K_EX-10.43_11575454_EX-10.43_Distributor Agreement.pdf': {'CARDINAL': '10',
#   'EVENT': 'Signature Orthopaedics Pty Ltd',
#   'ORG': 'FUSE MEDICAL',
#   'DATE': '3/21/2019',
#   'GPE': 'Ohio',
#   'FAC': 'Background',
#   'PERSON': 'Aria Stem',
#   'LAW': 'the\nCorporations Act',
#   'WORK_OF_ART': 'Signature BiPolar Head\nGenius Total knee system\n',
#   'NORP': 'RemedyTM',
#   'LOC': 'Territories',
#   'ORDINAL': 'Third',
#   'TIME': '9.00 am',
#   'MONEY': '70'},
#  'GentechHoldingsInc_20190808_1-A_EX1A-6 MAT CTRCT_11776814_EX1A-6 MAT CTRCT_Distributor Agreement.pdf': {'CARDINAL': '1',
#   'DATE': '8/8/2019',
#   'ORG': 'GENTECH HOLDINGS, INC.',
#   'EVENT': 'SW 11th CT',
#   'GPE': 'US',
#   'PERSON': 'Distributor',
#   'LAW': 'Section 6',
#   'WORK_OF_ART': 'Indemnifying Party',
#   'ORDINAL': '04th',
#   'PERCENT': '25%',
#   'TIME': 'up to 10 hours',
#   'PRODUCT': 'Agreement',
#   'NORP': 'addressee',
#   'LOC': 'Prices and Volume',
#   'MONEY': '9'},
#  'ImineCorp_20180725_S-1_EX-10.5_11275970_EX-10.5_Distributor Agreement.pdf': {'CARDINAL': '9',
#   'DATE': '7/25/2018',
#   'ORG': 'IMINE CORP,',
#   'NORP': 'Nondisclosure',
#   'FAC': 'Nanjing East Road',
#   'GPE': 'S-1',
#   'WORK_OF_ART': 'Protected Parties',
#   'PERSON': 'Daniel Tsai',
#   'LAW': 'the Export Administration Act',
#   'ORDINAL': 'FIRST',
#   'PERCENT': '15.11 Choice',
#   'MONEY': '13.2 Limitation on Actions',
#   'PRODUCT': 'Agreement',
#   'EVENT': 'RMA',
#   'LOC': '13.1 Limitation of Liabilities'},
#  'InnerscopeHearingTechnologiesInc_20181109_8-K_EX-10.6_11419704_EX-10.6_Distributor Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'INNERSCOPE HEARING TECHNOLOGIES, INC.',
#   'GPE': 'Erchonia',
#   'DATE': '11/9/2018',
#   'PERSON': 'Distributor',
#   'WORK_OF_ART': 'Licensed Territory\nWorldwide\nField of Use',
#   'NORP': 'D.',
#   'ORDINAL': 'third',
#   'PERCENT': '1.5%',
#   'LAW': 'the Bankruptcy Law',
#   'PRODUCT': 'Trademarks',
#   'FAC': 'Erchonia 3LT Laser',
#   'LOC': 'Trademarks',
#   'TIME': '8/29/2018 3:38 PM'},
#  'PrecheckHealthServicesInc_20200320_8-K_EX-99.2_12070169_EX-99.2_Distributor Agreement.pdf': {'CARDINAL': '8',
#   'DATE': '3/20/2020',
#   'ORG': 'PreCheck Health Services, Inc.',
#   'PERSON': 'Commercialization\nJustin Anderson',
#   'GPE': 'Romania',
#   'NORP': 'Principal',
#   'LOC': 'Europe',
#   'WORK_OF_ART': 'Territory',
#   'ORDINAL': 'first'},
#  'ScansourceInc_20190509_10-Q_EX-10.2_11661422_EX-10.2_Distributor Agreement.pdf': {'CARDINAL': '10',
#   'GPE': 'Xplore',
#   'PERSON': 'Distributor',
#   'DATE': '5/9/2019',
#   'WORK_OF_ART': 'Estimated\nShipping Date',
#   'ORG': 'POD',
#   'LOC': 'the Proof of Delivery',
#   'PRODUCT': 'Delivery Duty Paid',
#   'LAW': 'the Distribution Agreement'},
#  'ScansourceInc_20190822_10-K_EX-10.38_11793958_EX-10.38_Distributor Agreement1.pdf': {'CARDINAL': '10',
#   'GPE': 'Cisco',
#   'PERSON': 'Renew',
#   'ORG': 'Cisco Engineering',
#   'DATE': '8/22/2019',
#   'WORK_OF_ART': 'The End of Life Policy',
#   'ORDINAL': 'third',
#   'NORP': 'non-Cisco',
#   'LAW': 'Return Materials Authorization',
#   'PRODUCT': 'Renew',
#   'LOC': 'Quest Way',
#   'PERCENT': 'as least 50.1%',
#   'FAC': 'Table 1',
#   'EVENT': 'RMA',
#   'MONEY': '4(c',
#   'TIME': '24 hours'},
#  'ScansourceInc_20190822_10-K_EX-10.38_11793958_EX-10.38_Distributor Agreement2.pdf': {'CARDINAL': '10',
#   'PERSON': 'LOST',
#   'ORG': 'Software',
#   'WORK_OF_ART': 'The Warranty and the Software License',
#   'DATE': '8/22/2019',
#   'NORP': 'Software',
#   'GPE': 'the State of California',
#   'PRODUCT': 'Agreement',
#   'ORDINAL': 'third',
#   'TIME': 'normal business hours'},
#  'ScansourceInc_20190822_10-K_EX-10.39_11793959_EX-10.39_Distributor Agreement.pdf': {'CARDINAL': '10',
#   'GPE': 'Cisco',
#   'PERSON': 'Jeff Yelton',
#   'PRODUCT': 'Agreement',
#   'ORG': 'S.K. Vereschagin NAME',
#   'WORK_OF_ART': 'Authorized Signature',
#   'DATE': '8/22/2019',
#   'FAC': 'Notwithstanding Cisco’s',
#   'LAW': 'this Amendment No.',
#   'EVENT': 'RMA',
#   'ORDINAL': 'third',
#   'LOC': 'the Effective Date',
#   'NORP': 'http://www.cisco.com/legal/anti'},
#  'SmartRxSystemsInc_20180914_1-A_EX1A-6 MAT CTRCT_11351705_EX1A-6 MAT CTRCT_Distributor Agreement.pdf': {'CARDINAL': '1',
#   'ORG': 'SMART RX SYSTEMS INC',
#   'DATE': '9/14/2018',
#   'GPE': 'Texas',
#   'FAC': 'Customer Kiosk Location',
#   'WORK_OF_ART': 'Sandeep Mathow\nName',
#   'LAW': 'Section 6',
#   'PERSON': 'Tracy W. Gunter',
#   'ORDINAL': 'third',
#   'MONEY': '15.2 Service',
#   'NORP': 'WITNESS',
#   'PRODUCT': 'Agreement',
#   'LOC': 'Kiosk',
#   'PERCENT': '5%',
#   'EVENT': 'Series',
#   'TIME': 'normal business hours',
#   'QUANTITY': '9.2 Company Representations'},
#  'StaarSurgicalCompany_20180801_10-Q_EX-10.37_11289449_EX-10.37_Distributor Agreement.pdf': {'CARDINAL': '10',
#   'WORK_OF_ART': 'Governmental Entity',
#   'ORG': 'STAAR SURGICAL CO',
#   'NORP': 'Survival',
#   'FAC': 'EEA;',
#   'GPE': 'U.S.',
#   'PERSON': 'DISTRIBUTOR',
#   'ORDINAL': 'first',
#   'LOC': 'Indemnities',
#   'DATE': '8/1/2018',
#   'PRODUCT': 'Certification',
#   'PERCENT': '20%',
#   'LANGUAGE': 'English',
#   'LAW': 'Sections 9, 10',
#   'MONEY': 'US$5 million'},
#  'WaterNowInc_20191120_10-Q_EX-10.12_11900227_EX-10.12_Distributor Agreement.pdf': {'CARDINAL': '10',
#   'DATE': 'the next business day',
#   'EVENT': 'the Rio Grande River',
#   'GPE': 'San Antonio',
#   'WORK_OF_ART': 'Number and Gender',
#   'ORG': 'the Rio Grande',
#   'PERSON': 'Odessa',
#   'LAW': 'Section 11.10',
#   'FAC': 'Customer Locations',
#   'PERCENT': '10.1 Term',
#   'ORDINAL': 'first',
#   'PRODUCT': 'the Eagle Ford Shale Basin',
#   'LOC': 'West Texas',
#   'QUANTITY': '7,500 square miles',
#   'MONEY': '11.12 Captions',
#   'TIME': '5:00 p.m.',
#   'LANGUAGE': 'English',
#   'NORP': 'B.'},
#  'ZogenixInc_20190509_10-Q_EX-10.2_11663313_EX-10.2_Distributor Agreement.pdf': {'CARDINAL': '10',
#   'GPE': 'US',
#   'PERSON': 'Authorized Representative',
#   'ORG': 'ZOGENIX',
#   'DATE': '5/9/2019',
#   'LAW': 'the Supply Agreement',
#   'WORK_OF_ART': 'Applicable Laws',
#   'FAC': 'FCPA',
#   'EVENT': 'Prior Non-Disclosure Agreements',
#   'PRODUCT': 'Product',
#   'ORDINAL': 'first',
#   'LANGUAGE': 'English',
#   'LOC': 'the Effective Date',
#   'PERCENT': '12.1 Term',
#   'NORP': 'Japanese',
#   'TIME': 'overnight',
#   'MONEY': '14.8 Independent Contractors',
#   'QUANTITY': '6.2 Funding to Support Development of The Product'},
#  'BerkshireHillsBancorpInc_20120809_10-Q_EX-10.16_7708169_EX-10.16_Endorsement Agreement.pdf': {'CARDINAL': '10',
#   'ORG': 'Auriemma',
#   'GPE': 'Berkshire',
#   'LOC': 'North Street',
#   'PERSON': 'Berkshire',
#   'DATE': '8/9/2012',
#   'EVENT': 'the Services Period for Berkshire',
#   'LAW': 'the “License Rights”',
#   'WORK_OF_ART': 'Selected \nJurisdiction',
#   'MONEY': '30,000.00',
#   'FAC': 'Berkshire Hills Bancorp, Inc.',
#   'ORDINAL': 'third',
#   'PERCENT': 'thirty (',
#   'TIME': '1) hour',
#   'PRODUCT': 'Agreement',
#   'NORP': 'American'},
#  'BizzingoInc_20120322_8-K_EX-10.17_7504499_EX-10.17_Endorsement Agreement.pdf': {'DATE': '3/22/2012',
#   'WORK_OF_ART': 'Bonus Warrant',
#   'ORG': 'INC.',
#   'GPE': 'Theismann',
#   'CARDINAL': '8',
#   'FAC': 'Network',
#   'PRODUCT': 'Bizzingo',
#   'PERSON': 'Schedule A-l',
#   'LOC': 'the Termination Date',
#   'NORP': 'Theismann',
#   'ORDINAL': 'second',
#   'EVENT': 'the Royalty Warrant',
#   'MONEY': '0.15',
#   'TIME': 'normal business hours',
#   'LAW': 'the "Act'},
#  'EcoScienceSolutionsInc_20171117_8-K_EX-10.1_10956472_EX-10.1_Endorsement Agreement.pdf': {'DATE': '11/17/2017',
#   'WORK_OF_ART': 'Talent Indemnities',
#   'GPE': 'Michigan',
#   'PERSON': 'Jeffery Taylor',
#   'CARDINAL': '8',
#   'ORG': 'Company',
#   'LOC': 'the Effective Date',
#   'NORP': 'Tweets',
#   'TIME': 'eight (8) hours',
#   'MONEY': '10,000',
#   'ORDINAL': 'first',
#   'PRODUCT': 'Agreement;',
#   'EVENT': 'SW 117th Ave\n',
#   'FAC': 'Agreement'},
#  'GridironBionutrientsInc_20171206_8-K_EX-10.1_10972555_EX-10.1_Endorsement Agreement.pdf': {'CARDINAL': '12/6/2017',
#   'FAC': 'Madison Avenue',
#   'LAW': 'Chapter of the',
#   'DATE': '12/6/2017',
#   'ORG': 'GRIDIRON BIONUTRIENTS, INC.',
#   'GPE': 'California',
#   'LOC': 'Hayward',
#   'PERSON': 'Eric Price',
#   'NORP': 'B.',
#   'WORK_OF_ART': 'Living Water Concentrate',
#   'ORDINAL': 'third',
#   'MONEY': '0.05',
#   'PERCENT': '1%',
#   'EVENT': 'the Contract Period',
#   'TIME': 'hours',
#   'PRODUCT': 'Company',
#   'QUANTITY': '225 miles'},
#  'GridironBionutrientsInc_20171206_8-K_EX-10.2_10972556_EX-10.2_Endorsement Agreement.pdf': {'CARDINAL': '12/6/2017',
#   'DATE': 'November 22nd, 2017',
#   'ORG': 'GRIDIRON BIONUTRIENTS, INC.',
#   'FAC': 'CA 93291',
#   'GPE': 'NC',
#   'LOC': 'Northern California Chapter',
#   'WORK_OF_ART': 'Living\nWater\n= 1 Unit\n \nb.\n(',
#   'PERSON': 'Page 2',
#   'EVENT': 'the Contract Period',
#   'MONEY': '0.05',
#   'PERCENT': '15%'},
#  'LegacyEducationAllianceInc_20141110_8-K_EX-10.9_8828866_EX-10.9_Endorsement Agreement.pdf': {'DATE': '11/10/2014',
#   'ORG': 'LEGACY EDUCATION ALLIANCE, INC.',
#   'CARDINAL': '8',
#   'MONEY': '75\xa0Boston\xa0Manor\xa0Road',
#   'GPE': 'the\xa0County\xa0Court',
#   'PERSON': 'Sharon\xa0Bowler',
#   'WORK_OF_ART': 'Talent’s\xa0Property',
#   'ORDINAL': 'third',
#   'LOC': 'ENTENT',
#   'FAC': 'Robbie\xa0Fowler\n\xa0\nAddress',
#   'NORP': 'SURVIVAL'},
#  'LifewayFoodsInc_20160316_10-K_EX-10.24_9489766_EX-10.24_Endorsement Agreement.pdf': {'CARDINAL': '3/16/2016',
#   'FAC': 'ENDORSEMENT AGREEMENT\nThis Endorsement Agreement',
#   'DATE': 'March 14, 2016\nSource',
#   'WORK_OF_ART': 'Effective Date',
#   'ORG': 'INC.',
#   'GPE': 'the State of Illinois',
#   'PERSON': 'Julie Smolyansky',
#   'LAW': 'the Marketing Materials',
#   'NORP': 'Individual;',
#   'MONEY': '50,000',
#   'ORDINAL': 'third',
#   'PRODUCT': 'Agreement',
#   'TIME': 'overnight'},
#  'NakedBrandGroupInc_20150731_POS AM (on S-1)_EX-10.75_9196027_EX-10.75_Endorsement Agreement.pdf': {'CARDINAL': '19',
#   'DATE': '7/31/2015',
#   'WORK_OF_ART': 'Intellectual\xa0Property\xa0Rights',
#   'GPE': 'New\xa0York',
#   'PERSON': '7/31/2015',
#   'ORG': 'NAKED BRAND GROUP INC.',
#   'PRODUCT': 'AGREEMENT\xa0\n1',
#   'ORDINAL': 'first',
#   'TIME': 'consecutive\xa0hours',
#   'PERCENT': '50%',
#   'NORP': 'Inducement',
#   'FAC': 'Broadway'},
#  'PapaJohnsInternationalInc_20190617_8-K_EX-10.1_11707365_EX-10.1_Endorsement Agreement.pdf': {'CARDINAL': '8',
#   'FAC': 'Broadway',
#   'DATE': '6/17/2019',
#   'EVENT': 'the Insurance Period',
#   'ORG': 'PAPA JOHNS INTERNATIONAL INC',
#   'GPE': 'New York',
#   'PERSON': 'Steve Ritchie',
#   'WORK_OF_ART': 'Signature Page Follows',
#   'LAW': 'the Personality Rights, Materials and/or Products',
#   'LOC': 'the Effective Date',
#   'NORP': 'D.',
#   'PRODUCT': 'Approval',
#   'ORDINAL': 'first',
#   'TIME': 'five or ten minutes',
#   'PERCENT': 'as to 36%',
#   'MONEY': '5,000,000'},
#  'PerformanceSportsBrandsInc_20110909_S-1_EX-10.10_7220214_EX-10.10_Endorsement Agreement.pdf': {'ORG': 'INC.',
#   'DATE': '9/9/2011',
#   'GPE': 'S-1',
#   'CARDINAL': '12',
#   'PERSON': 'Andy North \n\xa0\n\xa0\n\xa0\nDate',
#   'PRODUCT': 'Agreement',
#   'LAW': 'section 8',
#   'LOC': 'North',
#   'NORP': 'Company',
#   'WORK_OF_ART': 'Force Majeure',
#   'ORDINAL': 'first',
#   'TIME': '3) hours',
#   'MONEY': '2,000,000',
#   'EVENT': 'Contract Year 2011',
#   'QUANTITY': 'Twenty-Five thousand dollars',
#   'PERCENT': 'thirty (',
#   'FAC': 'Broadway Avenue'},
#  'PharmagenInc_20120803_8-KA_EX-10.1_7693204_EX-10.1_Endorsement Agreement.pdf': {'CARDINAL': '8',
#   'FAC': 'Galleria Parkway',
#   'DATE': 'March 8, 2012',
#   'WORK_OF_ART': 'Marks',
#   'ORG': 'INC.',
#   'GPE': 'Georgia',
#   'PERSON': 'Carolyn Silas',
#   'LOC': 'the Northern District',
#   'NORP': 'D.',
#   'EVENT': 'the Production Session',
#   'TIME': '8) \nhours',
#   'ORDINAL': '8/3/2012',
#   'PRODUCT': 'Agreement',
#   'MONEY': 'less than $2,000,000'},
#  'PrudentialBancorpInc_20170606_8-K_EX-10.4_10474434_EX-10.4_Endorsement Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'Prudential Bank',
#   'DATE': '2017',
#   'GPE': 'PA',
#   'PERSON': 'Name',
#   'PRODUCT': 'Employee',
#   'LOC': 'Employer',
#   'LAW': 'section 2',
#   'WORK_OF_ART': 'Policies',
#   'FAC': 'Employee',
#   'MONEY': '100,000'},
#  'ThriventVariableInsuranceAccountB_20190701_N-6_EX-99.D(IV)_11720968_EX-99.D(IV)_Endorsement Agreement.pdf': {'DATE': '7/1/2019',
#   'ORG': 'VB-TL-TFFL',
#   'NORP': 'ASSIGNMENT',
#   'WORK_OF_ART': 'Signed for Thrivent Financial for Lutherans',
#   'PERSON': 'N-6',
#   'GPE': 'Minneapolis',
#   'CARDINAL': '18',
#   'PERCENT': '5%',
#   'LOC': 'North Ballard Road',
#   'FAC': 'Fourth Avenue South',
#   'ORDINAL': 'first'},
#  'PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_Franchise Agreement1.pdf': {'LOC': 'Agreement Date',
#   'WORK_OF_ART': 'Agreement or the Personal Guaranty',
#   'ORG': 'PF HOSPITALITY GROUP INC.',
#   'PERSON': 'Mutual Waiver',
#   'LAW': 'Section 25',
#   'CARDINAL': '10-12',
#   'DATE': '9/23/2015',
#   'GPE': 'Franchisee',
#   'EVENT': 'the Opening Date',
#   'NORP': 'System',
#   'ORDINAL': 'first',
#   'PRODUCT': 'Agreement',
#   'FAC': 'Page 38',
#   'MONEY': '7,500',
#   'PERCENT': '10%',
#   'TIME': 'normal business hours',
#   'QUANTITY': '23.3 Force Majeure'},
#  'PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_Franchise Agreement3.pdf': {'CARDINAL': '10-12',
#   'WORK_OF_ART': 'this Agreement',
#   'GPE': 'Franchisee',
#   'PERSON': 'Franchisor',
#   'LAW': 'the Franchise Agreement',
#   'ORG': 'PF HOSPITALITY GROUP INC.',
#   'NORP': 'Compete',
#   'DATE': '9/23/2015',
#   'QUANTITY': '3) mile',
#   'PRODUCT': 'C - 2\nSource',
#   'ORDINAL': 'first'},
#  'RgcResourcesInc_20151216_8-K_EX-10.3_9372751_EX-10.3_Franchise Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'RGC RESOURCES INC',
#   'DATE': '12/14/2015',
#   'GPE': 'Virginia',
#   'FAC': 'Vinton',
#   'MONEY': '98,196',
#   'TIME': 'overnight',
#   'NORP': 'SIGNATURES',
#   'PERSON': 'Susan\xa0N.\xa0Johnson'},
#  'SimplicityEsportsGamingCompany_20181130_8-K_EX-10.1_11444071_EX-10.1_Franchise Agreement.pdf': {'CARDINAL': '8',
#   'WORK_OF_ART': 'Avenue of the Americas',
#   'DATE': '11/30/2018',
#   'GPE': 'Franchisee',
#   'ORG': 'SIMPLICITY ESPORTS & GAMING CO',
#   'NORP': 'addressee',
#   'FAC': 'Smaaash Centre',
#   'PERSON': 'Trademarks',
#   'LOC': 'the Effective Date',
#   'ORDINAL': '11th',
#   'LAW': 'Section 10.4',
#   'PRODUCT': 'a Force Majeure',
#   'PERCENT': 'thirty (',
#   'MONEY': '8.3 Termination for Cause',
#   'QUANTITY': '10.10 Amendment'},
#  'SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement1.pdf': {'CARDINAL': '8/14/2015',
#   'GPE': 'CONCEPTS',
#   'ORG': 'INC.',
#   'DATE': '8/14/2015',
#   'PERSON': 'TERRITORY',
#   'PRODUCT': 'Receipt',
#   'WORK_OF_ART': 'Master\xa0Franchise\xa0Agreement\n\xa0\nMASTER',
#   'NORP': 'Survival',
#   'QUANTITY': '5.9\xa0Master',
#   'MONEY': '19.9\xa0Additional\xa0Documents\n\xa0\nEach',
#   'LAW': 'Article\xa033',
#   'PERCENT': '2%',
#   'ORDINAL': 'first',
#   'TIME': '24)\xa0hours',
#   'LOC': 'RELATIONSHIP'},
#  'SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement2.pdf': {'WORK_OF_ART': 'Master\xa0Franchisee',
#   'ORG': 'INC.',
#   'CARDINAL': '8/14/2015',
#   'DATE': 'the\xa0day',
#   'PERSON': 'Franchisor',
#   'NORP': 'D.'},
#  'SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement3.pdf': {'WORK_OF_ART': 'The\xa0Master\xa0Franchise\xa0Agreement',
#   'GPE': 'California',
#   'DATE': 'MAY',
#   'CARDINAL': '8/14/2015',
#   'ORG': 'INC.'},
#  'SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement4.pdf': {'CARDINAL': '8/14/2015',
#   'PERSON': 'Addendum',
#   'DATE': '2015',
#   'NORP': 'Canadian',
#   'GPE': 'CONCEPTS',
#   'ORG': 'INC.'},
#  'Freecook_20180605_S-1_EX-10.3_11233807_EX-10.3_Hosting Agreement.pdf': {'PERSON': 'FREECOOK',
#   'ORG': 'Search Engine Optimization',
#   'DATE': '6/5/2018',
#   'GPE': 'S-1',
#   'CARDINAL': '2',
#   'MONEY': '40',
#   'WORK_OF_ART': 'Change Order',
#   'LOC': 'Scope of Work',
#   'NORP': 'Company',
#   'TIME': 'the normal business hours',
#   'PERCENT': '25%'},
#  'PareteumCorp_20081001_8-K_EX-99.1_2654808_EX-99.1_Hosting Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'PARETEUM CORP',
#   'GPE': 'Netherlands',
#   'DATE': '10/1/2008',
#   'PERSON': 'Martin\xa0Zuurbier\nTitle',
#   'WORK_OF_ART': 'Initial\xa0Term\xa0of\xa0the\xa0Agreement',
#   'NORP': 'Dutch',
#   'PRODUCT': 'Appendix\xa04',
#   'LAW': 'article\xa011',
#   'FAC': 'Soft\xa0Launch',
#   'ORDINAL': 'first',
#   'PERCENT': '1\xa0%',
#   'QUANTITY': '20.9\xa0\nRepresentation',
#   'MONEY': '20.6\xa0\n',
#   'LANGUAGE': 'English'},
#  'QuantumGroupIncFl_20090120_8-K_EX-99.2_3672910_EX-99.2_Hosting Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'QUANTUM GROUP INC /FL',
#   'GPE': 'Attachment',
#   'WORK_OF_ART': 'Additional\xa0Hourly\xa0Database\xa0Support',
#   'LOC': 'Outage',
#   'PRODUCT': 'Bandwidth',
#   'DATE': '1/20/2009',
#   'PERCENT': '5%',
#   'PERSON': 'c.\xa0',
#   'FAC': 'Failover\xa0Configuration',
#   'TIME': 'hours',
#   'ORDINAL': 'second',
#   'EVENT': 'Minutes',
#   'MONEY': '147.14.00',
#   'NORP': 'Assist'},
#  'VitalibisInc_20180316_8-K_EX-10.2_11100168_EX-10.2_Hosting Agreement.pdf': {'CARDINAL': '8',
#   'WORK_OF_ART': 'Change Orders',
#   'ORG': 'VITALIBIS, INC.',
#   'FAC': 'Agreement',
#   'GPE': 'U.S.',
#   'PERSON': 'Licensee',
#   'DATE': '3/16/2018',
#   'PRODUCT': 'the Total Number of',
#   'TIME': '5:00',
#   'MONEY': '9A1V1-5PM',
#   'QUANTITY': '7.2 Indenmification',
#   'LAW': 'Section 4',
#   'LOC': 'The Effective Date',
#   'PERCENT': '8.1 Exclusion',
#   'ORDINAL': 'third',
#   'NORP': 'Panics',
#   'LANGUAGE': 'English',
#   'EVENT': 'this Statement of Work'},
#  'ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf': {'CARDINAL': '8',
#   'DATE': '1/7/2019',
#   'ORG': 'the Diamond 10 Technology',
#   'GPE': 'Black',
#   'WORK_OF_ART': 'Filing Date\nPatent Number\nIssue Date',
#   'PERSON': 'Logo Background',
#   'FAC': 'AFI Licensing LLC',
#   'PRODUCT': 'Status\nApp',
#   'LOC': 'the Buyer Entities',
#   'NORP': '9-Jul-15',
#   'LAW': 'Schedule 1.1(u',
#   'EVENT': 'the SPA Signing Date',
#   'ORDINAL': 'first',
#   'TIME': '3-Apr-15',
#   'PERCENT': '20%',
#   'QUANTITY': '25mm'},
#  'CerenceInc_20191002_8-K_EX-10.4_11827494_EX-10.4_Intellectual Property Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'CERENCE INC.',
#   'DATE': '10/2/2019',
#   'WORK_OF_ART': 'SpinCo’s',
#   'LAW': 'Section 11.16',
#   'GPE': 'the United States of America',
#   'PERSON': 'Leanne Fitzgerald\nTitle',
#   'PRODUCT': 'Agreement',
#   'LOC': 'the Distribution Date',
#   'EVENT': 'the Distribution Date',
#   'ORDINAL': 'third',
#   'FAC': 'the Spin-Off',
#   'NORP': 'D.'},
#  'GarrettMotionInc_20181001_8-K_EX-2.4_11364532_EX-2.4_Intellectual Property Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'GARRETT MOTION INC',
#   'DATE': '10/1/2018',
#   'WORK_OF_ART': 'Signature Page to Intellectual Property Agreement]\nSource: GARRETT MOTION INC.',
#   'LAW': 'Section 11.15',
#   'PERSON': 'Su Ping Lu',
#   'PRODUCT': 'Agreement',
#   'GPE': 'the United States of America',
#   'LOC': 'the Distribution Date',
#   'ORDINAL': 'third',
#   'FAC': 'Tabor Road\nMorris Plains',
#   'EVENT': 'the Distribution Date',
#   'NORP': 'Subsidiaries',
#   'PERCENT': '50%',
#   'TIME': '16\n1180'},
#  'RareElementResourcesLtd_20171019_SC 13D_EX-99.4_10897534_EX-99.4_Intellectual Property Agreement.pdf': {'ORG': 'SC',
#   'GPE': 'US',
#   'CARDINAL': '1',
#   'WORK_OF_ART': 'Extraction of Rare Earth\nElements',
#   'DATE': '10/13/2015',
#   'PERSON': 'Kenneth J. Mushinski\n \nTitle',
#   'LAW': 'Article 18.04',
#   'EVENT': 'Exclusive Dispute Resolution Mechanism',
#   'LOC': 'the Effective Date',
#   'FAC': 'CA 2,964,306',
#   'ORDINAL': 'second',
#   'QUANTITY': '3.04 Prior',
#   'NORP': 'Company'},
#  'AlliedEsportsEntertainmentInc_20190815_8-K_EX-10.19_11788293_EX-10.19_Content License Agreement.pdf': {'DATE': '8/15/2019',
#   'ORG': 'ALLIED ESPORTS ENTERTAINMENT',
#   'GPE': 'ZYNGA',
#   'FAC': '8th Street',
#   'PERSON': 'g.\nGoverning Law and Forum',
#   'CARDINAL': '8',
#   'ORDINAL': 'third',
#   'LAW': 'the “WPT Indemnified Parties',
#   'LOC': 'the Northern District',
#   'NORP': 'Asian',
#   'WORK_OF_ART': 'Confidential Information',
#   'MONEY': 'more than $1,500',
#   'PERCENT': 'thirty (',
#   'PRODUCT': 'WPT Tournaments',
#   'EVENT': 'Tournaments'},
#  'ArconicRolledProductsCorp_20191217_10-12B_EX-2.7_11923804_EX-2.7_Trademark License Agreement.pdf': {'CARDINAL': '6',
#   'DATE': '10-12B',
#   'WORK_OF_ART': 'Licensor Indemnitees',
#   'ORG': 'PRODUCTS CORP',
#   'GPE': 'Licensor',
#   'PERSON': '12/17/2019',
#   'FAC': 'Isabella Street',
#   'LAW': 'section 5.1',
#   'EVENT': 'the Transition Period',
#   'MONEY': '1.3 Trademark Notices',
#   'ORDINAL': 'third',
#   'LOC': 'the Effective Date',
#   'PRODUCT': 'Agreement',
#   'PERCENT': '6.4 Waiver',
#   'QUANTITY': '6.1 Governing Law',
#   'TIME': 'overnight',
#   'NORP': 'Affiliates'},
#  'ArtaraTherapeuticsInc_20200110_8-K_EX-10.5_11943350_EX-10.5_License Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'ARTARA THERAPEUTICS',
#   'DATE': '1/10/2020',
#   'TIME': 'normal business hours',
#   'GPE': 'ArTara',
#   'PERSON': 'Richard Smith',
#   'FAC': 'Publication',
#   'LAW': 'ARTICLE NINE\n',
#   'PERCENT': '8.1 Term',
#   'ORDINAL': 'third',
#   'PRODUCT': 'Agreement',
#   'NORP': 'Japanese',
#   'WORK_OF_ART': 'University Indemnitees',
#   'EVENT': 'Phase II',
#   'LOC': 'ArTara',
#   'MONEY': '125,000',
#   'QUANTITY': '9.4 Governing Law'},
#  'ChinaRealEstateInformationCorp_20090929_F-1_EX-10.32_4771615_EX-10.32_Content License Agreement.pdf': {'CARDINAL': '19',
#   'ORG': 'CHINA REAL ESTATE INFORMATION CORP',
#   'GPE': 'Shanghai',
#   'PERSON': 'WITNESSETH',
#   'WORK_OF_ART': 'Termination Agreement',
#   'DATE': '9/29/2009',
#   'LAW': 'this Termination Agreement',
#   'PRODUCT': 'Agreement',
#   'ORDINAL': '9/29/2009',
#   'LOC': 'the Effective Date',
# ...
#  'SalesforcecomInc_20171122_10-Q_EX-10.1_10961535_EX-10.1_Reseller Agreement.pdf': {'CARDINAL': '10',
#   'WORK_OF_ART': 'Signature Page\nReseller Full Legal Name\nSalesforce.org',
#   'FAC': 'The Landmark @',
#   'ORG': 'SALESFORCE.COM, INC.',
#   'GPE': 'California',
#   'DATE': 'August 1, 2015',
#   'PRODUCT': 'Sub-Reseller',
#   'LAW': 'Section 2(ii',
#   'ORDINAL': 'third'},
#  'GpaqAcquisitionHoldingsInc_20200123_S-4A_EX-10.8_11951679_EX-10.8_Service Agreement.pdf': {'CARDINAL': '17',
#   'ORG': 'EXH',
#   'GPE': 'the City of Canton',
#   'DATE': '1/23/2020',
#   'PERSON': 'H-1\nSource',
#   'PRODUCT': 'CONSTELLATION\nAMERICA',
#   'LAW': 'S-4/A',
#   'QUANTITY': '6.7 Force Majeure',
#   'ORDINAL': 'SECOND',
#   'LOC': 'Village',
#   'WORK_OF_ART': 'Player Care Center including',
#   'MONEY': '6.20 HOF Entity Rights and Obligations',
#   'EVENT': 'Parties',
#   'TIME': 'normal business hours',
#   'FAC': 'Point Street',
#   'PERCENT': '6.14 Headings'},
#  'IntegrityFunds_20200121_485BPOS_EX-99.E UNDR CONTR_11948727_EX-99.E UNDR CONTR_Service Agreement.pdf': {'PERSON': 'Shannon D. Radke - President',
#   'DATE': '1/21/2020',
#   'ORG': 'Integrity Short Term Government Fund',
#   'LAW': 'Section 8.6',
#   'GPE': 'North Dakota',
#   'TIME': 'normal business hours',
#   'CARDINAL': '485BPOS',
#   'LOC': 'SEC;',
#   'ORDINAL': 'first',
#   'PRODUCT': 'SEC;'},
#  'ReynoldsConsumerProductsInc_20200121_S-1A_EX-10.22_11948918_EX-10.22_Service Agreement.pdf': {'CARDINAL': '1/21/2020',
#   'DATE': '1/21/2020',
#   'ORG': 'S-1/A',
#   'GPE': 'Conga',
#   'WORK_OF_ART': 'Commencement Date',
#   'PERSON': 'Pactiv Retiree\n',
#   'LAW': '•\u2003\u200aFamiliarization',
#   'FAC': 'the Warehousing and Freight Services Agreement',
#   'PERCENT': '50%',
#   'ORDINAL': 'third',
#   'LOC': 'Europe & Asia',
#   'PRODUCT': '•\u2003\u200aFTA',
#   'TIME': 'hourly',
#   'EVENT': 'the Commencement Date\n•',
#   'NORP': 'Concur',
#   'MONEY': '100'},
#  'VerizonAbsLlc_20200123_8-K_EX-10.4_11952335_EX-10.4_Service Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'Depositor',
#   'NORP': 'Issuer',
#   'PERSON': 'Subcontractor',
#   'DATE': '1/23/2020',
#   'LAW': 'the Exchange Act',
#   'WORK_OF_ART': 'Servicing\nAssessment and Attestation Report',
#   'PRODUCT': 'Agreement',
#   'GPE': 'Servicing Criteria',
#   'LOC': 'each Payment Date',
#   'EVENT': 'the Amortization Period',
#   'ORDINAL': 'third',
#   'FAC': 'the Receivables Transfer Agreements',
#   'TIME': 'overnight',
#   'PERCENT': 'less than 7.65%',
#   'MONEY': '17,877,097.97'},
#  'AlliedEsportsEntertainmentInc_20190815_8-K_EX-10.34_11788308_EX-10.34_Sponsorship Agreement.pdf': {'CARDINAL': '8',
#   'LAW': 'Section 15.10',
#   'DATE': '8/15/2019',
#   'EVENT': 'this Section 9',
#   'ORG': 'ALLIED ESPORTS ENTERTAINMENT',
#   'GPE': 'California',
#   'WORK_OF_ART': 'Confidential Information of the Disclosing Party',
#   'PRODUCT': 'Agreement',
#   'FAC': 'Esports Arena Las Vegas',
#   'PERSON': 'Judson Hannigan',
#   'LOC': 'the Effective Date',
#   'MONEY': '15.11 Third Party Rights',
#   'ORDINAL': '6th',
#   'PERCENT': '13.4 Return',
#   'QUANTITY': '15.9 Notice',
#   'LANGUAGE': 'English',
#   'NORP': 'addressee',
#   'TIME': '11:40 am, Feb 25, 2019'},
#  'ArcGroupInc_20171211_8-K_EX-10.1_10976103_EX-10.1_Sponsorship Agreement.pdf': {'CARDINAL': '8',
#   'GPE': 'Sponsor',
#   'ORG': 'ARC GROUP',
#   'DATE': '12/11/2017',
#   'FAC': 'Stadium',
#   'LAW': 'Section 150',
#   'WORK_OF_ART': 'Club Approval Rights under Section 5',
#   'PERSON': 'Stand',
#   'EVENT': 'Jaguars Home Game and Other Events',
#   'PRODUCT': 'Agreement;',
#   'ORDINAL': 'second',
#   'TIME': 'thirty second',
#   'QUANTITY': 'up to thirty\nseconds',
#   'LOC': 'Stadium'},
#  'EcoScienceSolutionsInc_20180406_8-K_EX-10.1_11135398_EX-10.1_Sponsorship Agreement.pdf': {'DATE': 'Hawaii 96768',
#   'WORK_OF_ART': 'Governing Law:',
#   'ORG': 'Stella McLaughlan',
#   'FAC': 'Makawao Avenue',
#   'CARDINAL': '8',
#   'GPE': '4/6/2018',
#   'EVENT': 'SW 117th Ave',
#   'NORP': 'Promoter',
#   'MONEY': 'one million dollars',
#   'PERSON': 'Jeffery Taylor\nTitle',
#   'TIME': 'overnight',
#   'ORDINAL': 'first'},
#  'FreezeTagInc_20180411_8-K_EX-10.1_11139603_EX-10.1_Sponsorship Agreement.pdf': {'CARDINAL': '8',
#   'ORG': 'Company Legal Department',
#   'DATE': '4/11/2018',
#   'PERSON': 'c.\nTracking Funds',
#   'NORP': 'Company',
#   'GPE': 'Company',
#   'FAC': 'Crystal Drive',
#   'WORK_OF_ART': 'Legal Requirements',
#   'LAW': 'this Sponsorship Agreement',
#   'ORDINAL': 'third',
#   'MONEY': '25,000',
#   'EVENT': 'Program or Event',
#   'TIME': 'overnight',
#   'LOC': 'Central Drive',
#   'PRODUCT': 'Twitter',
#   'PERCENT': '100%'},
#  'AgapeAtpCorp_20191202_10-KA_EX-10.1_11911128_EX-10.1_Supply Agreement.pdf': {'ORG': 'Organic Preparations INC.',
#   'FAC': 'Energy Plaza',
#   'PERSON': 'ATP 1S',
#   'GPE': 'Kuala Lumpur',
#   'CARDINAL': '10',
#   'DATE': '12/2/2019',
#   'LOC': 'Territories',
#   'WORK_OF_ART': 'Witness Signature',
#   'ORDINAL': 'first',
#   'PRODUCT': 'Product',
#   'EVENT': 'RMA',
#   'PERCENT': 'The remaining 50%',
#   'LANGUAGE': 'English',
#   'LAW': 'Date 31',
#   'NORP': 'Chinese',
#   'MONEY': '1.00'},
#  'LohaCompanyltd_20191209_F-1_EX-10.16_11917878_EX-10.16_Supply Agreement.pdf': {'CARDINAL': '6',
#   'LOC': 'BUYER',
#   'PERSON': 'Force Majeure',
#   'GPE': 'the People’s Republic of China',
#   'ORG': 'F-1',
#   'DATE': '12/9/2019',
#   'NORP': 'Chinese',
#   'WORK_OF_ART': 'KEEP',
#   'PERCENT': 'the 30%',
#   'TIME': '72 hours',
#   'PRODUCT': 'Contract',
#   'LANGUAGE': 'English'},
#  'ReynoldsConsumerProductsInc_20191115_S-1_EX-10.18_11896469_EX-10.18_Supply Agreement.pdf': {'CARDINAL': '12',
#   'DATE': '11/15/2019',
#   'EVENT': 'the International Sale of Goods',
#   'ORG': 'REYNOLDS CONSUMER PRODUCTS INC.',
#   'GPE': 'S-1',
#   'WORK_OF_ART': 'Applicable Law',
#   'FAC': 'Affiliate',
#   'PERSON': 'John McGrath',
#   'LOC': 'the Effective Date',
#   'ORDINAL': 'third',
#   'LAW': 'this Master Supply Agreement',
#   'PRODUCT': 'Agreement',
#   'MONEY': '100',
#   'PERCENT': '2%'},
#  'WestPharmaceuticalServicesInc_20200116_8-K_EX-10.1_11947529_EX-10.1_Supply Agreement.pdf': {'CARDINAL': '8',
#   'LAW': 'Article 14',
#   'WORK_OF_ART': 'Change of Control',
#   'ORG': 'WEST PHARMACEUTICAL SERVICES INC',
#   'PERSON': 'Buyer',
#   'LOC': 'Buyer',
#   'FAC': 'Buyer’s Affiliates',
#   'DATE': '1/16/2020',
#   'GPE': 'Brussels',
#   'PRODUCT': 'Product',
#   'MONEY': '50-$55',
#   'ORDINAL': 'third',
#   'QUANTITY': '200 nautical miles',
#   'EVENT': 'the International Sale of Goods',
#   'PERCENT': '50%',
#   'LANGUAGE': 'English',
#   'NORP': 'non-US',
#   'TIME': '6) hours'},
#  'PenntexMidstreamPartnersLp_20150416_S-1A_EX-10.4_9042833_EX-10.4_Transportation Agreement.pdf': {'CARDINAL': '4/16/2015',
#   'ORG': 'LP, S-1/A',
#   'DATE': '10010',
#   'WORK_OF_ART': 'Receipt\n\xa0\nDelivery\xa0Point\xa0Name\n\xa0\nTransporter’s\nMeter\xa0#',
#   'GPE': 'LA',
#   'PERSON': 'Mcf',
#   'LAW': 'Article\xa0XIV',
#   'FAC': 'Camp\n\xa0\n',
#   'NORP': 'Parish',
#   'LOC': 'Mount\xa0Olive',
#   'EVENT': 'Article\xa0XIII',
#   'TIME': 'intraday',
#   'ORDINAL': '15th',
#   'QUANTITY': '12\xa0miles',
#   'PRODUCT': 'Receipt',
#   'PERCENT': '10%',
#   'MONEY': '0.04'},
#  'RangeResourcesLouisianaInc_20150417_8-K_EX-10.5_9045501_EX-10.5_Transportation Agreement.pdf': {'CARDINAL': '8',
#   'DATE': '4/17/2015',
#   'WORK_OF_ART': 'Tariff',
#   'GPE': 'LA',
#   'ORG': 'Lincoln',
#   'PERSON': 'Miscellaneous',
#   'FAC': 'Affiliate',
#   'PRODUCT': 'Receipt\nPoint',
#   'TIME': '48)\xa0hours',
#   'LOC': 'Carrier',
#   'NORP': 'Parish',
#   'ORDINAL': 'first',
#   'LAW': 'ARTICLE',
#   'EVENT': '9\xa0\n',
#   'PERCENT': '1%',
#   'MONEY': '1.00',
#   'QUANTITY': '27\xa0miles',
#   'LANGUAGE': 'Parish'},
#  'TcPipelinesLp_20160226_10-K_EX-99.12_9454048_EX-99.12_Transportation Agreement.pdf': {'ORG': 'QuickLinks',
#   'FAC': 'Shipper and Transporter',
#   'PERSON': 'Primary Delivery\nMDQ\nMaximum\nAllowable',
#   'PRODUCT': 'Shipper',
#   'CARDINAL': '2/26/2016',
#   'DATE': '10/31/2017',
#   'GPE': 'Houston',
#   'WORK_OF_ART': 'General Terms and Conditions',
#   'QUANTITY': '9 and/or',
#   'LAW': 'the Natural Gas Act'},
#  'ZtoExpressCaymanInc_20160930_F-1_EX-10.10_9752871_EX-10.10_Transportation Agreement.pdf': {'ORG': 'CAYMAN) INC.',
#   'CARDINAL': '4',
#   'DATE': '2014',
#   'GPE': '9/30/2016',
#   'PERSON': '9/30/2016',
#   'WORK_OF_ART': 'Road\xa0Transportation\xa0Agreement',
#   'ORDINAL': 'third',
#   'TIME': 'two\xa0hours'},
#  'OLDAPIWIND-DOWNLTD_01_08_2016-EX-1.3-AGENCY AGREEMENT1.pdf': {'CARDINAL': '6',
#   'ORG': 'Dealer Covered Person',
#   'DATE': 'Subscriber',
#   'FAC': 'the Closing Time',
#   'GPE': 'Offering',
#   'PERSON': 'Advertising',
#   'MONEY': '10,000',
#   'WORK_OF_ART': 'Dealer Covered Persons',
#   'PERCENT': '20%',
#   'LOC': 'the Closing Date',
#   'LAW': 'Section 4(a)(2',
#   'PRODUCT': 'Subscribers',
#   'TIME': '5:00 p.m.',
#   'NORP': 'Issuer',
#   'ORDINAL': 'first',
#   'EVENT': 'a Disqualification Event'},
#  'OLDAPIWIND-DOWNLTD_01_08_2016-EX-1.3-AGENCY AGREEMENT2.pdf': {'ORG': 'Schedule A',
#   'GPE': 'U.S.',
#   'DATE': 'this day of , 2015',
#   'PERSON': 'Advertising',
#   'LAW': 'Section 4(a',
#   'CARDINAL': '2',
#   'WORK_OF_ART': 'Regulation D;',
#   'PRODUCT': 'Subscribers'},
#  'BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1).pdf': {'CARDINAL': '2',
#   'WORK_OF_ART': 'Modified Work Plan',
#   'ORG': 'Cargill',
#   'DATE': 'Month 42',
#   'LAW': 'the Work Plan  \n\xa0 \nThird Party',
#   'PERSON': '•\n\xa0 Cargill',
#   'FAC': 'Publication',
#   'GPE': 'US',
#   'ORDINAL': 'third',
#   'MONEY': 'US$',
#   'EVENT': 'the Target Date',
#   'PRODUCT': 'the Term Sheet',
#   'LOC': 'the Effective Date',
#   'TIME': 'overnight'},
#  'BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT - First Amendment.pdf': {'PRODUCT': 'AMENDMENT 1 TO',
#   'LAW': 'Section 5.9',
#   'ORG': 'SAS',
#   'DATE': 'October 15, 2011\n',
#   'WORK_OF_ART': 'BRI Project',
#   'FAC': 'Sarnia Plant',
#   'LOC': 'the Sarnia Plant',
#   'PERSON': 'Jean-François',
#   'CARDINAL': '2',
#   'GPE': 'Minneapolis',
#   'NORP': 'Corynebacteria',
#   'QUANTITY': '35,000 metric tons'},
#  'NETGEAR,INC_04_21_2003-EX-10.16- AMENDMENT #2 TO THE DISTRIBUTION AGREEMENT.pdf': {'DATE': '1600',
#   'LAW': '"Amendment\xa0Date',
#   'ORG': 'CA\xa092705\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#   'CARDINAL': '7/15/98',
#   'GPE': 'Santa\xa0Clara',
#   'ORDINAL': 'first',
#   'PERSON': 'V.\xa0P.\nNetgear',
#   'WORK_OF_ART': 'Ingram'},
#  'NETGEAR,INC_04_21_2003-EX-10.16-AMENDMENT TO THE DISTRIBUTOR AGREEMENT BETWEEN INGRAM MICRO AND NETGEAR-.pdf': {'PERSON': 'V.\xa0P.\nNetgear',
#   'CARDINAL': '7/15/98',
#   'GPE': 'Santa\xa0Clara',
#   'ORG': 'CA\xa092705\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#   'DATE': '1600',
#   'QUANTITY': '4\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0MARKETING\xa0PLAN',
#   'LAW': '"Amendment\xa0Date',
#   'ORDINAL': 'first',
#   'WORK_OF_ART': 'Ingram'},
#  'NETGEAR,INC_04_21_2003-EX-10.16-DISTRIBUTOR AGREEMENT.pdf': {'ORG': 'NETGEAR',
#   'GPE': 'INGRAM',
#   'DATE': '083096',
#   'PERSON': 'G.\xa0\xa0\xa0\xa0\xa0\xa0\xa0Neither',
#   'CARDINAL': '15',
#   'WORK_OF_ART': 'Trademarks',
#   'ORDINAL': 'first',
#   'NORP': 'D.',
#   'EVENT': 'RMA',
#   'TIME': 'hours',
#   'QUANTITY': '4\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0MARKETING\xa0PLAN'},
#  'WOMENSGOLFUNLIMITEDINC_03_29_2000-EX-10.13-ENDORSEMENT AGREEMENT - Intellectual Property Rights                 Confidentiality and Non-Use Obligations Agreement.pdf': {'CARDINAL': '302',
#   'ORG': 'Information',
#   'NORP': 'INTELLECTUAL',
#   'ORDINAL': 'first',
#   'PERSON': 'Kathy\xa0Whitworth',
#   'GPE': 'New\xa0Jersey',
#   'DATE': '87501',
#   'WORK_OF_ART': 'Intellectual\xa0Property',
#   'PRODUCT': 'A-1\n\xa0\xa0\xa011'},
#  'HEALTHGATEDATACORP_11_24_1999-EX-10.1-HOSTING AND MANAGEMENT AGREEMENT (1).pdf': {'CARDINAL': '2',
#   'DATE': '60 days',
#   'ORG': 'Download',
#   'GPE': 'Mathematica',
#   'WORK_OF_ART': 'Downloads of the material',
#   'FAC': 'HTML Email',
#   'PERSON': 'Max',
#   'TIME': '5:00 A.M.',
#   'NORP': 'Acrobat',
#   'PRODUCT': 'PUBLISHING                                       24',
#   'LAW': 'Article Title',
#   'ORDINAL': 'first',
#   'LOC': 'System Control',
#   'PERCENT': '50%',
#   'MONEY': '1.00',
#   'EVENT': 'the Initial Period',
#   'LANGUAGE': 'English',
#   'QUANTITY': '8mm'},
#  'HEALTHGATEDATACORP_11_24_1999-EX-10.1-HOSTING AND MANAGEMENT AGREEMENT - Escrow Agreement.pdf': {'CARDINAL': '242',
#   'ORG': 'Registered Office',
#   'PERSON': 'Licensee',
#   'GPE': 'UK',
#   'DATE': '2275',
#   'PRODUCT': 'M1 7ED',
#   'TIME': '12 hours',
#   'FAC': 'Package',
#   'EVENT': 'Malden MA 02148',
#   'MONEY': '4     Documentation',
#   'LOC': 'NCC',
#   'LAW': 'the Licence Agreement',
#   'WORK_OF_ART': 'England\nTelephone: +44',
#   'PERCENT': '100%',
#   'LANGUAGE': 'St(pound)5,000,000',
#   'QUANTITY': '1\n      cubic foot',
#   'ORDINAL': 'first'},
#  'FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT.pdf': {'CARDINAL': '0.10',
#   'ORG': 'Category of Services',
#   'DATE': 'the month',
#   'GPE': 'Pennsylvania',
#   'PRODUCT': 'Adviser',
#   'PERSON': 'Adviser',
#   'WORK_OF_ART': 'Applicable Margin',
#   'LAW': 'Section 5(b',
#   'ORDINAL': 'first'},
#  'FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_AMENDMENT.pdf': {'PERSON': 'J. Christopher Donahue',
#   'DATE': 'January 1, 2004',
#   'WORK_OF_ART': '2. Administration and Risk Management',
#   'ORG': 'FEDERATED INVESTMENT MANAGEMENT FEDERATED ADVISORY SERVICES COMPANY\nCOMPANY',
#   'GPE': 'RECITALS',
#   'PRODUCT': 'Adviser',
#   'LAW': 'the 1940 Act',
#   'CARDINAL': 'one',
#   'ORDINAL': 'first'},
#  'FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_POWEROF.pdf': {'ORG': 'Gartmore- Federated',
#   'DATE': '2-5 Years',
#   'PRODUCT': 'Adviser',
#   'PERSON': 'G. Andrew Bonnewell\nTitle',
#   'LAW': 'the Services Agreement',
#   'WORK_OF_ART': 'Federated Intermediate Corporate Bond Fund',
#   'CARDINAL': '1',
#   'GPE': 'Pennsylvania',
#   'ORDINAL': 'first'},
#  'FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_SECONDAMENDMENT.pdf': {'LAW': 'this Second Amendment',
#   'DATE': '4',
#   'ORG': 'FEDERATED INVESTMENT MANAGEMENT FEDERATED ADVISORY SERVICES COMPANY\nCOMPANY',
#   'GPE': 'Pennsylvania',
#   'PRODUCT': 'Adviser',
#   'PERSON': 'J. Christopher Donahue',
#   'WORK_OF_ART': 'Quantitative Analysis',
#   'CARDINAL': 'one',
#   'ORDINAL': 'first'},
#  'KUBIENT,INC_07_02_2020-EX-10.14-MASTER SERVICES AGREEMENT_Part1.pdf': {'DATE': 'five 5 days',
#   'EVENT': 'the "Effective Date',
#   'ORG': 'Global Products\nDate',
#   'CARDINAL': '02-05-2020',
#   'GPE': 'US',
#   'WORK_OF_ART': 'Confidential Information',
#   'FAC': 'Liberty Street',
#   'PERSON': 'Paul Caluori',
#   'ORDINAL': 'third',
#   'LOC': 'the Effective Date',
#   'PRODUCT': 'Agreement',
#   'LAW': 'section 3'},
#  'KUBIENT,INC_07_02_2020-EX-10.14-MASTER SERVICES AGREEMENT_Part2.pdf': {'WORK_OF_ART': 'Above Threshold',
#   'DATE': '2020',
#   'ORG': 'Taboola',
#   'PERSON': 'Ted Mendelsohn',
#   'ORDINAL': '26th',
#   'CARDINAL': '3/27/2020',
#   'PRODUCT': 'Agreement',
#   'LAW': 'Schedule 1',
#   'MONEY': '100,000.00',
#   'PERCENT': '50%',
#   'GPE': 'Nativo'},
#  'NEONSYSTEMSINC_03_01_1999-EX-10.5-DISTRIBUTOR AGREEMENT_Amendment.pdf': {'CARDINAL': '9',
#   'LAW': 'Section 15.12',
#   'DATE': 'the 1st day of January, 1999',
#   'ORG': 'Skunkware, Inc.',
#   'GPE': 'Texas',
#   'PERSON': 'Joe Backer',
#   'WORK_OF_ART': 'PBTC',
#   'MONEY': '10,000,000',
#   'EVENT': 'the Option Period',
#   'PERCENT': '10%',
#   'FAC': 'Southwest Freeway',
#   'ORDINAL': 'first',
#   'NORP': 'Offeree',
#   'LOC': 'Option'},
#  'NEONSYSTEMSINC_03_01_1999-EX-10.5-DISTRIBUTOR AGREEMENT_New.pdf': {'ORG': 'TERRITORY',
#   'LAW': 'Section 15.10  WAIVER',
#   'CARDINAL': '20',
#   'PRODUCT': 'Agreement',
#   'DATE': '14141',
#   'GPE': 'Licensor',
#   'PERSON': 'Territory',
#   'WORK_OF_ART': 'Redistributor',
#   'FAC': 'Southwest Freeway',
#   'ORDINAL': 'first',
#   'PERCENT': '5%',
#   'EVENT': 'Sublicense',
#   'TIME': 'overnight',
#   'MONEY': '17\n                                      ARTICLE'}}

# %%
def classify_clauses(text, entities):  
    clauses = {}  
    for entity, value in entities.items():  
        if entity in text:  
            clauses[entity] = text.split(entity)[1].split('.')[0]  # simple clause extraction  
    return clauses  
  
# Classify clauses for each document  
classified_clauses = {file: classify_clauses(text, entities[file]) for file, text in parsed_texts.items()}  
classified_clauses
# Out:
# {'CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.pdf': {'ORG': 'AN\n•\xa0CHASE\n•\xa0MANHATTAN\n•\xa0AARP\n•\xa0AMAZON',
#   'FAC': 'T\xa0THAT\xa0THIS\xa0AGREEMENT\xa0HAS\xa0BEEN\xa0DRAFTED\xa0BY\xa0CHASE,\xa0AND\xa0IT\xa0SHALL\nNOT\xa0ASSERT\xa0THAT\xa0THIS\xa0AGREEMENT\xa0IS\xa0UNENFORCEABLE\xa0OR\xa0INVALID\xa0ON\xa0THE\xa0GROUNDS\xa0THAT\xa0IT\xa0IS\xa0A\xa0CONTRACT\xa0OF\xa0ADHESION,\nTHAT\xa0IT\xa0IS\xa0UNCONSCIONABLE,\xa0OR\xa0ANY\xa0SIMILAR\xa0THEORY',
#   'TIME': '\xa0(DIRECTLY\xa0OR\nINDIRECTLY)\xa0SOLICIT\xa0CUSTOMER\xa0REFERRALS\xa0ON\xa0TERMS\xa0THAT\xa0MAY\xa0DIFFER\xa0FROM\xa0THOSE\xa0CONTAINED\xa0IN\xa0THIS\xa0AGREEMENT'},
#  'CybergyHoldingsInc_20140520_10-Q_EX-10.27_8605784_EX-10.27_Affiliate Agreement.pdf': {'DATE': ' OF SHIPMENT',
#   'PERSON': 'S\xa0–\xa0MA\xa0shall\xa0at\xa0all\xa0times\xa0have\xa0certified\xa0sales\xa0persons\xa0trained\xa0by\nCompany on staff in accordance with certain minimums defined by each Purchase Level'},
#  'DigitalCinemaDestinationsCorp_20111220_S-1_EX-10.10_7346719_EX-10.10_Affiliate Agreement.pdf': {'PERSON': ' OR ENTITY FOR ANY INDIRECT, INCIDENTAL, CONSEQUENTIAL, SPECIAL, PUNITIVE, \nEXEMPLARY, OR EXTRA-CONTRACTUAL DAMAGES OF ANY KIND WHATSOEVER ARISING FROM OR CONNECTED WITH THIS \nAGREEMENT, INCLUDING, BUT NOT LIMITED TO, LOST PROFITS, LOST REVENUES, OR LOSS OF BUSINESS, REGARDLESS OF LEGAL \nTHEORY, WHETHER OR NOT FORESEEABLE, EVEN IF EITHER PARTY HERETO HAS BEEN ADVISED OF THE POSSIBILITY OR \nPROBABILITY OF SUCH DAMAGES AND EVEN IF THE REMEDIES OTHERWISE PROVIDED BY THIS AGREEMENT FAIL OF THEIR \nESSENTIAL PURPOSE',
#   'PRODUCT': 'S, AND SERVICES, INCLUDING, WITHOUT LIMITATION, THE NCM PROPERTY, IS PROVIDED “AS IS”\xa0AND “WITH ALL \nFAULTS”\xa0AND NCM MAKES NO REPRESENTATIONS OR WARRANTIES, AND DISCLAIMS ALL REPRESENTATIONS AND \nWARRANTIES, EXPRESS OR IMPLIED, WRITTEN OR ORAL, ARISING FROM COURSE OF DEALING, COURSE OF PERFORMANCE, \nUSAGE OF TRADE, OR OTHERWISE INCLUDING, WITHOUT LIMITATION, THE IMPLIED WARRANTIES OF TITLE, NON-\nINFRINGEMENT, MERCHANTABILITY, AND FITNESS FOR A PARTICULAR PURPOSE',
#   'LOC': 'ATE THE \nRISKS OF THIS AGREEMENT BETWEEN THE PARTIES, SOME OF WHICH MAY BE UNKNOWN OR UNDERMINABLE',
#   'EVENT': ' SHALL EITHER PARTY BE LIABLE TO THE \nOTHER PARTY OR ANY OTHER PERSON OR ENTITY FOR ANY INDIRECT, INCIDENTAL, CONSEQUENTIAL, SPECIAL, PUNITIVE, \nEXEMPLARY, OR EXTRA-CONTRACTUAL DAMAGES OF ANY KIND WHATSOEVER ARISING FROM OR CONNECTED WITH THIS \nAGREEMENT, INCLUDING, BUT NOT LIMITED TO, LOST PROFITS, LOST REVENUES, OR LOSS OF BUSINESS, REGARDLESS OF LEGAL \nTHEORY, WHETHER OR NOT FORESEEABLE, EVEN IF EITHER PARTY HERETO HAS BEEN ADVISED OF THE POSSIBILITY OR \nPROBABILITY OF SUCH DAMAGES AND EVEN IF THE REMEDIES OTHERWISE PROVIDED BY THIS AGREEMENT FAIL OF THEIR \nESSENTIAL PURPOSE'},
#  'LinkPlusCorp_20050802_8-K_EX-10_3240252_EX-10_Affiliate Agreement.pdf': {'DATE': 'D JULY 15, 2005\n                               AFFILIATE AGREEMENT\n         This Agreement entered into as of the Effective Date by and between\nLink Plus Corporation and Axiometric, LLC',
#   'PERSON': 'S\n                  AFFECTED BY THIS AGREEMENT SPECIFICALLY WAIVE ALL RIGHT TO A\n                  TRIAL BY JURY AND SPECIFICALLY CONSENT TO THE '},
#  'SouthernStarEnergyInc_20051202_SB-2A_EX-9_801890_EX-9_Affiliate Agreement.pdf': {},
#  'SteelVaultCorp_20081224_10-K_EX-10.16_3074935_EX-10.16_Affiliate Agreement.pdf': {'EVENT': ' WILL \nEQUIDATA BE LIABLE FOR ANY INDIRECT, EXEMPLARY, PUNITIVE, SPECIAL, OR CONSEQUENTIAL DAMAGES \nINCLUDING WITHOUT LIMITATION LOST PROFITS OR OTHER ECONOMIC LOSS, LOST REIMBURSEMENTS, AND \nLOST DATA, OR FOR ANY CLAIM BY ANY THIRD PARTY',
#   'PRODUCT': ', SERVICE, LICENSE OR \nPERMISSION PROVIDED BY EQUIDATA UNDER THIS AGREEMENT IS PROVIDED ON AN “AS IS”\xa0BASIS'},
#  'TubeMediaCorp_20060310_8-K_EX-10.1_513921_EX-10.1_Affiliate Agreement.pdf': {'DATE': ':\xa0______________\nCHANNEL\xa0NUMBER:\xa0______________\n\xa0\n\xa0\n\xa0\nSIGNATURE:\nTITLE:\n',
#   'PERSON': 'AL\xa0PROPERTY)\xa0IN\xa0ANY\xa0CAUSE\xa0OF\xa0ACTION\nARISING\xa0OUT\xa0OF,\xa0RELATED\xa0TO,\xa0OR\xa0IN\xa0CONNECTION\xa0WITH\xa0A\xa0DEFAULT\xa0UNDER\xa0OR\xa0A\xa0BREACH\xa0OF\xa0THIS\xa0AGREEMENT'},
#  'UnionDentalHoldingsInc_20050204_8-KA_EX-10_3345577_EX-10_Affiliate Agreement.pdf': {},
#  'UsioInc_20040428_SB-2_EX-10.11_1723988_EX-10.11_Affiliate Agreement 2.pdf': {'LAW': ''},
#  '2ThemartComInc_19990826_10-12G_EX-10.10_6700288_EX-10.10_Co-Branding Agreement_ Agency Agreement.pdf': {'DATE': '" means the first date on which the\nCo-Branded Site is pointed to in all references to\ni-Escrow from 2TheMart auction site, and the\nInformation Transfer Mechanism is publicly\ndeployed (post-beta)',
#   'EVENT': ' OF A\nBREACH OF SECTION 11, NEITHER PARTY SHALL BE LIABLE FOR SPECIAL,\nINCIDENTAL OR CONSEQUENTIAL DAMAGES OR LOST PROFITS\n(HOWEVER ARISING, INCLUDING NEGLIGENCE) ARISING OUT OF OR IN\nCONNECTION WITH THIS AGREEMENT, EVEN IF THE PARTIES ARE\nAWARE OF THE POSSIBILITY OF SUCH DAMAGES',
#   'LAW': ''},
#  'DeltathreeInc_19991102_S-1A_EX-10.19_6227850_EX-10.19_Co-Branding Agreement_ Service Agreement.pdf': {},
#  'EbixInc_20010515_10-Q_EX-10.3_4049767_EX-10.3_Co-Branding Agreement.pdf': {'DATE': '" means the date on which the ebix Content is first displayed\n      to the public on the Insurance Center',
#   'MONEY': ' CHANNEL HOME PAGE" means the Web page that is displayed to the\n      About User when the URL HTTP://HOME'},
#  'EdietsComInc_20001030_10QSB_EX-10.4_2606646_EX-10.4_Co-Branding Agreement.pdf': {'EVENT': ' WILL EITHER PARTY\nBE LIABLE TO THE OTHER FOR ANY SPECIAL, INCIDENTAL, INDIRECT OR CONSEQUENTIAL\nDAMAGES, WHETHER BASED ON BREACH OF CONTRACT, TORT (INCLUDING NEGLIGENCE) OR\nOTHERWISE, WHETHER OR NOT THAT PARTY HAS BEEN ADVISED OF, KNEW, OR SHOULD HAVE\nKNOWN OF, THE POSSIBILITY OF SUCH DAMAGE AND NOTWITHSTANDING THE FAILURE OF\nESSENTIAL PURPOSE OF ANY LIMITED REMEDY',
#   'PRODUCT': 'ION GUIDELINES\nThe following are the Women',
#   'TIME': ' TO ENSURE NETWORK COMPATIBILITY:\n   o  JAVA\n   o  ENLIVEN\n   o  UNICAST\n   o  FLASH\nSource: EDIETS COM INC, 10QSB, 10/30/2000\nPlease check with ad production regarding other formats'},
#  'EmbarkComInc_19991008_S-1A_EX-10.10_6487661_EX-10.10_Co-Branding Agreement.pdf': {'LAW': '; FORUM SELECTION'},
#  'HealthcentralCom_19991108_S-1A_EX-10.27_6623292_EX-10.27_Co-Branding Agreement.pdf': {'LAW': '\nThis Agreement shall be governed by and interpreted and enforced in accordance\nwith the laws of the Province of Ontario and the Parties agree to abide by the\njurisdiction of the Courts of Ontario'},
#  'ImpresseCorp_20000322_S-1A_EX-10.11_5199234_EX-10.11_Co-Branding Agreement.pdf': {'DATE': ' shall mean the day on which the Co-Branded Site and the\nV-Solutions Area become fully operational and generally available on the\nInternet',
#   'FAC': 'E OR USER EXPERIENCE ASSOCIATED WITH THE\nVERTICALNET SITES AND RESERVES THE RIGHT, IN ITS SOLE DISCRETION, TO MODIFY THE\nPLACEMENT OF ALL LINKS, URLS AND PROPRIETARY FEATURES; PROVIDED, HOWEVER, THAT\nIN THE EVENT VERTICALNET REDESIGNS THE USER INTER',
#   'LAW': '',
#   'EVENT': ' VERTICALNET REDESIGNS THE USER INTERFACE, SUCH LINKS, URLS AND\nPROPRIETARY FEATURES SHALL RECEIVE MUTUALLY AGREEABLE PLACEMENT SUBSTANTIALLY\nSIMILAR TO THE ORIGINAL DESIGN'},
#  'IntegrityMediaInc_20010329_10-K405_EX-10.17_2373875_EX-10.17_Co-Branding Agreement.pdf': {'PRODUCT': ' DEVELOPMENT AND CO-BRANDING AGREEMENT\n                            "SONGS 4 WORSHIP SERIES"\n                         EXCLUDING CONFIDENTIAL PORTIONS\n/1/ Indicates information which has been redacted pursuant to a request for\n    confidential treatment'},
#  'InvendaCorp_20000828_S-1A_EX-10.2_2588206_EX-10.2_Co-Branding Agreement.pdf': {'TIME': ' GUARANTEE\n     a)   The Co-Branded Application shall not experience more than two outages\n          (unscheduled downtime) of more than two hours during any one month'},
#  'LeadersonlineInc_20000427_S-1A_EX-10.8_4991089_EX-10.8_Co-Branding Agreement.pdf': {'FAC': 'E\nOR USER EXPERIENCE ASSOCIATED WITH THE VERTICALNET SITES AND RESERVES THE RIGHT,\nIN ITS SOLE DISCRETION, TO MODIFY THE PLACEMENT OF ALL LINKS, URLS AND\nPROPRIETARY FEATURES; PROVIDED, HOWEVER, THAT IN THE EVENT VERTICALNET REDESIGNS\nTHE USER INTER',
#   'EVENT': ' VERTICALNET REDESIGNS\nTHE USER INTERFACE, SUCH LINKS, URLS AND PROPRIETARY FEATURES SHALL RECEIVE\nPLACEMENT SUBSTANTIALLY SIMILAR TO THE ORIGINAL DESIGN'},
#  'MphaseTechnologiesInc_20030911_10-K_EX-10.15_1560667_EX-10.15_Co-Branding Agreement.pdf': {},
#  'MusclepharmCorp_20170208_10-KA_EX-10.38_9893581_EX-10.38_Co-Branding Agreement.pdf': {'PRODUCT': 'S\n\xa0\nPromotional\xa0Products\xa0shall\xa0include\xa0the\xa0following\xa0products:\n·\nT-Shirts;\n·\nGolf\xa0Shirts;\n·\nHats;\n·\nVisors;\n·\nWristbands\xa0and\xa0Headbands;\xa0and\n·\nShakers'},
#  'NeoformaInc_19991202_S-1A_EX-10.26_5224521_EX-10.26_Co-Branding Agreement.pdf': {'FAC': 'SIMILES',
#   'PERSON': '      DESCRIPTION\n- --------------- -------- -------------- -------- ----------- ---------------- ------------------\n                                                            \nDAYE            FLD1     FLD2           FLDF     FLDH        FLDI             DESC\n- --------------- -------- -------------- -------- ----------- ---------------- ------------------\n(3) default is 7 days\n- --------------- --------------------- -------- ----------- ------------------ ------------------\nSELLER ID#      IMAGE LOCATION\n- --------------- --------------------- -------- ----------- ------------------ ------------------\n                                                               \nSELL            IMAG\n- --------------- --------------------- -------- ----------- ------------------ ------------------\n*Certain information on this page has been omitted and filed separately with the\n Commission',
#   'DATE': '/TIME(2)\n- ------------- ----------- -------------- ---------------- ------------------- ------------------\n                                                               \nFLDG          QNTY        MINB           RSRV             INCR                STRT\n- ------------- ----------- -------------- ---------------- ------------------- ------------------\n(1) default is [*]\n(2) default is today\n- --------------- -------- -------------- -------- ----------- ---------------- ------------------\nDURATION(3)     ITEM #   APPROX',
#   'LAW': '',
#   'LOC': 'ATION    SALESPERSON      DESCRIPTION\n- --------------- -------- -------------- -------- ----------- ---------------- ------------------\n                                                            \nDAYE            FLD1     FLD2           FLDF     FLDH        FLDI             DESC\n- --------------- -------- -------------- -------- ----------- ---------------- ------------------\n(3) default is 7 days\n- --------------- --------------------- -------- ----------- ------------------ ------------------\nSELLER ID#      IMAGE ',
#   'PRODUCT': 'S shall mean any equipment, instruments or other\nproducts used for scientific research and analysis in the field of human health\ncare, including, but not limited to, the categories of equipment, instruments\nand products listed on EXHIBIT A, (i) that is (a) previously used and is being\nresold by or on behalf of the prior end-user purchaser or (b) previously sold\nbut unused and is being resold by or on behalf of the prior end-user purchaser,\nand (ii) excluding Medical Products',
#   'QUANTITY': '    STARTING BID   RESERVE PRICE    BID INCREMENTS(1)   START DATE/TIME(2)\n- ------------- ----------- -------------- ---------------- ------------------- ------------------\n                                                               \nFLDG          QNTY        MINB           RSRV             INCR                STRT\n- ------------- ----------- -------------- ---------------- ------------------- ------------------\n(1) default is [*]\n(2) default is today\n- --------------- -------- -------------- -------- ----------- ---------------- ------------------\nDURATION(3)     ITEM #   APPROX',
#   'TIME': '(2)\n- ------------- ----------- -------------- ---------------- ------------------- ------------------\n                                                               \nFLDG          QNTY        MINB           RSRV             INCR                STRT\n- ------------- ----------- -------------- ---------------- ------------------- ------------------\n(1) default is [*]\n(2) default is today\n- --------------- -------- -------------- -------- ----------- ---------------- ------------------\nDURATION(3)     ITEM #   APPROX'},
#  'PaperexchangeComInc_20000322_S-1A_EX-10.4_5202103_EX-10.4_Co-Branding Agreement.pdf': {},
#  'PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement1.pdf': {'DATE': 'D OCTOBER 11, 1996\nSCHEDULE OF SERVICES AND FEES\n[***]\nBy:  PC Quote, Inc',
#   'PERCENT': 'AGE RATE of 12% on the outstanding balance',
#   'EVENT': ' WILL EITHER PARTY BE RESPONSIBLE FOR LOST PROFITS OR\nSPECIAL INDIRECT, INCIDENTAL OR CONSEQUENTIAL DAMAGES WHICH ABW OR PCQ INCUR\nOR EXPERIENCE ON ACCOUNT OF ENTERING INTO OR RELYING ON THIS AGREEMENT, EVEN\nIF PCQ OR ABW HAS BEEN ADVISED OF THE POSSIBILITY OF SUCH DAMAGES'},
#  'PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement2.pdf': {},
#  'PcquoteComInc_19990721_S-1A_EX-10.11_6377149_EX-10.11_Co-Branding Agreement3.pdf': {},
#  'RaeSystemsInc_20001114_10-Q_EX-10.57_2631790_EX-10.57_Co-Branding Agreement.pdf': {'PERCENT': 'AGE OF ADVERTISING REVENUE\n     5'},
#  'RandWorldwideInc_20010402_8-KA_EX-10.2_2102464_EX-10.2_Co-Branding Agreement.pdf': {'LAW': ' ANY RIGHT IT MAY HAVE\nTO A TRIAL BY JURY WITH RESPECT TO ANY ACTIONS OR PROCEEDINGS DIRECTLY OR\nINDIRECTLY ARISING OUT OF, UNDER OR IN CONNECTION WITH THIS AGREEMENT, OR THE\nTRANSACTIONS CONTEMPLATED HEREUNDER',
#   'EVENT': ' SHALL EITHER PARTY BE LIABLE TO THE OTHER FOR ANY\nINDIRECT, SPECIAL, INCIDENTAL, PUNITIVE OR CONSEQUENTIAL DAMAGES, LOSSES, OR\nEXPENSES INCLUDING, BUT NOT LIMITED TO, LOSS OF USE, LOSS OF PROFITS, OR LOSS OF\nGOODWILL, EVEN IF THAT PARTY HAS BEEN ADVISED OF THE POSSIBILITY OF SUCH LOSS OR\nDAMAGE'},
#  'StampscomInc_20001114_10-Q_EX-10.47_2631630_EX-10.47_Co-Branding Agreement.pdf': {'EVENT': ' WILL EITHER PARTY BE LIABLE FOR\nSource: STAMPS'},
#  'TheglobeComInc_19990503_S-1A_EX-10.20_5416126_EX-10.20_Co-Branding Agreement.pdf': {'EVENT': ' OF A CLAIM UNDER SECTION 10 OR FAILURE TO PAY UNDER SECTION\n6, IN NO ',
#   'TIME': ' MACHINE'},
#  'TomOnlineInc_20060501_20-F_EX-4.46_749700_EX-4.46_Co-Branding Agreement.pdf': {'DATE': '\xa0OF\xa0EXPIRATION\xa0OR\nTERMINATION\xa0HEREOF',
#   'PRODUCT': 'S,\xa0SERVICES\xa0OR\xa0WEB\xa0SITES\xa0WILL\xa0BE\xa0UNINTERRUPTED\xa0OR\nERROR-FREE,\xa0THAT\xa0DEFECTS\xa0WILL\xa0BE\xa0CORRECTED,\xa0AND\xa0THAT\xa0THE\xa0',
#   'LAW': ''},
#  'AimmuneTherapeuticsInc_20200205_8-K_EX-10.3_11967170_EX-10.3_Development Agreement.pdf': {'DATE': 'D AS OF FEBRUARY 4, 2020\nBY AND BETWEEN\nXENCOR, INC',
#   'LAW': ' OR OTHERWISE, ARE HEREBY EXPRESSLY EXCLUDED',
#   'GPE': 'x Technology, as defined in the\nUpstream Agreement, to the extent included within the Xencor Technology, or commit any act or permit the occurrence of any omission that would cause\nthe breach or termination of the Upstream Agreement, or otherwise knowingly take actions or permit omissions that would adversely affect the rights\ngranted to Aimmune hereunder with respect to the Xencor Patents and Xencor Know-How, or (b) without Aimmune’s prior written consent, amend or\notherwise modify or permit to be amended or modified, the Upstream Agreement in any respect that would adversely affect Aimmune’s rights with respect\nto, the Antibody or Products'},
#  'ArcaUsTreasuryFund_20200207_N-2_EX-99.K5_11971930_EX-99.K5_Development Agreement.pdf': {},
#  'ClickstreamCorp_20200330_1-A_EX1A-6 MAT CTRCT_12089935_EX1A-6 MAT CTRCT_Development Agreement.pdf': {'LAW': ''},
#  'CnsPharmaceuticalsInc_20200326_8-K_EX-10.1_12079626_EX-10.1_Development Agreement.pdf': {},
#  'CoherusBiosciencesInc_20200227_10-K_EX-10.29_12021376_EX-10.29_Development Agreement.pdf': {'FAC': 'TURING AND SUPPLY17\n6'},
#  'ConformisInc_20191101_10-Q_EX-10.6_11861402_EX-10.6_Development Agreement.pdf': {},
#  'ElPolloLocoHoldingsInc_20200306_10-K_EX-10.16_12041700_EX-10.16_Development Agreement.pdf': {'PERSON': 'AL JURISDICTION OVER THEM BY\nSUCH COURTS AND TO THE PROPRIETY OF VENUE OF SUCH COURTS FOR THE PURPOSE OF\nCARRYING OUT THE PROVISION, AND THEY WAIVE ANY OBJECTION THAT THEY WOULD\nOTHERWISE HAVE TO THE SAME',
#   'DATE': '',
#   'LAW': '; CHOICE OF FORUM; WAIVER OF JURY TRIAL',
#   'LOC': 'O® FRANCHISE DEVELOPMENT AGREEMENT\nDated: ____________________\nTerritory:\nDeveloper:\n(Disclosure Document Control No',
#   'EVENT': 'S OF DEFAULT'},
#  'EmeraldHealthBioceuticalsInc_20200218_1-A_EX1A-6 MAT CTRCT_11987205_EX1A-6 MAT CTRCT_Development Agreement.pdf': {},
#  'EtonPharmaceuticalsInc_20191114_10-Q_EX-10.1_11893941_EX-10.1_Development Agreement.pdf': {'FAC': 'TURE AND SUPPLY\n4',
#   'PRODUCT': ' DEVELOPMENT AGREEMENT\nTHIS EXCLUSIVE LICENSE AND '},
#  'FuelcellEnergyInc_20191106_8-K_EX-10.1_11868007_EX-10.1_Development Agreement.pdf': {'DATE': ']\nbetween ExxonMobil Research and Engineering Company (“ExxonMobil”) and FuelCell Energy, Inc',
#   'LAW': '\n17\nARTICLE 14 - ASSIGNMENT\n18\nARTICLE 15 - FORCE MAJEURE\n18\nARTICLE 16 - ADDRESSES AND NOTICES\n18\nARTICLE 17 - COMPLIANCE\n19\nARTICLE 18 - RECORDS AND AUDIT\n20\nARTICLE 19 - TAXES\n20\nARTICLE 20 - ADDITIONAL PROVISIONS\n20\nAPPENDIX A - DEFINITIONS\n24\nAPPENDIX B - SAMPLE PROJECT DESCRIPTION FORMAT\n30\nSource: FUELCELL ENERGY INC, 8-K, 11/6/2019\nJOINT DEVELOPMENT AGREEMENT\nThis Agreement is made as of the Effective Date between:\nExxonMobil Research and Engineering Company, a corporation of the State of Delaware having offices at 1545 Route 22 East,\nAnnandale, New Jersey 08801 (“ExxonMobil”); and\nFuelCell Energy, Inc',
#   'TIME': ' SCHEDULE:\nCommencement Date: ____________\nCompletion Date: ________________\n3'},
#  'HarpoonTherapeuticsInc_20200312_10-K_EX-10.18_12051356_EX-10.18_Development Agreement_Option Agreement.pdf': {'LAW': ', BY STATUTE OR OTHERWISE, AND EACH PARTY\nSPECIFICALLY DISCLAIMS ANY OTHER WARRANTIES, WHETHER WRITTEN OR ORAL, OR EXPRESS OR IMPLIED,\nINCLUDING ANY WARRANTY OF QUALITY, MERCHANTABILITY, OR FITNESS FOR A PARTICULAR USE OR\nPURPOSE OR ANY WARRANTY AS TO THE VALIDITY OF ANY PATENTS OR THE NON-INFRINGEMENT OF ANY\nINTELLECTUAL PROPERTY RIGHTS OF THIRD PARTIES',
#   'PRODUCT': 'S, EVEN IF ADVISED OF THE POSSIBILITY OF SUCH\nDAMAGES',
#   'FAC': 'T OR BY OPERATION OF LAW, BY STATUTE OR OTHERWISE, AND EACH PARTY\nSPECIFICALLY DISCLAIMS ANY OTHER WARRANTIES, WHETHER WRITTEN OR ORAL, OR EXPRESS OR IMPLIED,\nINCLUDING ANY WARRANTY OF QUALITY, MERCHANTABILITY, OR FITNESS FOR A PARTICULAR USE OR\nPURPOSE OR ANY WARRANTY AS TO THE VALIDITY OF ANY PATENTS OR THE NON-INFRINGEMENT OF ANY\nINTELLECTUAL PROPERTY RIGHTS OF THIRD PARTIES'},
#  'HfEnterprisesInc_20191223_S-1_EX-10.22_11931299_EX-10.22_Development Agreement.pdf': {},
#  'IbioInc_20200313_8-K_EX-10.1_12052678_EX-10.1_Development Agreement.pdf': {},
#  'LegacyEducationAllianceInc_20200330_10-K_EX-10.18_12090678_EX-10.18_Development Agreement.pdf': {},
#  'LiquidmetalTechnologiesInc_20200205_8-K_EX-10.1_11968198_EX-10.1_Development Agreement.pdf': {},
#  'NlsPharmaceuticsLtd_20200228_F-1_EX-10.14_12029046_EX-10.14_Development Agreement.pdf': {},
#  'PelicanDeliversInc_20200211_S-1_EX-10.3_11975895_EX-10.3_Development Agreement1.pdf': {},
#  'PelicanDeliversInc_20200211_S-1_EX-10.3_11975895_EX-10.3_Development Agreement2.pdf': {'LAW': ' AND VENUE\nThis Agreement will be governed by the laws of the State of Washington without regards for its conflict of laws principle'},
#  'PhasebioPharmaceuticalsInc_20200330_10-K_EX-10.21_12086810_EX-10.21_Development Agreement.pdf': {'PERSON': 'ALLY \nIDENTIFIABLE INFORMATION\n11',
#   'LAW': ' AND NOTWITHSTANDING\nANY PROVISION IN THIS AGREEMENT TO THE CONTRARY, NEITHER PARTY WILL BE LIABLE TO THE OTHER\nPARTY FOR ANY INDIRECT, INCIDENTAL, CONSEQUENTIAL, SPECIAL, RELIANCE OR PUNITIVE DAMAGES\nOR LOST OR IMPUTED PROFITS OR ROYALTIES OR COST OF PROCUREMENT OF SUBSTITUTE GOODS OR\nSERVICES, WHETHER LIABILITY IS ASSERTED IN CONTRACT, TORT (INCLUDING NEGLIGENCE AND STRICT\nPRODUCTS LIABILITY), INDEMNITY OR CONTRIBUTION, AND IRRESPECTIVE OF WHETHER THAT PARTY OR\nANY REPRESENTATIVE OF THAT PARTY HAS BEEN ADVISED OF, OR OTHERWISE MIGHT HAVE ANTICIPATED\nTHE POSSIBILITY OF, ANY SUCH LOSS OR DAMAGE',
#   'PRODUCT': '',
#   'EVENT': ' UNDER ARTICLE 6, OR ANY OTHER UNEARNED, SPECULATIVE OR OTHERWISE\nCONTINGENT PAYMENTS PROVIDED FOR IN THIS AGREEMENT'},
#  'ReedsInc_20191113_10-Q_EX-10.4_11888303_EX-10.4_Development Agreement.pdf': {'EVENT': ' SHALL EITHER PARTY BE LIABLE FOR CONSEQUENTIAL, INDIRECT,\nINCIDENTAL, SPECIAL, EXEMPLARY, PUNITIVE OR ENHANCED DAMAGES, LOST PROFITS OR REVENUES OR DIMINUTION IN VALUE\nARISING OUT OF, RELATING TO, OR IN CONNECTION WITH ANY BREACH OF THIS AGREEMENT OR CLAIM HEREUNDER, REGARDLESS\nOF (A) WHETHER SUCH DAMAGES WERE FORESEEABLE, (B) WHETHER OR NOT IT WAS ADVISED OF THE POSSIBLITY OF SUCH\nDAMAGES, AND (C) THE LEGAL OR EQUITABLE THEORY (CONTRACT, TORT OR OTHERWISE) UPON WHICH THE CLAIM IS BASED'},
#  'RevolutionMedicinesInc_20200117_S-1_EX-10.1_11948417_EX-10.1_Development Agreement.pdf': {'FAC': 'TURING AND SUPPLY\n7'},
#  'RitterPharmaceuticalsInc_20200313_S-4A_EX-10.54_12055220_EX-10.54_Development Agreement.pdf': {'PRODUCT': 'S OR THE OTHER\nSUBJECT MATTER OF THIS AGREEMENT'},
#  'VgrabCommunicationsInc_20200129_10-K_EX-10.33_11958828_EX-10.33_Development Agreement.pdf': {'DATE': '\nThis Agreement shall commence on 5th March 2019\nAGREEMENT PERIOD\nThis Agreement will be for the maximum period of six (6) months beginning for the commencement\ndate, renewable in accordance with the terms hereof, unless earlier terminated pursuant to this\nAgreement',
#   'FAC': 'T)',
#   'LANGUAGE': '\nThe English language shall be the medium used in all correspondence and legally binding tender'},
#  'FuseMedicalInc_20190321_10-K_EX-10.43_11575454_EX-10.43_Distributor Agreement.pdf': {},
#  'GentechHoldingsInc_20190808_1-A_EX1A-6 MAT CTRCT_11776814_EX1A-6 MAT CTRCT_Distributor Agreement.pdf': {'EVENT': ' SHALL EITHER PARTY BE LIABLE TO THE OTHER FOR ANY SPECIAL, INDIRECT, EXEMPLARY OR\nCONSEQUENTIAL DAMAGES ARISING OUT OF THIS AGREEMENT OR PURCHASE OR USE OF THE PRODUCTS',
#   'PRODUCT': 'S'},
#  'ImineCorp_20180725_S-1_EX-10.5_11275970_EX-10.5_Distributor Agreement.pdf': {'DATE': ' FIRST\nWRITTEN ABOVE',
#   'FAC': 'TURER',
#   'PRODUCT': ' SHALL BE\nPROVIDED BY THE COMPONENT MANUFACTURER',
#   'EVENT': ' SHALL JRVS’S LIABILITY ARISING OUT OF THIS AGREEMENT EXCEED\nTHE AMOUNT RECEIVED BY JRVS FROM THE DISTRIBUTOR HEREUNDER FOR THE PRODUCT GIVING RISE TO THE\nLIABILITY'},
#  'InnerscopeHearingTechnologiesInc_20181109_8-K_EX-10.6_11419704_EX-10.6_Distributor Agreement.pdf': {'PRODUCT': 'S'},
#  'PrecheckHealthServicesInc_20200320_8-K_EX-99.2_12070169_EX-99.2_Distributor Agreement.pdf': {},
#  'ScansourceInc_20190509_10-Q_EX-10.2_11661422_EX-10.2_Distributor Agreement.pdf': {'PRODUCT': 'S\n1'},
#  'ScansourceInc_20190822_10-K_EX-10.38_11793958_EX-10.38_Distributor Agreement1.pdf': {'LAW': 'S',
#   'PRODUCT': '\n13',
#   'FAC': 'TORY QUALITY, QUIET ENJOYMENT, ACCURACY, OR SYSTEM INTEGRATION, OR (B) ARISING\nFROM ANY COURSE OF DEALING, COURSE OF PERFORMANCE, OR USAGE IN THE INDUSTRY',
#   'EVENT': ' OF ANY SUCH INFRINGEMENT, MISAPPROPRIATION OR ANY CLAIM\nTHEREOF SHALL BE AS SET FORTH IN SECTION 15 OF THIS AGREEMENT ("PATENT AND COPYRIGHT INFRINGEMENT")',
#   'MONEY': ' PAID TO CISCO FOR PRODUCTS OR FOR SERVICES, SEPARATELY AND AS APPLICABLE, UNDER THIS AGREEMENT DURING THE\n[*****] PERIOD PRECEDING THE EVENT OR CIRCUMSTANCES FIRST GIVING RISE TO SUCH LIABILITY'},
#  'ScansourceInc_20190822_10-K_EX-10.38_11793958_EX-10.38_Distributor Agreement2.pdf': {'PRODUCT': ', YOU MAY RETURN THE\nENTIRE ',
#   'TIME': ' OF ACQUIRING SUCH\nCOPY OR UPGRADE, ALREADY HOLDS A VALID LICENSE TO THE ORIGINAL SOFTWARE AND HAS PAID THE APPLICABLE FEE FOR THE\nUPGRADE; (2) USE OF UPGRADES IS LIMITED TO CISCO EQUIPMENT FOR WHICH CUSTOMER IS THE ORIGINAL END USER PURCHASER\nOR LESSEE OR WHO OTHERWISE HOLDS A VALID LICENSE TO USE THE SOFTWARE WHICH IS BEING UPGRADED; AND (3) THE\nMAKING AND USE OF ADDITIONAL COPIES IS LIMITED TO NECESSARY BACKUP PURPOSES ONLY'},
#  'ScansourceInc_20190822_10-K_EX-10.39_11793959_EX-10.39_Distributor Agreement.pdf': {'DATE': ': 8/4/10 ',
#   'LAW': 'S, INCLUDING ANTI-CORRUPTION'},
#  'SmartRxSystemsInc_20180914_1-A_EX1A-6 MAT CTRCT_11351705_EX1A-6 MAT CTRCT_Distributor Agreement.pdf': {'LAW': ', ALL IMPLIED WARRANTIES, INCLUDING BUT NOT\nLIMITED TO IMPLIED WARRANTIES OF MERCHANTABILITY AND FITNESS FOR A PARTICULAR PURPOSE, ARE HEREBY EXCLUDED',
#   'PERSON': ', EXCEPT AS SET FORTH IN ANY COMPANY OR END USER\nLICENSE AGREEMENT FOR SUCH COMPANY PRODUCTS',
#   'PRODUCT': 'S OR AS TO SERVICE TO DISTRIBUTOR OR TO ANY OTHER PERSON, EXCEPT AS SET FORTH IN ANY COMPANY OR END USER\nLICENSE AGREEMENT FOR SUCH COMPANY '},
#  'StaarSurgicalCompany_20180801_10-Q_EX-10.37_11289449_EX-10.37_Distributor Agreement.pdf': {'LOC': 'AL STATUTES\nTHAT CANNOT BE EXCLUDED, RESTRICTED OR MODIFIED, NEITHER PARTY SHALL BE LIABLE FOR ANY INDIRECT, INCIDENTAL,\nCONSEQUENTIAL, PUNITIVE OR SPECIAL DAMAGES, OR FOR DAMAGES DUE TO LOSS OF PROFITS, LOSS OF BUSINESS, LOSS OF USE\nOR DATA, OR INTERRUPTION OF BUSINESS, EVEN IF SUCH PARTY HAS BEEN ADVISED OF THE POSSIBILITY OF SUCH DAMAGES'},
#  'WaterNowInc_20191120_10-Q_EX-10.12_11900227_EX-10.12_Distributor Agreement.pdf': {'LAW': 'S OF THE STATE OF TEXAS, U',
#   'PRODUCT': ' AND INVENTORY\n4'},
#  'ZogenixInc_20190509_10-Q_EX-10.2_11663313_EX-10.2_Distributor Agreement.pdf': {'DATE': '\nPatents claiming ZX008 or its use in Japan\nDocket No\nAppln',
#   'PRODUCT': ''},
#  'BerkshireHillsBancorpInc_20120809_10-Q_EX-10.16_7708169_EX-10.16_Endorsement Agreement.pdf': {'LAW': ''},
#  'BizzingoInc_20120322_8-K_EX-10.17_7504499_EX-10.17_Endorsement Agreement.pdf': {},
#  'EcoScienceSolutionsInc_20171117_8-K_EX-10.1_10956472_EX-10.1_Endorsement Agreement.pdf': {'PRODUCT': ' IS NOT INTENDED TO\nDIAGNOSE, TREAT, CURE OR PREVENT ANY DISEASE',
#   'EVENT': ' ANY DISEASE'},
#  'GridironBionutrientsInc_20171206_8-K_EX-10.1_10972555_EX-10.1_Endorsement Agreement.pdf': {'LAW': '; ARBITRATION\n \nThis Agreement shall be governed by, and its provisions enforced in accordance with, the laws of California without regard to its\nprinciples of conflicts of laws',
#   'EVENT': 'EEN'},
#  'GridironBionutrientsInc_20171206_8-K_EX-10.2_10972556_EX-10.2_Endorsement Agreement.pdf': {},
#  'LegacyEducationAllianceInc_20141110_8-K_EX-10.9_8828866_EX-10.9_Endorsement Agreement.pdf': {},
#  'LifewayFoodsInc_20160316_10-K_EX-10.24_9489766_EX-10.24_Endorsement Agreement.pdf': {},
#  'NakedBrandGroupInc_20150731_POS AM (on S-1)_EX-10.75_9196027_EX-10.75_Endorsement Agreement.pdf': {},
#  'PapaJohnsInternationalInc_20190617_8-K_EX-10.1_11707365_EX-10.1_Endorsement Agreement.pdf': {'EVENT': ' SHALL ABG’S, AUTHENTIC BRANDS GROUP LLC’S, AND CELEBRITY’S TOTAL LIABILITY UNDER THIS AGREEMENT\nEXCEED THE AMOUNTS ACTUALLY RECEIVED BY ABG (EXCLUSIVE OF REIUMBURSEMENT OF EXPENSES) HEREUNDER, REGARDLESS\nOF THE NUMBER OR TYPE OF CLAIMS',
#   'LAW': ', NEITHER\nABG NOR AUTHENTIC BRANDS GROUP LLC NOR CELEBRITY SHALL BE LIABLE TO PAPA JOHN’S FOR ANY CONSEQUENTIAL,\nINCIDENTAL, PUNITIVE, EXEMPLARY, OR SPECIAL DAMAGES, REGARDLESS OF THE FORM OR ACTION, WHETHER IN CONTRACT OR\nIN TORT, EVEN IF ABG OR AUTHENTIC BRANDS GROUP LLC HAS BEEN ADVISED OF THE POSSIBLITY OF SUCH DAMAGES OR LOSSES'},
#  'PerformanceSportsBrandsInc_20110909_S-1_EX-10.10_7220214_EX-10.10_Endorsement Agreement.pdf': {},
#  'PharmagenInc_20120803_8-KA_EX-10.1_7693204_EX-10.1_Endorsement Agreement.pdf': {'EVENT': ' \nANY DISEASE',
#   'PRODUCT': ' IS NOT INTENDED TO DIAGNOSE, TREAT, CURE OR PREVENT \nANY DISEASE'},
#  'PrudentialBancorpInc_20170606_8-K_EX-10.4_10474434_EX-10.4_Endorsement Agreement.pdf': {},
#  'ThriventVariableInsuranceAccountB_20190701_N-6_EX-99.D(IV)_11720968_EX-99.D(IV)_Endorsement Agreement.pdf': {},
#  'PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_Franchise Agreement1.pdf': {'LAW': '\n36\n25'},
#  'PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_Franchise Agreement3.pdf': {'PERSON': 'NEL)\nTHIS SAMPLE OF NON-DISCLOSURE AND NON-COMPETITION AGREEMENT (“Agreement”) is made this _____ day of\n_________, 20___, by and between ___________________________ (the “Franchisee”), and ___________________________, who is an\nofficer, director, or employee of Franchisee (the “Member”)'},
#  'RgcResourcesInc_20151216_8-K_EX-10.3_9372751_EX-10.3_Franchise Agreement.pdf': {'DATE': ''},
#  'SimplicityEsportsGamingCompany_20181130_8-K_EX-10.1_11444071_EX-10.1_Franchise Agreement.pdf': {},
#  'SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement1.pdf': {'DATE': '\xa0OF\xa0AGREEMENT\n\xa0\n\xa0\nSource: SOUPMAN, INC',
#   'PERSON': '\xa0NOT\xa0LISTED\xa0IN\xa0THIS\xa0AGREEMENT\xa0WHO\xa0IS\xa0A\xa0SPOUSE,\xa0PARTNER,\xa0AN\xa0OFFICER,\xa0DIRECTOR,\nSHAREHOLDER,\xa0GENERAL\xa0PARTNER\xa0OR\xa0MEMBER\xa0OF\xa0MASTER\xa0FRANCHISEE:\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nName:\n\xa0\n\xa0\n\xa0\n\xa0\nAddress:\n\xa0\n\xa0\n\xa0\nTelephone:\n\xa0\nRelationship:\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nName:\n\xa0\n\xa0\n\xa0\n\xa0\nAddress:\n\xa0\n\xa0\n\xa0\nTelephone:\n\xa0\nRelationship:\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nName:\n\xa0\n\xa0\n\xa0\n\xa0\nAddress:\n\xa0\n\xa0\n\xa0\nTelephone:\n\xa0\nRelationship:\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nName:\n\xa0\n\xa0\n\xa0\n\xa0\nAddress:\n\xa0\n\xa0\n\xa0\nTelephone:\n\xa0\nRelationship:\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nName:\n\xa0\n\xa0\n\xa0\n\xa0\nAddress:\n\xa0\n\xa0\n\xa0\nTelephone:\n\xa0\nRelationship:\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nName:\n\xa0\n\xa0\n\xa0\n\xa0\nAddress:\n\xa0\n\xa0\n\xa0\nTelephone:\n\xa0\nRelationship:\n\xa0\n\xa0\n\xa0\nSource: SOUPMAN, INC',
#   'LAW': '\n35\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n17'},
#  'SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement2.pdf': {},
#  'SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement3.pdf': {},
#  'SoupmanInc_20150814_8-K_EX-10.1_9230148_EX-10.1_Franchise Agreement4.pdf': {},
#  'Freecook_20180605_S-1_EX-10.3_11233807_EX-10.3_Hosting Agreement.pdf': {},
#  'PareteumCorp_20081001_8-K_EX-99.1_2654808_EX-99.1_Hosting Agreement.pdf': {'LAW': '\n\xa0\nThis\xa0Agreement\xa0shall\xa0be\xa0governed\xa0by\xa0and\xa0construed\xa0in\xa0all\xa0respects\xa0exclusively\xa0in\xa0accordance\xa0with\xa0the\xa0laws\xa0of\xa0the\xa0Netherlands'},
#  'QuantumGroupIncFl_20090120_8-K_EX-99.2_3672910_EX-99.2_Hosting Agreement.pdf': {},
#  'VitalibisInc_20180316_8-K_EX-10.2_11100168_EX-10.2_Hosting Agreement.pdf': {'DATE': '> (the "SOW Effective Date"), by and between VITALIBIS INC',
#   'LAW': ", VOTOCAST'S AGGREGATE LIABILITY ARISING FROM OR\nRELATING TO THIS AGREEMENT OR THE USE OR INABILITY TO USE THE SERVICES SHALL BE LIMITED TO THE AMOUNT OF ALL FEES\nACTUALLY RECEIVED BY VOTOCAST FROM LICENSEE UNDER THIS AGREEMENT"},
#  'ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf': {'DATE': '\nPATENT NUMBER\nISSUE ',
#   'ORG': 'ED HERITAGE\nPublished\n1,752,076\n26-Oct-15\nCA\nHydropel\nPending\n1917541\n30-Aug-18\nUS\nHydropel\nPending\n88148020\n9-Oct-18\nUS\nLOCK&FOLD\nRegistered\n76656450\n13-Mar-06\n3200208\n23-Jan-07\nUS\nMIDTOWN\nRegistered\n85736605\n24-Sep-12\n4401628\n10-Sep-13\nUS\nMILLWORK SQUARE\nRegistered\n86906649\n12-Feb-16\n5183008\n11-Apr-17\nCA\nMILLWORK SQUARE\nPublished\n1768051\n16-Feb-16\nCA\nORIGINAL RUSTICS\nPublished\n1791791\n18-Jul-16\nUS\nORIGINAL RUSTICS\nCLTM\nSource: ARMSTRONG FLOORING, INC',
#   'LOC': 'K&FOLD\nRegistered\n76656450\n13-Mar-06\n3200208\n23-Jan-07\nUS\nMIDTOWN\nRegistered\n85736605\n24-Sep-12\n4401628\n10-Sep-13\nUS\nMILLWORK SQUARE\nRegistered\n86906649\n12-Feb-16\n5183008\n11-Apr-17\nCA\nMILLWORK SQUARE\nPublished\n1768051\n16-Feb-16\nCA\nORIGINAL RUSTICS\nPublished\n1791791\n18-Jul-16\nUS\nORIGINAL RUSTICS\nCLTM\nSource: ARMSTRONG FLOORING, INC',
#   'EVENT': ' OF LITIGATION, SEEK TO ENFORCE THE FOREGOING\nWAIVER, (ii) EACH SUCH PARTY UNDERSTANDS AND HAS CONSIDERED THE IMPLICATIONS OF THIS WAIVER, (iii) EACH SUCH\nPARTY MAKES THIS WAIVER VOLUNTARILY, AND (iv) EACH SUCH PARTY HAS BEEN INDUCED TO ENTER INTO THIS\nAGREEMENT BY, AMONG OTHER THINGS, THE MUTUAL WAIVERS AND CERTIFICATIONS IN THIS SECTION 13',
#   'TIME': '\nPublished\n87261852\n8-Dec-16\nUS\nRUSTIC\nRESTORATIONS\nPublished\n87215879\n26-Oct-16\n5520272\n17-Jul-18\nCA\nRUSTIC\nRESTORATIONS\nPending\n1806462\n26-Oct-16\nUS\nSDF\nPending\n‘87947440\n4-Jun-18\nCA\nSDF\nPending\n1902212\n1-Jun-18\nSource: ARMSTRONG FLOORING, INC'},
#  'CerenceInc_20191002_8-K_EX-10.4_11827494_EX-10.4_Intellectual Property Agreement.pdf': {'LAW': ' AND STATUTORY CLAIMS'},
#  'GarrettMotionInc_20181001_8-K_EX-2.4_11364532_EX-2.4_Intellectual Property Agreement.pdf': {'LAW': ' AND STATUTORY CLAIMS'},
#  'RareElementResourcesLtd_20171019_SC 13D_EX-99.4_10897534_EX-99.4_Intellectual Property Agreement.pdf': {'PERSON': ' FOR OR ON ACCOUNT OF ANY INJURY, LOSS\nOR DAMAGE OF ANY KIND OR NATURE, SUSTAINED BY, OR ANY DAMAGES ASSESSED OR ASSERTED AGAINST, OR ANY OTHER\nLIABILITY INCURRED BY OR IMPOSED ON INVESTOR OR ANY OTHER ',
#   'EVENT': ' COMPANY, OR ITS OFFICERS, EMPLOYEES OR AGENTS, IS HELD LIABLE'},
#  'AlliedEsportsEntertainmentInc_20190815_8-K_EX-10.19_11788293_EX-10.19_Content License Agreement.pdf': {'EVENT': ' SHALL EITHER PARTY OR ITS\nOFFICERS, DIRECTORS, OR EMPLOYEES BE LIABLE TO THE OTHER PARTY IN CONNECTION WITH THE SUBJECT\nMATTER HEREOF, FOR ANY SPECIAL, INDIRECT, CONSEQUENTIAL OR PUNITIVE DAMAGES OF ANY KIND, LOST\nPROFITS OR LOST REVENUE, WHETHER ARISING IN CONTRACT, TORT, NEGLIGENCE, STATUTE, OR OTHERWISE, EVEN\nIF ADVISED OF THE POSSIBILITY THEREOF'},
#  'ArconicRolledProductsCorp_20191217_10-12B_EX-2.7_11923804_EX-2.7_Trademark License Agreement.pdf': {'LAW': ' EACH PARTY HEREBY IRREVOCABLY\nWAIVES ALL RIGHT OF TRIAL BY JURY IN ANY ACTION, PROCEEDING, CLAIM, OR COUNTERCLAIM ARISING OUT OF OR IN\nCONNECTION WITH THIS AGREEMENT OR ANY MATTER ARISING HEREUNDER',
#   'PRODUCT': 'S\nCORP'},
#  'ArtaraTherapeuticsInc_20200110_8-K_EX-10.5_11943350_EX-10.5_License Agreement.pdf': {'TIME': ' IN CONNECTION WITH THIS\nAGREEMENT, ARE MADE AVAILABLE TO ARTARA AS AN ACCOMMODATION, AND WITHOUT REPRESENTATION OR\nWARRANTY OF ANY KIND, WHETHER EXPRESS, IMPLIED OR STATUTORY, AS TO THE ACCURACY AND COMPLETENESS OF\nSUCH MATERIALS, DOCUMENTS, AND OTHER INFORMATION',
#   'LAW': ' AND SHALL NOT GIVE RISE TO ANY LIABILITY OF OR AGAINST THE UNIVERSITY',
#   'EVENT': ' SHALL EITHER PARTY BE LIABLE TO THE OTHER PARTY UNDER THIS AGREEMENT IN A\nDIRECT ACTION BETWEEN THE PARTIES FOR SPECIAL, INDIRECT, INCIDENTAL OR CONSEQUENTIAL DAMAGES (INCLUDING,\nWITHOUT LIMITATION, LOSS OF PROFITS) SUFFERED BY THE OTHER PARTY'},
#  'ChinaRealEstateInformationCorp_20090929_F-1_EX-10.32_4771615_EX-10.32_Content License Agreement.pdf': {},
#  'CytodynInc_20200109_10-Q_EX-10.5_11941634_EX-10.5_License Agreement.pdf': {'EVENT': ' WILL EITHER PARTY BE LIABLE TO THE OTHER PARTY (OR THE OTHER PARTY’S AFFILIATES OR\nSUBLICENSEES) IN CONNECTION WITH THIS AGREEMENT FOR LOST REVENUE, LOST PROFITS, LOST ROYALTIES, LOST SAVINGS, LOSS OF\nUSE, DAMAGE TO GOODWILL, OR ANY CONSEQUENTIAL, INCIDENTAL, SPECIAL, EXEMPLARY, PUNITIVE OR INDIRECT DAMAGES IN\nCONNECTION WITH THIS AGREEMENT, HOWEVER CAUSED, UNDER ANY THEORY OF LIABILITY, INCLUDING CONTRACT, NEGLIGENCE, OR\nSTRICT LIABILITY, EVEN IF THAT PARTY HAS BEEN PLACED ON NOTICE OF THE POSSIBILITY OF SUCH DAMAGES',
#   'LAW': ', BY STATUTE OR OTHERWISE, AND EACH PARTY SPECIFICALLY DISCLAIMS ANY\nOTHER WARRANTIES, INCLUDING ANY EXPRESS OR IMPLIED WARRANTY OF QUALITY, MERCHANTABILITY, FITNESS FOR A PARTICULAR\nPURPOSE, OR WARRANTY OF NON-INFRINGEMENT OR AS TO THE VALIDITY OF ANY PATENTS',
#   'PRODUCT': 'S IN ACCORDANCE WITH THE TERMS OF THIS\nAGREEMENT COULD CONSTITUTE DIRECT DAMAGES TO THE EXTENT AWARDED IN ACCORDANCE WITH ARTICLE 12',
#   'FAC': 'TURE AND SUPPLY\n6'},
#  'DataCallTechnologies_20060918_SB-2A_EX-10.9_944510_EX-10.9_Content License Agreement.pdf': {'LAW': '  AND  VENUE\n     10'},
#  'EuromediaHoldingsCorp_20070215_10SB12G_EX-10.B(01)_525118_EX-10.B(01)_Content License Agreement.pdf': {'DATE': ''},
#  'FulucaiProductionsLtd_20131223_10-Q_EX-10.9_8368347_EX-10.9_Content License Agreement.pdf': {},
#  'GlobalTechnologiesGroupInc_20050928_10KSB_EX-10.9_4148808_EX-10.9_Content License Agreement.pdf': {},
#  'GluMobileInc_20070319_S-1A_EX-10.09_436630_EX-10.09_Content License Agreement1.pdf': {'DATE': '\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nNOTE:\xa0This\xa0report\xa0is\xa0required\xa0to\xa0be\xa0filed\xa0whether\xa0or\xa0not\xa0there\xa0were\xa0any\xa0sales\xa0for\xa0the\xa0period',
#   'PERSON': 'AL\xa0INFORMATION\nInside\xa0the\xa0News\xa0America\xa0Group,\xa0we\xa0use\xa0personally\xa0identifiable\xa0information\xa0only\xa0in\xa0a\xa0manner\xa0consistent\xa0with\xa0these\xa0Privacy\xa0Principles',
#   'PRODUCT': 'S:\n(a)\xa0Development:\xa0Subject\xa0to\xa0Fox’s\xa0delivery\xa0of\xa0the\xa0PSM\xa0Materials\xa0(as\xa0defined\xa0in\xa0Paragraph\xa02(a)(i)\xa0below),\xa0Licensee\xa0shall\xa0be\xa0obligated\xa0to\xa0create,\ndevelop,\xa0and\xa0publish\xa0the\xa0Wireless\xa0Products,\xa0pursuant\xa0to\xa0the\xa0terms\xa0and\xa0conditions\xa0of\xa0this\xa0Agreement'},
#  'GluMobileInc_20070319_S-1A_EX-10.09_436630_EX-10.09_Content License Agreement2.pdf': {},
#  'GluMobileInc_20070319_S-1A_EX-10.09_436630_EX-10.09_Content License Agreement3.pdf': {},
#  'GluMobileInc_20070319_S-1A_EX-10.09_436630_EX-10.09_Content License Agreement4.pdf': {},
#  'GopageCorp_20140221_10-K_EX-10.1_8432966_EX-10.1_Content License Agreement.pdf': {'DATE': 'D, SPECIAL OR EXEMPLARY DAMAGES OR PENALTIES, INCLUDING WITHOUT\nLIMITATION, LOSSES OF BUSINESS, REVENUE OR ANTICIPATED PROFITS, REGARDLESS OF WHETHER SUCH DAMAGE WAS\nFORESEEABLE AND WHETHER LICENSOR HAS BEEN ADVISED OF THE POSSIBILITY OF SUCH DAMAGES'},
#  'GpaqAcquisitionHoldingsInc_20200123_S-4A_EX-10.6_11951677_EX-10.6_License Agreement.pdf': {},
#  'HertzGroupRealtyTrustInc_20190920_S-11A_EX-10.8_11816941_EX-10.8_Trademark License Agreement.pdf': {},
#  'IdeanomicsInc_20151124_8-K_EX-10.2_9354744_EX-10.2_Content License Agreement.pdf': {'LANGUAGE': '\xa0AND\xa0PROVISONS\xa0FOR\xa0THE\xa0PAYMENT\xa0OF\xa0PROFIT\xa0INTEREST,\xa0AUDIT\xa0RIGHTSS\xa0AND\xa0DISPUTE\xa0PROVISIONS'},
#  'IdeanomicsInc_20160330_10-K_EX-10.26_9512211_EX-10.26_Content License Agreement.pdf': {},
#  'LejuHoldingsLtd_20140121_DRS (on F-1)_EX-10.26_8473102_EX-10.26_Content License Agreement1.pdf': {},
#  'LejuHoldingsLtd_20140121_DRS (on F-1)_EX-10.26_8473102_EX-10.26_Content License Agreement2.pdf': {},
#  'MidwestEnergyEmissionsCorp_20080604_8-K_EX-10.2_3093976_EX-10.2_Content License Agreement.pdf': {'DATE': 'D\xa0June\xa02,\xa02008\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nDESCRIPTION\xa0OF\xa0CONTENT\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\nSupply\xa0Agreement\xa0for\xa0Content\xa0dated\xa0May\xa031,\xa02008\xa0among\xa0Yes\xa0Television\xa0(Hong\xa0Kong)\xa0Limited,\xa0New\xa0China\nMedia\xa0Limited\xa0and\xa0Youth\xa0Media\xa0"HKG"\xa0Limited,\xa0a\xa0copy\xa0of\xa0which\xa0is\xa0annexed\xa0hereto',
#   'EVENT': '\xa0WILL\xa0CONTENT\xa0PROVIDER\xa0BE\xa0\nLIABLE\xa0TO\xa0COMPANY\xa0NOR\xa0WILL\nCOMPANY\xa0BE\xa0LIABLE\xa0TO\xa0CONTENT\xa0PROVIDER\xa0FOR\xa0ANY\xa0\nSPECIAL,\xa0INCIDENTAL\nOR\xa0CONSEQUENTIAL\xa0DAMAGES,\xa0WHETHER\xa0BASED\xa0ON\xa0BREACH\xa0OF\xa0\nCONTRACT,\nTORT\xa0(INCLUDING\xa0NEGLIGENCE)\xa0OR\xa0OTHERWISE,\xa0WHETHER\xa0OR\xa0NOT\xa0THAT\xa0PARTY\nHAS\xa0BEEN\xa0ADVISED\xa0OF\xa0THE\xa0POSSIBILITY\xa0OF\xa0SUCH\xa0DAMAGE'},
#  'MorganStanleyDirectLendingFund_20191119_10-12GA_EX-10.5_11898508_EX-10.5_Trademark License Agreement.pdf': {'ORG': 'AN STANLEY DIRECT LENDING FUND, 10-12G/A, 11/19/2019\ndisputing the validity, enforceability or Licensor’s ownership of the Brand (and the associated goodwill), including without limitation, in any claim,\nallegation, action, demand, proceeding or suit (“Action”) regarding enforcement of this Agreement or involving any third party',
#   'LAW': ' OF THE STATE OF NEW YORK',
#   'LOC': 'ATED IN NEW YORK CITY FOR THE PURPOSE OF ANY ACTION\nRELATING TO OR ARISING OUT OF THIS AGREEMENT'},
#  'NmfSlfIInc_20200115_10-12GA_EX-10.5_11946987_EX-10.5_Trademark License Agreement.pdf': {'DATE': ' OF THIS AGREEMENT\nNEW MOUNTAIN FINANCE\nADVISERS BDC, L'},
#  'PacificapEntertainmentHoldingsInc_20051115_8-KA_EX-1.01_4300894_EX-1.01_Content License Agreement.pdf': {},
#  'PalmerSquareCapitalBdcInc_20200116_10-12GA_EX-10.6_11949289_EX-10.6_Trademark License Agreement.pdf': {},
#  'PhoenixNewMediaLtd_20110421_F-1_EX-10.17_6958322_EX-10.17_Content License Agreement.pdf': {'LAW': '; DISPUTE RESOLUTION \n\xa0 \n11'},
#  'PlayboyEnterprisesInc_20090220_10-QA_EX-10.2_4091580_EX-10.2_Content License Agreement_ Marketing Agreement_ Sales-Purchase Agreement1.pdf': {'EVENT': ' OF A BREACH OF SECTION 8 (CONFIDENTIALITY) OR \nLIABILITY ARISING UNDER A PARTY’S INDEMNIFICATION OBLIGATIONS UNDER SECTION 12, IN NO \n',
#   'PRODUCT': 'ION SCHEDULE \nStyle Out \n11/27/2007 \nMerchandiser \nSamples due Final \n12/5/2007 \nPhotography \n12/10/2007 \n12/14/2007 \nComplete \ntabletop pre pro \n12/7/2007 \nTableTop Photography \n12/10/2007 \n12/17/2007 \nCreative \nPage Building \n12/12/2007 \n12/25/2007 \nCreative \nSelects Review \n1/3/2008 \nMktng/Merch/Crtve \nProof One \n1/7/2008 \n1/11/2008 \nMktng/Merch \nProof one Revisions \n1/14/2008 \n1/16/2008 \nCreative \nProof Two \n1/16/2008 \n1/23/2008 \nMktng/Merch \nFinal Proof \n1/28/2008 \n2/1/2008 \nMktng/Merch \nRelease Pages \n2/4/2008 \n2/8/2008 \nSeparator \n46\nSource: PLAYBOY ENTERPRISES INC, 10-Q/A, 2/20/2009\n\xa0 \n \n\xa0 \n\xa0 \n \n47 \nProof Separations \n2/11/2008 \n2/15/2008 \nCreative/Separator \nFiles DUE to Printer \n2/21/2008 \nSeparator \nPrinter Proofs DUE \n2/22/2008 \nPrinter \nCorrection Due to Printer \n2/22/2008 \nCreative \nON PRESS \n2/25/2008 \nPrinter \nPRINTING SCHEDULES \nPaper DUE (40 Days Prior) \n2/20/2008 \nCreative \nPrint Order/Distrib'},
#  'PlayboyEnterprisesInc_20090220_10-QA_EX-10.2_4091580_EX-10.2_Content License Agreement_ Marketing Agreement_ Sales-Purchase Agreement2.pdf': {},
#  'RemarkHoldingsInc_20081114_10-Q_EX-10.24_2895649_EX-10.24_Content License Agreement.pdf': {'EVENT': '\xa0WILL\xa0EITHER\xa0PARTY\xa0BE\nLIABLE\xa0FOR\xa0SPECIAL,\xa0INCIDENTAL,\xa0CONSEQUENTIAL,\xa0INDIRECT\xa0OR\xa0PUNITIVE\xa0DAMAGES,\xa0OR\xa0LOST\nPROFITS,\xa0REGARDLESS\xa0OF\xa0WHETHER\xa0SUCH\xa0LIABILITY\xa0IS\xa0BASED\xa0ON\xa0BREACH\xa0OF\xa0CONTRACT,\nTORT,\xa0STRICT\xa0LIABILITY,\xa0BREACH\xa0OF\xa0WARRANTIES,\xa0FAILURE\xa0OF\xa0ESSENTIAL\xa0PURPOSE\xa0OR\nOTHERWISE\xa0AND\xa0EVEN\xa0IF\xa0ADVISED\xa0OF\xa0THE\xa0POSSIBILITY\xa0OF\xa0SUCH\xa0DAMAGES'},
#  'VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement.pdf': {'DATE': '” of this Agreement shall mean the date the last party hereto has executed this Agreement',
#   'FAC': 'TURE,\nUSE, OR SALE OF THE LICENSED PRODUCTS AND LICENSED SERVICES UNDER THIS AGREEMENT',
#   'PRODUCT': '(S)” as used herein in either singular or plural shall mean any material, compositions, or other product, the\nmanufacture, use or sale of which would constitute, but for the license granted to Company pursuant to this Agreement, an\ninfringement of a claim of PATENT RIGHT(S) (infringement shall include, but is not limited to, direct, contributory, or inducement\nto infringe)',
#   'EVENT': '\n4'},
#  'WatchitMediaInc_20061201_8-K_EX-10.1_4148672_EX-10.1_Content License Agreement.pdf': {},
#  'WebmdHealthCorp_20050908_S-1A_EX-10.7_1027007_EX-10.7_Content License Agreement.pdf': {'LOC': 'ATION\xa0OF\xa0RISK\xa0BETWEEN\xa0THE\xa0PARTIES,\xa0IS\xa0NOT\xa0A\xa0PENALTY,\xa0AND\xa0SHALL\xa0BE\xa0EXCLUSIVE'},
#  'XinhuaSportsEntertainmentLtd_20070221_F-1_EX-99.4_645553_EX-99.4_Content License Agreement.pdf': {'DATE': 'D 15TH DECEMBER 2001\n            CHINA ECONOMIC INFORMATION SERVICE OF XINHUA NEWS AGENCY\n                                       AND\n                        XINHUA FINANCIAL NETWORK LIMITED\n                                   ----------\n                            CONTENT LICENSE AGREEMENT\n               SUPPLEMENT TO THE EXCLUSIVE BROADCASTING AGREEMENT\n                                   ----------\n                                BAKER & McKENZIE\n                           14th Floor Hutchison House\n                                10 Harcourt Road\n                                    Hong Kong\n                                 Tel: 2846-1888\n                                 Fax: 2845-0476\n                                     CONTENT\nClause                                                                      Page\n------                                                                      ----\n                                                                         \n1',
#   'LAW': ' AND ARBITRATION\n16'},
#  'AtnInternationalInc_20191108_10-Q_EX-10.1_11878541_EX-10.1_Maintenance Agreement.pdf': {'FAC': 'ILITIES'},
#  'AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_Maintenance Agreement1.pdf': {'DATE': ':\n\xa0\nPAGE:\xa01\xa0/\xa01\nREPAIR\xa0ORDER\n(THIS\xa0FORM\xa0MUST\xa0BE\xa0ENCLOSED\xa0INSIDE\xa0THE\xa0BOX\xa0WITH\xa0THE\xa0UNIT)\n\xa0\nFROM:\n\xa0\n\xa0\n\xa0 TO\xa0(Shipping\xa0address):\n\xa0\nCOMPANY\xa0NAME\nSender:\n\xa0\nTel:\nFax:\n\xa0\n\xa0\n\xa0 ATR\xa0CUSTOMER\xa0SUPPORT\nc/o\xa0DHL\xa0Solutions\nZA\xa0du\xa0Pont\xa0Yblon\n95\xa0500\xa0Bonneuil\xa0en\xa0France\nFRANCE\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0 \xa0\n\xa0\nREPAIR\xa0ORDER\xa0NUMBER\xa0:\n\xa0\nDATA\xa0RELATED\xa0TO\xa0REMOVED\xa0UNIT\nA/C\nDATA\n\xa0 TYPE:\n\xa0\nMSN:\n\xa0 FH:\n\xa0 REGISTRATION:\n\xa0\n\xa0 CY:\nUNIT\nDATA\n\xa0 PART\xa0NUMBER:\n\xa0 TSN:\n\xa0 AMENDMENT:\n\xa0 CSN:\n\xa0 SERIAL\xa0NBR:\n\xa0 TSO:\n\xa0 DESIGNATION:PAGE:\n\xa0 CSO:\n\xa0\nWARRANTY\xa0COVERAGE\nINSTALLATION\xa0',
#   'PERSON': 'AL\xa0INJURY\xa0ARISING\xa0OUT\xa0OF\xa0NEGLIGENCE\xa0OR\xa0MISCONDUCT,,\xa0OR\xa0FOR\xa0ANY\xa0OTHER\nLIABILITY\xa0WHICH\xa0CANNOT\xa0BE\xa0EXCLUDED\xa0OR\xa0LIMITED\xa0BY\xa0LAW',
#   'QUANTITY': ',KG\n\xa0\n[*****]\n[*****]\n\xa0\nINDICATOR-FUEL\xa0',
#   'TIME': 'TER\xa0TRANSCEIVER\n\xa0\n[*****]\n[*****]\n\xa0\nRECEIVER-VOR/ILS/MKR\n\xa0\n[*****]\n[*****]\n\xa0\nT2CAS\xa0COMPUTER\n\xa0\n[*****]\n[*****]\n\xa0\nTRANSCEIVER-WEATHER\xa0RADAR\n\xa0\n[*****]\n[*****]\n\xa0\nVOR/ILS/MKR\xa0RECEIVER\n\xa0\n[*****]\n[*****]\n\xa0\nWX\xa0RADAR\xa0CONTROL\xa0PANEL\n\xa0\n[*****]\n[*****]\n\xa0\nTRANSMITTER/REGULATOR—OXYGEN\nPRESS\n\xa0\n[*****]\n[*****]\n\xa0\nDUCT-DISCHARGE\xa0DOWNSTREAM\xa0VALVE\n\xa0\n[*****]\n[*****]\n\xa0\nVALVE\xa0ASSY-SHUTOFF\n\xa0\n[*****]\n[*****]\n\xa0\nVALVE-XFEED,AIR\xa0BLEED\n\xa0\n[*****]\n[*****]\n\xa0\nCAC\xa0SWM\n\xa0\n[*****]\n[*****]\n\xa0\nCORE\xa0AVIONICS\xa0CABINET\xa0I/P\xa0O/P\xa0MODULE\nAP\n\xa0\n[*****]\n[*****]\n\xa0\nCORE\xa0AVIONICS\xa0CABINET\xa0I/P\xa0O/P\xa0MODULE-S\xa0\n[*****]\n[*****]\n\xa0\nCORE\xa0AVIONICS\xa0CABINET\xa0I/P\xa0O/P\xa0MODULE-\nDC\n\xa0\n[*****]\n[*****]\n\xa0\nINTEGRATED\xa0CORE\xa0PROCESSING\n\xa0\n[*****]\n\xa0\nMODULE\n\xa0\n[*****]\n\xa0\n[*****]\xa0Confidential\xa0material\xa0redacted\xa0and\xa0filed\xa0separately\xa0with\xa0the\xa0Securities\xa0and\xa0Exchange\xa0Commission',
# ...
#  'VnueInc_20150914_8-K_EX-10.1_9259571_EX-10.1_Promotion Agreement.pdf': {},
#  'BravatekSolutionsInc_20170418_8-K_EX-10.1_10205739_EX-10.1_Reseller Agreement.pdf': {},
#  'EhaveInc_20190515_20-F_EX-4.44_11678816_EX-4.44_License Agreement_ Reseller Agreement.pdf': {},
#  'HealthcareIntegratedTechnologiesInc_20190812_8-K_EX-10.1_11776966_EX-10.1_Reseller Agreement.pdf': {'PRODUCT': 'S ARE PROVIDED ON AN “AS IS” AND “AS AVAILABLE” BASIS, AND\nSUPPLIER DOES NOT MAKE ANY WARRANTIES, EXPRESS OR IMPLIED, WITH RESPECT TO THE\n',
#   'LAW': ', IN NO EVENT SHALL SUPPLIER BE\nLIABLE UNDER, OR OTHERWISE IN CONNECTION WITH, THIS AGREEMENT FOR: (A) ANY\nCONSEQUENTIAL, INDIRECT, SPECIAL, INCIDENTAL, OR PUNITIVE DAMAGES; (B) ANY LOSS OF\nPROFITS, LOSS OF BUSINESS, LOSS OF REVENUE, OR LOSS OF ANTICIPATED SAVINGS; (C) ANY LOSS\nOF, OR DAMAGE TO, DATA, REPUTATION, OR GOODWILL; AND/OR (D) THE COST OF PROCURING\nANY SUBSTITUTE GOODS OR SERVICES'},
#  'IpassInc_20181203_8-K_EX-99.1_11445874_EX-99.1_Reseller Agreement.pdf': {'DATE': ' OR TIME OR WILL HAVE THE CAPACITY TO MEET CHANNEL PARTNER’S OR END USER DEMAND DURING SPECIFIC\nHOURS',
#   'FAC': 'TION OF THIS LIMIT, AND MULTIPLE\nCLAIMS WILL NOT ENLARGE THE LIMIT',
#   'PERSON': 'AL\nINJURY OR DEATH, OR DAMAGE TO TANGIBLE PROPERTY CAUSED BY THE PARTY’S NEGLIGENT OR WILLFUL MISCONDUCT; AND (B)\nPROVEN DIRECT DAMAGES FOR ANY AND ALL CLAIMS ARISING FROM OR IN CONNECTION WITH OR RELATING TO THIS\nAGREEMENT OR THE LICENSED SOFTWARE OR SERVICES, NOT TO EXCEED AN AMOUNT EQUAL TO THE AMOUNT OF FEES\nACTUALLY PAID BY CHANNEL PARTNER TO IPASS DURING THE SIX (6) MONTHS PRECEDING THE FIRST EVENT GIVING RISE TO SUCH\nLIABILITY',
#   'LAW': ',\nSERVICES ARE PROVIDED ON AN “AS IS” AND “AS AVAILABLE” BASIS, AND CHANNEL PARTNER, IPASS AND THEIR SUPPLIERS\nDISCLAIM AND MAKE NO REPRESENTATIONS OR WARRANTIES AND THERE ARE NO CONDITIONS OF ANY KIND, EITHER EXPRESS,\nIMPLIED OR STATUTORY, INCLUDING BUT NOT LIMITED TO ANY WARRANTIES OF NON-INTERFERENCE, MERCHANTABILITY, FITNESS\nFOR A PARTICULAR PURPOSE OR USE, OR ARISING FROM COURSE OF DEALING OR USAGE OF TRADE',
#   'EVENT': ' GIVING RISE TO SUCH\nLIABILITY',
#   'TIME': 'LY, SECURE, ERROR FREE, AVAILABLE ON A\nSPECIFIED DATE OR '},
#  'SalesforcecomInc_20171122_10-Q_EX-10.1_10961535_EX-10.1_Reseller Agreement.pdf': {},
#  'GpaqAcquisitionHoldingsInc_20200123_S-4A_EX-10.8_11951679_EX-10.8_Service Agreement.pdf': {'PRODUCT': 'S & SERVICES\n1'},
#  'IntegrityFunds_20200121_485BPOS_EX-99.E UNDR CONTR_11948727_EX-99.E UNDR CONTR_Service Agreement.pdf': {},
#  'ReynoldsConsumerProductsInc_20200121_S-1A_EX-10.22_11948918_EX-10.22_Service Agreement.pdf': {'PRODUCT': 'S INC',
#   'EVENT': ' SHALL ANY PARTY BE LIABLE TO THE OTHER PARTY FOR ANY INDIRECT, SPECIAL, EXEMPLARY, PUNITIVE OR\nCONSEQUENTIAL DAMAGES, OR LOST PROFITS OR LOST REVENUES THAT THE OTHER PARTY MAY INCUR BY REASON OF ITS HAVING\nENTERED INTO OR RELIED UPON THIS AGREEMENT, OR IN CONNECTION WITH ANY OF THE SERVICES PROVIDED HEREUNDER OR THE\nFAILURE THEREOF, REGARDLESS OF THE FORM OF ACTION IN WHICH SUCH DAMAGES ARE ASSERTED, WHETHER IN CONTRACT OR\nTORT (INCLUDING NEGLIGENCE) OR OTHERWISE, EVEN IF ADVISED OF THE POSSIBILITY OF THE SAME OTHER THAN TO THE EXTENT\nAWARDED IN A THIRD PARTY CLAIM'},
#  'VerizonAbsLlc_20200123_8-K_EX-10.4_11952335_EX-10.4_Service Agreement.pdf': {'LAW': '\n45\nSection 10'},
#  'AlliedEsportsEntertainmentInc_20190815_8-K_EX-10.34_11788308_EX-10.34_Sponsorship Agreement.pdf': {'EVENT': ' SPONSORSHIP AGREEMENT\nThis Event Sponsorship Agreement ("Agreement”) is made and effective as of February 1, 2019 (the “Effective Date”), by and between Newegg\nInc',
#   'PRODUCT': 'S,\nWHETHER IN CONTRACT, TORT, STRICT LIABILITY OR OTHERWISE, EVEN IF THE PARTY HAS BEEN ADVISED, KNOWS OR SHOULD\nKNOW, OR IS OTHERWISE AWARE OF THE POSSIBILITY OF SUCH DAMAGES'},
#  'ArcGroupInc_20171211_8-K_EX-10.1_10976103_EX-10.1_Sponsorship Agreement.pdf': {},
#  'EcoScienceSolutionsInc_20180406_8-K_EX-10.1_11135398_EX-10.1_Sponsorship Agreement.pdf': {},
#  'FreezeTagInc_20180411_8-K_EX-10.1_11139603_EX-10.1_Sponsorship Agreement.pdf': {},
#  'AgapeAtpCorp_20191202_10-KA_EX-10.1_11911128_EX-10.1_Supply Agreement.pdf': {'ORG': 'ANIC PREPARATIONS INC',
#   'FAC': 'TURER\n3',
#   'LAW': '\nThis agreement shall be governed by the Laws of England (English common and statutory Law)'},
#  'LohaCompanyltd_20191209_F-1_EX-10.16_11917878_EX-10.16_Supply Agreement.pdf': {'DATE': ' OF SHIPMENT: According to specific order by YICHANGTAI or LEHEYUAN'},
#  'ReynoldsConsumerProductsInc_20191115_S-1_EX-10.18_11896469_EX-10.18_Supply Agreement.pdf': {'PRODUCT': 'S\nLLC, a Delaware limited liability company with its headquarters at 1900 West Field Court, Lake Forest, IL 60045 (“Seller”), and PACTIV LLC, a Delaware\nlimited liability company with its headquarters at 1900 West Field Court, Lake Forest, IL 60045 (“Buyer”)'},
#  'WestPharmaceuticalServicesInc_20200116_8-K_EX-10.1_11947529_EX-10.1_Supply Agreement.pdf': {'LAW': ' AND REGULATION\nThe Parties represent, warrant and undertake to each other on a continuous basis that they shall comply with all applicable anti-bribery and anti-\nmoney laundering laws, rules, and regulations of any government, including the U',
#   'PERSON': "S RELATING IN ANY WAY TO THE USE OF SUCH CAR(S), TRUCK(S) AND\nBARGE(S) WHILE SUCH ARE IN BUYER'S POSSESSION",
#   'LOC': 'ATIONS OF SUPPLY\nBuyer/Buyer Affiliates that may purchase Product from ExxonMobil Selling Affiliates are listed in Attachment C',
#   'DATE': ' OF:\nExxon Mobil Corporation\nJanuary 10, 2020\nDate: December 11, 2018\n/s/ Eric M',
#   'PRODUCT': 'S, QUANTITY, PRICE\nIn accordance with the provisions of this Agreement, ExxonMobil Selling Affiliates agree to sell to Buyer Affiliates, and Buyer Affiliates agree to\npurchase from ExxonMobil Selling Affiliates, the following product(s) (collectively, "Product"):\nProducts\nQuantity [Metric Tons / Year]\nContainer\nPackage\nYear\n2019\n2020\n2021\n2022\n2023\n[*****]\n[*****]\nMinimum\nMaximum\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\nLeased metal crates\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\nLeased metal crates\n[*****]\nnot defined\nLeased metal crates\nSubject to this Agreement\'s terms and conditions, Buyer Affiliates shall purchase and ExxonMobil Selling Affiliates shall sell the yearly minimum\namount of Product amounts (in the aggregate) listed above',
#   'QUANTITY': ', PRICE\nIn accordance with the provisions of this Agreement, ExxonMobil Selling Affiliates agree to sell to Buyer Affiliates, and Buyer Affiliates agree to\npurchase from ExxonMobil Selling Affiliates, the following product(s) (collectively, "Product"):\nProducts\nQuantity [Metric Tons / Year]\nContainer\nPackage\nYear\n2019\n2020\n2021\n2022\n2023\n[*****]\n[*****]\nMinimum\nMaximum\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\nLeased metal crates\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\n[*****]\nLeased metal crates\n[*****]\nnot defined\nLeased metal crates\nSubject to this Agreement\'s terms and conditions, Buyer Affiliates shall purchase and ExxonMobil Selling Affiliates shall sell the yearly minimum\namount of Product amounts (in the aggregate) listed above',
#   'EVENT': ' EXCEED THE PURCHASE PRICE OF PRODUCT IN RESPECT TO\nWHICH SUCH CAUSE AROSE',
#   'TIME': ' AND DEMURRAGE\nBuyer shall unload tank containers, cars, trucks and barges furnished by Seller and clear products from port, or at delivery destination, within the\nfree time specified by tariffs or time periods on file with applicable bodies, or promptly after receipt if no such tariffs or time periods are on file'},
#  'PenntexMidstreamPartnersLp_20150416_S-1A_EX-10.4_9042833_EX-10.4_Transportation Agreement.pdf': {},
#  'RangeResourcesLouisianaInc_20150417_8-K_EX-10.5_9045501_EX-10.5_Transportation Agreement.pdf': {'DATE': '\xa0OF\xa0THIS\xa0AGREEMENT',
#   'FAC': 'ILITIES\n7',
#   'PRODUCT': '\xa0INTERESTS\n9',
#   'TIME': '\xa0FOR\xa0FILING\n\xa014\xa0\n19',
#   'LOC': 'AL\xa0TARIFF\nCONTAINING\xa0RATES,\xa0RULES,\xa0AND\xa0REGULATIONS\nGOVERNING\xa0THE\xa0TRANSPORTATION\nOF\nNATURAL\xa0GAS\xa0LIQUIDS\nBY\xa0PIPELINE\n\xa0\n\xa0\nThe\xa0provisions\xa0published\xa0herein\xa0will,\xa0if\xa0effective,\xa0not\xa0result\xa0in\xa0an\xa0effect\xa0on\xa0the\xa0quality\xa0of\xa0human\xa0environment',
#   'LAW': 'S\n15',
#   'EVENT': '\xa0SHALL\xa0EITHER\xa0PARTY\xa0BE\xa0LIABLE\xa0TO\nTHE\xa0OTHER\xa0PARTY\xa0OR\xa0ITS\xa0AFFILIATES,\xa0ANY\xa0SUCCESSORS\xa0IN\xa0INTEREST\xa0OR\xa0ANY\xa0BENEFICIARY\xa0OR\xa0ASSIGNEE\xa0OF\xa0THIS\xa0AGREEMENT\nFOR\xa0ANY\xa0CONSEQUENTIAL,\xa0MULTIPLE,\xa0INCIDENTAL,\xa0INDIRECT,\xa0SPECIAL,\xa0EXEMPLARY\xa0OR\xa0PUNITIVE\xa0DAMAGES,\xa0OR\xa0LOSS\xa0OF\nPROFITS\xa0OR\xa0REVENUES\xa0ARISING\xa0OUT\xa0OF\xa0OR\xa0RELATING\xa0TO\xa0THIS\xa0AGREEMENT\xa0OR\xa0ANY\xa0BREACH\xa0HEREOF;\xa0PROVIDED,\xa0HOWEVER,\nTHE\xa0FOREGOING\xa0SHALL\xa0NOT\xa0BE\xa0CONSTRUED\xa0AS\xa0LIMITING\xa0AN\xa0OBLIGATION\xa0OF\xa0A\xa0PARTY\xa0HEREUNDER\xa0TO\xa0INDEMNIFY,\xa0DEFEND\xa0AND\nHOLD\xa0HARMLESS\xa0THE\xa0OTHER\xa0PARTY\xa0AGAINST\xa0CLAIMS\xa0ASSERTED\xa0BY\xa0UNAFFILIATED\xa0THIRD\xa0PARTIES,\xa0INCLUDING,\xa0BUT\xa0NOT\nLIMITED\xa0TO,\xa0THIRD\xa0PARTY\xa0CLAIMS\xa0FOR\xa0SPECIAL,\xa0INDIRECT,\xa0CONSEQUENTIAL,\xa0PUNITIVE\xa0OR\xa0EXEMPLARY\xa0DAMAGES'},
#  'TcPipelinesLp_20160226_10-K_EX-99.12_9454048_EX-99.12_Transportation Agreement.pdf': {'DATE': ': November 01, 2016 \n2',
#   'QUANTITY': ' (Dth/Day): 101,300\nPlease see Appendix A for further detail'},
#  'ZtoExpressCaymanInc_20160930_F-1_EX-10.10_9752871_EX-10.10_Transportation Agreement.pdf': {},
#  'OLDAPIWIND-DOWNLTD_01_08_2016-EX-1.3-AGENCY AGREEMENT1.pdf': {'FAC': '”); and the Corporation will not directly or indirectly use\nthe proceeds of this Offering, or lend, contribute or otherwise make available such proceeds to any subsidiary, joint venture\npartner or other person or entity, for the purpose of financing the activities of any person currently subject to any United\nStates sanctions administered by O',
#   'LAW': 'S\nAs used in this Schedule and related exhibits, the following terms shall have the meanings indicated:\n(a)\n“Accredited Investors” means institutions that are “accredited investors” meeting the criteria set forth in Rule 501(a) of\nRegulation D;\n(b)\n“Directed Selling Efforts” means “directed selling efforts” as that term is defined in Rule 902(c) of Regulation S, which,\nwithout limiting the foregoing, but for greater clarity in this Schedule, includes, subject to the exclusions from the definition\nof directed selling efforts contained in Regulation S, any activity undertaken for the purpose of, or that could reasonably be\nexpected to have the effect of, conditioning the market in the United States for any of the Offered Shares and includes the\nplacement of any advertisement in a publication with a general circulation in the United States that refers to the offering of\nthe Offered Shares;\n(c)\n“Foreign Issuer” means “foreign issuer” as that term is defined in Rule 902(e) of Regulation S;\n(d)\n“General Solicitation” and “General Advertising” means “general solicitation” and “general advertising”, respectively, as\nused in Rule 502(c) of Regulation D, including advertisements, articles, notices or other communications published in any\nnewspaper, magazine or similar media or the internet or broadcast over radio or television or the internet, or any seminar or\nmeeting whose attendees had been invited by general solicitation or general advertising;\n(e)\n“Offshore Transaction” means an “offshore transaction” as that term is defined in Rule 902(h) of Regulation S;\n(f)\n“Regulation D” means Regulation D adopted by the SEC under the U'},
#  'OLDAPIWIND-DOWNLTD_01_08_2016-EX-1.3-AGENCY AGREEMENT2.pdf': {'LAW': 'S)\nAGENTS’ CERTIFICATE\nIn connection with the offer and sale in the United States of common shares (the “Securities”) of Tribute Pharmaceuticals Inc'},
#  'BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1).pdf': {},
#  'BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT - First Amendment.pdf': {},
#  'NETGEAR,INC_04_21_2003-EX-10.16- AMENDMENT #2 TO THE DISTRIBUTION AGREEMENT.pdf': {},
#  'NETGEAR,INC_04_21_2003-EX-10.16-AMENDMENT TO THE DISTRIBUTOR AGREEMENT BETWEEN INGRAM MICRO AND NETGEAR-.pdf': {'LAW': '\nThis\xa0Agreement,\xa0including\xa0its\xa0attachment\xa0and\xa0order\xa0acknowledgments\xa0under\xa0the\nAgreement,\xa0constitutes\xa0the\xa0entire\xa0agreement\xa0between\xa0Distributor\xa0and\xa0NETGEAR\xa0with\nrespect\xa0to\xa0the\xa0purchase,\xa0resale\xa0and\xa0distribution\xa0of\xa0the\xa0Products\xa0and\xa0is\xa0governed\nby\xa0the\xa0laws\xa0of\xa0the\xa0State\xa0of\xa0California\xa0except\xa0that\xa0body\xa0of\xa0law\xa0dealing\xa0with\nconflicts\xa0of\xa0law'},
#  'NETGEAR,INC_04_21_2003-EX-10.16-DISTRIBUTOR AGREEMENT.pdf': {'EVENT': '\xa0WILL\xa0EITHER\xa0PARTY\xa0OR\xa0THEIR\xa0RESPECTIVE\xa0PARENT\xa0CORPORATIONS\xa0OR\nSUPPLIERS\xa0BE\xa0LIABLE\xa0FOR\xa0(1)\xa0THE\xa0COST\xa0OF\xa0SUBSTITUTE\xa0PROCUREMENT,\xa0SPECIAL,\nINDIRECT,\xa0INCIDENTAL,\xa0OR\xa0CONSEQUENTIAL\xa0DAMAGES,\xa0OR\xa0(2)\xa0ANY\xa0DAMAGES\xa0RESULTING\nFROM\xa0INACCURATE\xa0OR\xa0LOST\xa0DATA\xa0OR\xa0LOSS\xa0OF\xa0USE\xa0OR\xa0PROFITS\xa0ARISING\xa0OUT\xa0OF\xa0OR\xa0IN\nCONNECTION\xa0WITH\xa0THIS\xa0AGREEMENT,\xa0THE\xa0FURNISHING\xa0OF\xa0SERVICES,\xa0OR\xa0THE\xa0USE\xa0OR\nPERFORMANCE\xa0OF\xa0PRODUCTS,\xa0EVEN\xa0IF\xa0INFORMED\xa0OF\xa0SUCH\xa0DAMAGES'},
#  'WOMENSGOLFUNLIMITEDINC_03_29_2000-EX-10.13-ENDORSEMENT AGREEMENT - Intellectual Property Rights                 Confidentiality and Non-Use Obligations Agreement.pdf': {},
#  'HEALTHGATEDATACORP_11_24_1999-EX-10.1-HOSTING AND MANAGEMENT AGREEMENT (1).pdf': {},
#  'HEALTHGATEDATACORP_11_24_1999-EX-10.1-HOSTING AND MANAGEMENT AGREEMENT - Escrow Agreement.pdf': {'DATE': 'D:\nBetween:\n(1)   [-1] whose registered office is at [-2] (CRN: [-3]) ("the Owner");\n(2)   [-4] whose registered office is at [-5] (CRN: [-6]) ("the Licensee"); and\n(3)   NCC ESCROW INTERNATIONAL LIMITED whose registered office is at Oxford\n      House, Oxford Road, Manchester M1 7ED, England (CRN:3081952) ("NCC")'},
#  'FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT.pdf': {},
#  'FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_AMENDMENT.pdf': {},
#  'FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_POWEROF.pdf': {},
#  'FEDERATEDGOVERNMENTINCOMESECURITIESINC_04_28_2020-EX-99.SERV AGREE-SERVICES AGREEMENT_SECONDAMENDMENT.pdf': {},
#  'KUBIENT,INC_07_02_2020-EX-10.14-MASTER SERVICES AGREEMENT_Part1.pdf': {},
#  'KUBIENT,INC_07_02_2020-EX-10.14-MASTER SERVICES AGREEMENT_Part2.pdf': {},
#  'NEONSYSTEMSINC_03_01_1999-EX-10.5-DISTRIBUTOR AGREEMENT_Amendment.pdf': {},
#  'NEONSYSTEMSINC_03_01_1999-EX-10.5-DISTRIBUTOR AGREEMENT_New.pdf': {'LAW': '',
#   'PRODUCT': 'S',
#   'EVENT': ' SHALL A PARTY TO THIS AGREEMENT BE\nLIABLE TO THE OTHER PARTY TO THIS AGREEMENT FOR ANY SPECIAL, INDIRECT,\nINCIDENTAL OR CONSEQUENTIAL DAMAGES RESULTING FROM THE USE, OR INABILITY TO USE,\nTHE LICENSED PRODUCTS OR ARISING OUT OF THIS AGREEMENT, INCLUDING BUT NOT LMTED\nTO LOSS OF PROFIT OR OTHER MONETARY LOSS, LOSS OR INTERRUPTION OF DATA OR\nCONTUTER TIME, ALTERATION OR ERRONEOUS TRANSNUSSION OF DATA OR PROGRAM ERRORS,\nEVEN IF SUCH PARTY IS ADVISED IN ADVANCE OF THE POSSIBILITY OF SUCH DAMAGES',
#   'TIME': ' FOR ACCEPTANCE'}}

# %%
def compare_clauses(template, clauses):  
    differences = {}  
    for clause, content in template.items():  
        if clause in clauses and clauses[clause] != content:  
            differences[clause] = {'template': content, 'document': clauses[clause]}  
    return differences  
  
# Define a simple template for demonstration purposes  
template = {  
    'EFFECTIVE_DATE': 'January 1, 2020',  
    'PARTIES': 'Company A and Company B',  
    # Add more template clauses as needed  
}  
  
# Compare each document's clauses with the template  
differences = {file: compare_clauses(template, classified_clauses[file]) for file in classified_clauses}

# %%
def highlight_differences(differences):  
    for pdf_path, diff in differences.items():  
        doc = fitz.open(pdf_path)  
        for page in doc:  
            for clause, contents in diff.items():  
                text_instances = page.search_for(contents['document'])  
                for inst in text_instances:  
                    highlight = page.add_highlight_annot(inst)  
                    highlight.update()  
        output_path = os.path.join(os.path.dirname(pdf_path), 'highlighted_' + os.path.basename(pdf_path))  
        doc.save(output_path)  
  
# highlight_differences(differences)

# %%
pdf_dir = 'C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf'  
parsed_texts = parse_pdfs(pdf_dir)  
  
# Proceed with NER, classification, comparison, and highlighting as outlined  
entities = {file: extract_entities(text) for file, text in parsed_texts.items()}  
classified_clauses = {file: classify_clauses(text, entities[file]) for file, text in parsed_texts.items()}  
differences = {file: compare_clauses(template, classified_clauses[file]) for file in classified_clauses}  
  
highlight_differences(differences)

# %%
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

# Extract text from both PDFs
original_pdf_path = 'C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/DigitalCinemaDestinationsCorp_20111220_S-1_EX-10.10_7346719_EX-10.10_Affiliate Agreement.pdf'
highlighted_pdf_path = 'C:/Users/akash/Desktop/IntelUnnaati-BusinessValidation/CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/highlighted_DigitalCinemaDestinationsCorp_20111220_S-1_EX-10.10_7346719_EX-10.10_Affiliate Agreement.pdf'

original_text = extract_text_from_pdf(original_pdf_path)
highlighted_text = extract_text_from_pdf(highlighted_pdf_path)

# Compare texts to find differences
import difflib

differ = difflib.Differ()
diff = differ.compare(original_text.splitlines(), highlighted_text.splitlines())
diff_result = '\n'.join(diff)

diff_result
# Out:
# "  \xa0 \n  DIGITAL CINEMA DESTINATIONS CORP. \n  \xa0 \n  NETWORK AFFILIATE AGREEMENT \n  \xa0 \n  THIS NETWORK AFFILIATE AGREEMENT (this “Agreement”) is made as of this 14th day of March, 2011 by and between National CineMedia, \n  LLC, a Delaware limited liability company (“NCM”), and Digital Cinema Destinations Corp., a Delaware corporation (“Network Affiliate”\xa0and with \n  NCM, each a “Party”\xa0and collectively, the “Parties”). \n  \xa0 \n  BACKGROUND \n  \xa0 \n  WHEREAS, NCM operates a “Digital Content Network”\xa0of proprietary and third-party hardware and software pursuant to which the \n  Service may be digitally transmitted to equipment and facilities installed in, and displayed on movie screens, video display terminals and similar \n  equipment located in, movie theatres or other high traffic retail establishments, as further described herein; \n  \xa0 \n  WHEREAS, Network Affiliate owns and operates a theatre circuit with a patron base in excess of 400,000 patrons; and \n  \xa0 \n  WHEREAS, both Network Affiliate and NCM want to expand NCM’s advertising “footprint”\xa0in the markets served by Network Affiliate; \n  and \n  \xa0 \n  WHEREAS, NCM and Network Affiliate want to enter into a strategic alliance under which NCM will provide the Service to Network \n  Affiliate, and Network Affiliate will accept and display the Service in its theatres, all on the terms set forth herein. \n  \xa0 \n  NOW, THEREFORE, in consideration of the premises and mutual covenants in this Agreement, and for other good and valuable \n  consideration, the receipt and sufficiency of which are hereby expressly acknowledged, and, intending to be legally bound hereby, the Parties \n  agree as follows: \n  \xa0 \n  ARTICLE I \n  DEFINITIONS \n  \xa0 \n  The following terms shall have the following meanings: \n  \xa0 \n  “Advertising Revenue Share”\xa0has the meaning assigned to it in Section 7.1. \n  \xa0 \n  “Advertising Services”\xa0means the advertising and promotional services (including the Digital Content Service, the Digital Carousel, the \n  Traditional Content Program, Lobby Promotions and Event Sponsorships) as described in Part A of Exhibit A. \n  \xa0 \n  “Base Amount”\xa0has the meaning assigned to it in Section 7.2. \n  \xa0 \n  “Beverage Agreement” means that certain Beverage Agreement, Pepsi dated January 1, 2011. \n  \xa0 \n  \xa0\n  1\n  Source: DIGITAL CINEMA DESTINATIONS CORP., S-1, 12/20/2011\n  \xa0 \n  “Branded Slots”\xa0has the meaning assigned to it in Section 3.6(b). \n  \xa0 \n  “Change of Control”\xa0has the meaning assigned to it in Section 14.8. \n  \xa0 \n  “Confidential Information” means any and all technical and non-technical information of or related to either Party, including, without \n  limitation, proprietary information, know-how, the NCM Property and Derived Works, and information related to or regarding either Party’s \n  research and development, finances, suppliers, customers, business forecasts, and marketing plans, in whatever form disclosed or made available. \n  Confidential Information does not include information which: (i) the recipient can demonstrate was already known to it at the time of its receipt \n  hereunder; (ii) is or becomes generally available to the public other than by means of the recipient's breach of its obligations under this \n  Agreement; (iii) is independently obtained from a third party whose disclosure violates no duty of confidentiality; or (iv) is independently \n  developed by or on behalf of the recipient without use of or reliance on any Confidential Information furnished to it under this Agreement. \n  \xa0 \n  “Costs”\xa0has the meaning assigned to it in Section 10.1. \n  \xa0 \n  “Derived Works”\xa0has the meaning assigned to it in Section 12.2. \n  \xa0 \n  “Digital Carousel”\xa0means a loop of slide advertising with minimal branding and entertainment content which (i) is displayed before the \n  Pre-Feature Program in Digitized Theatres via the Digital Co ...
